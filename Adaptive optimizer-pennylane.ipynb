# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane import qchem

hf_state = []
qubits = 4

dev = qml.device('default.qubit', wires=4)

@qml.qnode(dev)
def circuit(weight):
    qml.BasisState(hf_state, wires=range(qubits))
    #qml.FermionicSingleExcitation(weight, wires=[0,3])
    #qml.DoubleExcitation(weight, wires=[0,1,2,3])
    qml.SingleExcitation(weight, wires=[1,2])
    
    return qml.state()

weight = 5.0
print(circuit(weight))
print(qml.draw(circuit, level="device", max_length=1000)(weight))
# Out:
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# 0: ──────────┤ ╭State
# 1: ─╭G(5.00)─┤ ├State
# 2: ─╰G(5.00)─┤ ├State
# 3: ──────────┤ ╰State

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane import qchem

dev = qml.device('default.qubit', wires=8)
#hf_state = [1,1,1,1,0,0,0,0]
hf_state = [0,0,0,0,1,1,1,1]

@qml.qnode(dev)
def circuit(weight):
    [qml.PauliX(i) for i in np.nonzero(hf_state)[0]]
    #qml.FermionicSingleExcitation(weight, wires=[0,2])
    qml.SingleExcitation(weight, wires=[0,4])
    #qml.FermionicDoubleExcitation(weight, wires1=[0,1], wires2=[2,3])
    #qml.DoubleExcitation(weight, wires=[0,1,2,3])
    #[qml.PauliX(i) for i in np.nonzero(hf_state)[0]]
    return qml.state()

weight = 0.9
print(circuit(weight))
print(qml.draw(circuit, level="device", max_length=1000)(weight))

# %%
#-0.43496553  0.9004471 - 4th line

# %%
import numpy as np
import pennylane as qml
from scipy.optimize import minimize

import pennylane as qml

from pennylane import qchem
from pennylane import numpy as np




X = qml.PauliX
Y = qml.PauliY
Z = qml.PauliZ
I = qml.Identity

symbols = ["H","H","H","H"]
r_bohr = 3.0*1.8897259886
coordinates = np.array([[0.0,0.0, 1*r_bohr], [0.0, 0.0, 2*r_bohr], [0.0,0.0,3*r_bohr],[0.0, 0.0, 4*r_bohr]])
H, qubits = qml.qchem.molecular_hamiltonian(symbols, coordinates, basis="sto-6g", method = "openfermion")

print('The original hamiltonian is', H)
electrons = 4
orbitals = 8
qubits = 8
singles, doubles = qml.qchem.excitations(electrons, orbitals,fermionic=True)
print('Singles are',singles)
print('Doubles are',doubles)
hf_state = qchem.hf_state(electrons, qubits)
print(f"Total number of excitations = {len(singles) + len(doubles)}")



dev = qml.device("default.qubit", wires=qubits)
@qml.qnode(dev)
def circuit(hf_state, electrons, qubits, H):
    # Prepare the Hartree-Fock state
    print('Updated hf_state is', hf_state)
    qml.BasisState(hf_state, wires=range(qubits))
    

    return qml.expval(H)
print('HF state is', circuit(hf_state, electrons, qubits, H))

# Define the Ash excitation structure (as per your example)
#ash_excitation = [[2, 3, 6, 7], [0, 3, 5, 6], [0, 1, 4, 5], [1, 2, 4, 7], [0, 4], [2,6]]
#ash_excitation = [[2, 3, 6, 7], [0, 3, 5, 6], [0, 1, 4, 5], [1, 2, 4, 7], [3, 7], [0,4]]
#ash_excitation = [[2, 3, 6, 7], [0, 3, 5, 6], [0, 1, 4, 5], [1, 2, 4, 7], [1, 5]]

ash_excitation = [[2,6],[1, 2, 4, 7],[0,1,4,5],[0, 3, 5, 6],[2, 3, 6, 7]]
params = np.zeros(len(ash_excitation), requires_grad=True)

dev = qml.device("default.qubit", wires=qubits)

# QNode to evaluate energy
@qml.qnode(dev)
def circuit(params, ash_excitation, hf_state, qubits, H):
    qml.BasisState(hf_state, wires=range(qubits))
    for i, excitations in enumerate(ash_excitation):
        if len(excitations) == 4:
            qml.FermionicDoubleExcitation(weight = params[i], wires1=excitations[2:][::-1], wires2=excitations[:2][::-1])
        else:
            print(f'Single excitations coming in is {excitations} and parameters are {params[i]}')
            qml.FermionicSingleExcitation(weight= params[i], wires = ash_excitation[i])
    return qml.expval(H)


#dev = qml.device("default.qubit", wires=qubits)

# QNode to evaluate energy
#@qml.qnode(dev)
def cost_fn(params, ash_excitation, hf_state, qubits, H):
    # Compute the energy
    energy = circuit(params, ash_excitation, hf_state, qubits, H)
    
    # Compute the gradient of the energy with respect to the parameters
    #grad = qml.grad(circuit)(params, ash_excitation, hf_state, qubits, H)
    
        # Calculate gradient norm (L2 norm)
    #grad_norm = np.linalg.norm(grad)
    
    # Calculate maximum gradient
    #grad_max = np.max(np.abs(grad))
    
    # Debugging: Print the gradient information
    print(f"Energy: {energy}")
    #print(f"Gradient: {grad}")
    #print(f"Gradient Norm: {grad_norm}")
    #print(f"Maximum Gradient: {grad_max}")
    return energy



params_initial = np.zeros(len(ash_excitation))
#bounds = ([(0, 0.97)] * len(ash_excitation))

# Function to minimize
def minimize_function(params):
    energy= cost_fn(params, ash_excitation, hf_state, qubits, H)
    return energy

# Using scipy.optimize.minimize with L-BFGS-B
result = minimize(
    fun=minimize_function,   # The cost function
    x0=params_initial,       # Initial guess
    jac=True,                 # Enable gradient computation
    method='L-BFGS-B',        # Use L-BFGS-B optimizer
    #bounds=bounds,       # Use L-BFGS-B optimizer
    options={'disp': True, 'maxiter': 100, 'gtol' : 1e-12}  # Display options and max iterations
)

# Extract the result
optimized_params = result.x
minimized_energy = result.fun
Gradient = result.jac   

print(f"Optimized parameters: {optimized_params}")
print(f"Minimized energy: {minimized_energy}")

# %% [markdown]
# ## Adaptive optimizer

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane import qchem



symbols = ["H","H","H","H"]
r_bohr = 5.0*1.8897259886
coordinates = np.array([[0.0,0.0, 1*r_bohr], [0.0, 0.0, 2*r_bohr], [0.0,0.0,3*r_bohr],[0.0, 0.0, 4*r_bohr]])
H, qubits = qml.qchem.molecular_hamiltonian(symbols, coordinates, basis="sto-6g", method="pyscf")

n_electrons = 4
singles, doubles = qml.qchem.excitations(n_electrons, qubits)
singles_excitations = [qml.SingleExcitation(0.0, x) for x in singles]
doubles_excitations = [qml.DoubleExcitation(0.0, x) for x in doubles]
operator_pool = doubles_excitations + singles_excitations
print(len(operator_pool))

hf_state = qml.qchem.hf_state(n_electrons, qubits)
dev = qml.device("default.qubit", wires=qubits)
@qml.qnode(dev)
def circuit():
    qml.BasisState(hf_state, wires=range(qubits))
    return qml.expval(H)

print(circuit())

opt = qml.AdaptiveOptimizer(param_steps = 6)
for i in range(len(operator_pool)):
    circuit, energy, gradient = opt.step_and_cost(circuit, operator_pool, drain_pool=False)
    print('Energy:', energy)
    print(qml.draw(circuit, show_matrices=False)())
    print('Largest Gradient:', gradient)
    print()
    if gradient < 1e-4:
        break
# Out:
# 26
# -1.2160238591303265
# Energy: -1.2160238591303265
# 0: ─╭|Ψ⟩───────────┤ ╭<𝓗>
# 1: ─├|Ψ⟩───────────┤ ├<𝓗>
# 2: ─├|Ψ⟩─╭G²(0.48)─┤ ├<𝓗>
# 3: ─├|Ψ⟩─├G²(0.48)─┤ ├<𝓗>
# 4: ─├|Ψ⟩─│─────────┤ ├<𝓗>
# 5: ─├|Ψ⟩─│─────────┤ ├<𝓗>
# 6: ─├|Ψ⟩─├G²(0.48)─┤ ├<𝓗>
# 7: ─╰|Ψ⟩─╰G²(0.48)─┤ ╰<𝓗>
# Largest Gradient: 0.1717303730851781
#
# Energy: -1.2926292852498282
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─┤ ╭<𝓗>
# 1: ─├|Ψ⟩───────────│─────────┤ ├<𝓗>
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────┤ ├<𝓗>
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─┤ ├<𝓗>
# 4: ─├|Ψ⟩─│─────────│─────────┤ ├<𝓗>
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─┤ ├<𝓗>
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)─┤ ├<𝓗>
# 7: ─╰|Ψ⟩─╰G²(0.48)───────────┤ ╰<𝓗>
# Largest Gradient: 0.19750003148620912
#
# Energy: -1.3906949104050665
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─┤ ╭<𝓗>
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─┤ ├<𝓗>
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────┤ ├<𝓗>
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────┤ ├<𝓗>
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─┤ ├<𝓗>
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─┤ ├<𝓗>
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────┤ ├<𝓗>
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────┤ ╰<𝓗>
# Largest Gradient: 0.2164507617150062
#
# Energy: -1.5040067554216985
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)───────────┤ ╭<𝓗>
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)─┤ ├<𝓗>
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─┤ ├<𝓗>
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────┤ ├<𝓗>
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─┤ ├<𝓗>
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────┤ ├<𝓗>
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────┤ ├<𝓗>
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─┤ ╰<𝓗>
# Largest Gradient: 0.24203728648165335
#
# Energy: -1.6364116111403604
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────┤ ╭<𝓗>
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────┤ ├<𝓗>
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─┤ ├<𝓗>
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─┤ ├<𝓗>
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────┤ ├<𝓗>
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────┤ ├<𝓗>
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)─┤ ├<𝓗>
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─┤ ╰<𝓗>
# Largest Gradient: 0.1864562892347193
#
# Energy: -1.7017780052118727
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─┤ ╭<𝓗>
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─┤ ├<𝓗>
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────┤ ├<𝓗>
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────┤ ├<𝓗>
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─┤ ├<𝓗>
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─┤ ├<𝓗>
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────┤ ├<𝓗>
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)───────────┤ ╰<𝓗>
# Largest Gradient: 0.18127238049114575
#
# Energy: -1.7621080233037936
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)─┤ ╭<𝓗>
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────┤ ├<𝓗>
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────┤ ├<𝓗>
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─┤ ├<𝓗>
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────┤ ├<𝓗>
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─┤ ├<𝓗>
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─┤ ├<𝓗>
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────┤ ╰<𝓗>
# Largest Gradient: 0.13712263279365305
#
# Energy: -1.796172542888034
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────┤ ╭<𝓗>
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─┤ ├<𝓗>
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─┤ ├<𝓗>
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────┤ ├<𝓗>
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─┤ ├<𝓗>
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────┤ ├<𝓗>
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────┤ ├<𝓗>
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)─┤ ╰<𝓗>
# Largest Gradient: 0.124585949575646
#
# Energy: -1.8237393969644347
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)─┤
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│─────────┤
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│─────────┤
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)─┤
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│─────────┤
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)─┤
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)─┤
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)───────────┤
#
#   ╭<𝓗>
#   ├<𝓗>
#   ├<𝓗>
#   ├<𝓗>
#   ├<𝓗>
#   ├<𝓗>
#   ├<𝓗>
#   ╰<𝓗>
# Largest Gradient: 0.08243437571676582
#
# Energy: -1.8355093732957242
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ────────────┤ ╭<𝓗>
# ──╭G²(0.16)─┤ ├<𝓗>
# ──├G²(0.16)─┤ ├<𝓗>
# ──│─────────┤ ├<𝓗>
# ──├G²(0.16)─┤ ├<𝓗>
# ──│─────────┤ ├<𝓗>
# ──│─────────┤ ├<𝓗>
# ──╰G²(0.16)─┤ ╰<𝓗>
# Largest Gradient: 0.070522846063242
#
# Energy: -1.8440617488427897
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ──────────────────────┤ ╭<𝓗>
# ──╭G²(0.16)───────────┤ ├<𝓗>
# ──├G²(0.16)─╭G²(0.11)─┤ ├<𝓗>
# ──│─────────├G²(0.11)─┤ ├<𝓗>
# ──├G²(0.16)─│─────────┤ ├<𝓗>
# ──│─────────│─────────┤ ├<𝓗>
# ──│─────────├G²(0.11)─┤ ├<𝓗>
# ──╰G²(0.16)─╰G²(0.11)─┤ ╰<𝓗>
# Largest Gradient: 0.046748615981793806
#
# Energy: -1.8476868720042694
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ──────────────────────╭G²(0.08)─┤ ╭<𝓗>
# ──╭G²(0.16)───────────│─────────┤ ├<𝓗>
# ──├G²(0.16)─╭G²(0.11)─│─────────┤ ├<𝓗>
# ──│─────────├G²(0.11)─├G²(0.08)─┤ ├<𝓗>
# ──├G²(0.16)─│─────────│─────────┤ ├<𝓗>
# ──│─────────│─────────├G²(0.08)─┤ ├<𝓗>
# ──│─────────├G²(0.11)─╰G²(0.08)─┤ ├<𝓗>
# ──╰G²(0.16)─╰G²(0.11)───────────┤ ╰<𝓗>
# Largest Gradient: 0.03499959667615815
#
# Energy: -1.849774579210617
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ──────────────────────╭G²(0.08)───────────┤ ╭<𝓗>
# ──╭G²(0.16)───────────│─────────╭G²(0.06)─┤ ├<𝓗>
# ──├G²(0.16)─╭G²(0.11)─│─────────├G²(0.06)─┤ ├<𝓗>
# ──│─────────├G²(0.11)─├G²(0.08)─│─────────┤ ├<𝓗>
# ──├G²(0.16)─│─────────│─────────├G²(0.06)─┤ ├<𝓗>
# ──│─────────│─────────├G²(0.08)─│─────────┤ ├<𝓗>
# ──│─────────├G²(0.11)─╰G²(0.08)─│─────────┤ ├<𝓗>
# ──╰G²(0.16)─╰G²(0.11)───────────╰G²(0.06)─┤ ╰<𝓗>
# Largest Gradient: 0.02609846168773866
#
# Energy: -1.8509336064379507
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ──────────────────────╭G²(0.08)───────────╭G²(0.04)─┤ ╭<𝓗>
# ──╭G²(0.16)───────────│─────────╭G²(0.06)─├G²(0.04)─┤ ├<𝓗>
# ──├G²(0.16)─╭G²(0.11)─│─────────├G²(0.06)─│─────────┤ ├<𝓗>
# ──│─────────├G²(0.11)─├G²(0.08)─│─────────│─────────┤ ├<𝓗>
# ──├G²(0.16)─│─────────│─────────├G²(0.06)─├G²(0.04)─┤ ├<𝓗>
# ──│─────────│─────────├G²(0.08)─│─────────╰G²(0.04)─┤ ├<𝓗>
# ──│─────────├G²(0.11)─╰G²(0.08)─│───────────────────┤ ├<𝓗>
# ──╰G²(0.16)─╰G²(0.11)───────────╰G²(0.06)───────────┤ ╰<𝓗>
# Largest Gradient: 0.019853110060806145
#
# Energy: -1.8515846818661785
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ──────────────────────╭G²(0.08)───────────╭G²(0.04)─╭G²(0.03)─┤ ╭<𝓗>
# ──╭G²(0.16)───────────│─────────╭G²(0.06)─├G²(0.04)─│─────────┤ ├<𝓗>
# ──├G²(0.16)─╭G²(0.11)─│─────────├G²(0.06)─│─────────│─────────┤ ├<𝓗>
# ──│─────────├G²(0.11)─├G²(0.08)─│─────────│─────────├G²(0.03)─┤ ├<𝓗>
# ──├G²(0.16)─│─────────│─────────├G²(0.06)─├G²(0.04)─│─────────┤ ├<𝓗>
# ──│─────────│─────────├G²(0.08)─│─────────╰G²(0.04)─├G²(0.03)─┤ ├<𝓗>
# ──│─────────├G²(0.11)─╰G²(0.08)─│───────────────────╰G²(0.03)─┤ ├<𝓗>
# ──╰G²(0.16)─╰G²(0.11)───────────╰G²(0.06)─────────────────────┤ ╰<𝓗>
# Largest Gradient: 0.014149547436212995
#
# Energy: -1.8519249599595144
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ──────────────────────╭G²(0.08)───────────╭G²(0.04)─╭G²(0.03)───────────┤ ╭<𝓗>
# ──╭G²(0.16)───────────│─────────╭G²(0.06)─├G²(0.04)─│─────────╭G²(0.02)─┤ ├<𝓗>
# ──├G²(0.16)─╭G²(0.11)─│─────────├G²(0.06)─│─────────│─────────├G²(0.02)─┤ ├<𝓗>
# ──│─────────├G²(0.11)─├G²(0.08)─│─────────│─────────├G²(0.03)─│─────────┤ ├<𝓗>
# ──├G²(0.16)─│─────────│─────────├G²(0.06)─├G²(0.04)─│─────────├G²(0.02)─┤ ├<𝓗>
# ──│─────────│─────────├G²(0.08)─│─────────╰G²(0.04)─├G²(0.03)─│─────────┤ ├<𝓗>
# ──│─────────├G²(0.11)─╰G²(0.08)─│───────────────────╰G²(0.03)─│─────────┤ ├<𝓗>
# ──╰G²(0.16)─╰G²(0.11)───────────╰G²(0.06)─────────────────────╰G²(0.02)─┤ ╰<𝓗>
# Largest Gradient: 0.008887122574815942
#
# Energy: -1.852059156490164
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ──────────────────────╭G²(0.08)───────────╭G²(0.04)─╭G²(0.03)───────────╭G²(0.02)─┤ ╭<𝓗>
# ──╭G²(0.16)───────────│─────────╭G²(0.06)─├G²(0.04)─│─────────╭G²(0.02)─│─────────┤ ├<𝓗>
# ──├G²(0.16)─╭G²(0.11)─│─────────├G²(0.06)─│─────────│─────────├G²(0.02)─│─────────┤ ├<𝓗>
# ──│─────────├G²(0.11)─├G²(0.08)─│─────────│─────────├G²(0.03)─│─────────├G²(0.02)─┤ ├<𝓗>
# ──├G²(0.16)─│─────────│─────────├G²(0.06)─├G²(0.04)─│─────────├G²(0.02)─│─────────┤ ├<𝓗>
# ──│─────────│─────────├G²(0.08)─│─────────╰G²(0.04)─├G²(0.03)─│─────────├G²(0.02)─┤ ├<𝓗>
# ──│─────────├G²(0.11)─╰G²(0.08)─│───────────────────╰G²(0.03)─│─────────╰G²(0.02)─┤ ├<𝓗>
# ──╰G²(0.16)─╰G²(0.11)───────────╰G²(0.06)─────────────────────╰G²(0.02)───────────┤ ╰<𝓗>
# Largest Gradient: 0.007585555808032218
#
# Energy: -1.8521569161175868
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ──────────────────────╭G²(0.08)───────────╭G²(0.04)─╭G²(0.03)───────────╭G²(0.02)───────────┤ ╭<𝓗>
# ──╭G²(0.16)───────────│─────────╭G²(0.06)─├G²(0.04)─│─────────╭G²(0.02)─│─────────╭G²(0.01)─┤ ├<𝓗>
# ──├G²(0.16)─╭G²(0.11)─│─────────├G²(0.06)─│─────────│─────────├G²(0.02)─│─────────├G²(0.01)─┤ ├<𝓗>
# ──│─────────├G²(0.11)─├G²(0.08)─│─────────│─────────├G²(0.03)─│─────────├G²(0.02)─│─────────┤ ├<𝓗>
# ──├G²(0.16)─│─────────│─────────├G²(0.06)─├G²(0.04)─│─────────├G²(0.02)─│─────────├G²(0.01)─┤ ├<𝓗>
# ──│─────────│─────────├G²(0.08)─│─────────╰G²(0.04)─├G²(0.03)─│─────────├G²(0.02)─│─────────┤ ├<𝓗>
# ──│─────────├G²(0.11)─╰G²(0.08)─│───────────────────╰G²(0.03)─│─────────╰G²(0.02)─│─────────┤ ├<𝓗>
# ──╰G²(0.16)─╰G²(0.11)───────────╰G²(0.06)─────────────────────╰G²(0.02)───────────╰G²(0.01)─┤ ╰<𝓗>
# Largest Gradient: 0.004903497147995206
#
# Energy: -1.8521977631644726
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ──────────────────────╭G²(0.08)───────────╭G²(0.04)─╭G²(0.03)───────────╭G²(0.02)──────────
# ──╭G²(0.16)───────────│─────────╭G²(0.06)─├G²(0.04)─│─────────╭G²(0.02)─│─────────╭G²(0.01)
# ──├G²(0.16)─╭G²(0.11)─│─────────├G²(0.06)─│─────────│─────────├G²(0.02)─│─────────├G²(0.01)
# ──│─────────├G²(0.11)─├G²(0.08)─│─────────│─────────├G²(0.03)─│─────────├G²(0.02)─│────────
# ──├G²(0.16)─│─────────│─────────├G²(0.06)─├G²(0.04)─│─────────├G²(0.02)─│─────────├G²(0.01)
# ──│─────────│─────────├G²(0.08)─│─────────╰G²(0.04)─├G²(0.03)─│─────────├G²(0.02)─│────────
# ──│─────────├G²(0.11)─╰G²(0.08)─│───────────────────╰G²(0.03)─│─────────╰G²(0.02)─│────────
# ──╰G²(0.16)─╰G²(0.11)───────────╰G²(0.06)─────────────────────╰G²(0.02)───────────╰G²(0.01)
#
# ──╭G²(0.01)─┤ ╭<𝓗>
# ──│─────────┤ ├<𝓗>
# ──│─────────┤ ├<𝓗>
# ──├G²(0.01)─┤ ├<𝓗>
# ──│─────────┤ ├<𝓗>
# ──├G²(0.01)─┤ ├<𝓗>
# ──╰G²(0.01)─┤ ├<𝓗>
# ────────────┤ ╰<𝓗>
# Largest Gradient: 0.004074553604713427
#
# Energy: -1.852225966341282
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ──────────────────────╭G²(0.08)───────────╭G²(0.04)─╭G²(0.03)───────────╭G²(0.02)──────────
# ──╭G²(0.16)───────────│─────────╭G²(0.06)─├G²(0.04)─│─────────╭G²(0.02)─│─────────╭G²(0.01)
# ──├G²(0.16)─╭G²(0.11)─│─────────├G²(0.06)─│─────────│─────────├G²(0.02)─│─────────├G²(0.01)
# ──│─────────├G²(0.11)─├G²(0.08)─│─────────│─────────├G²(0.03)─│─────────├G²(0.02)─│────────
# ──├G²(0.16)─│─────────│─────────├G²(0.06)─├G²(0.04)─│─────────├G²(0.02)─│─────────├G²(0.01)
# ──│─────────│─────────├G²(0.08)─│─────────╰G²(0.04)─├G²(0.03)─│─────────├G²(0.02)─│────────
# ──│─────────├G²(0.11)─╰G²(0.08)─│───────────────────╰G²(0.03)─│─────────╰G²(0.02)─│────────
# ──╰G²(0.16)─╰G²(0.11)───────────╰G²(0.06)─────────────────────╰G²(0.02)───────────╰G²(0.01)
#
# ──╭G²(0.01)───────────┤ ╭<𝓗>
# ──│───────────────────┤ ├<𝓗>
# ──│─────────╭G²(0.01)─┤ ├<𝓗>
# ──├G²(0.01)─├G²(0.01)─┤ ├<𝓗>
# ──│─────────│─────────┤ ├<𝓗>
# ──├G²(0.01)─│─────────┤ ├<𝓗>
# ──╰G²(0.01)─├G²(0.01)─┤ ├<𝓗>
# ────────────╰G²(0.01)─┤ ╰<𝓗>
# Largest Gradient: 0.002946641836204078
#
# Energy: -1.8522402943844085
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ──────────────────────╭G²(0.08)───────────╭G²(0.04)─╭G²(0.03)───────────╭G²(0.02)──────────
# ──╭G²(0.16)───────────│─────────╭G²(0.06)─├G²(0.04)─│─────────╭G²(0.02)─│─────────╭G²(0.01)
# ──├G²(0.16)─╭G²(0.11)─│─────────├G²(0.06)─│─────────│─────────├G²(0.02)─│─────────├G²(0.01)
# ──│─────────├G²(0.11)─├G²(0.08)─│─────────│─────────├G²(0.03)─│─────────├G²(0.02)─│────────
# ──├G²(0.16)─│─────────│─────────├G²(0.06)─├G²(0.04)─│─────────├G²(0.02)─│─────────├G²(0.01)
# ──│─────────│─────────├G²(0.08)─│─────────╰G²(0.04)─├G²(0.03)─│─────────├G²(0.02)─│────────
# ──│─────────├G²(0.11)─╰G²(0.08)─│───────────────────╰G²(0.03)─│─────────╰G²(0.02)─│────────
# ──╰G²(0.16)─╰G²(0.11)───────────╰G²(0.06)─────────────────────╰G²(0.02)───────────╰G²(0.01)
#
# ──╭G²(0.01)─────────────────────┤ ╭<𝓗>
# ──│───────────────────╭G²(0.00)─┤ ├<𝓗>
# ──│─────────╭G²(0.01)─├G²(0.00)─┤ ├<𝓗>
# ──├G²(0.01)─├G²(0.01)─│─────────┤ ├<𝓗>
# ──│─────────│─────────├G²(0.00)─┤ ├<𝓗>
# ──├G²(0.01)─│─────────│─────────┤ ├<𝓗>
# ──╰G²(0.01)─├G²(0.01)─│─────────┤ ├<𝓗>
# ────────────╰G²(0.01)─╰G²(0.00)─┤ ╰<𝓗>
# Largest Gradient: 0.0019585775855052168
#
# Energy: -1.8522468107782701
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ──────────────────────╭G²(0.08)───────────╭G²(0.04)─╭G²(0.03)───────────╭G²(0.02)──────────
# ──╭G²(0.16)───────────│─────────╭G²(0.06)─├G²(0.04)─│─────────╭G²(0.02)─│─────────╭G²(0.01)
# ──├G²(0.16)─╭G²(0.11)─│─────────├G²(0.06)─│─────────│─────────├G²(0.02)─│─────────├G²(0.01)
# ──│─────────├G²(0.11)─├G²(0.08)─│─────────│─────────├G²(0.03)─│─────────├G²(0.02)─│────────
# ──├G²(0.16)─│─────────│─────────├G²(0.06)─├G²(0.04)─│─────────├G²(0.02)─│─────────├G²(0.01)
# ──│─────────│─────────├G²(0.08)─│─────────╰G²(0.04)─├G²(0.03)─│─────────├G²(0.02)─│────────
# ──│─────────├G²(0.11)─╰G²(0.08)─│───────────────────╰G²(0.03)─│─────────╰G²(0.02)─│────────
# ──╰G²(0.16)─╰G²(0.11)───────────╰G²(0.06)─────────────────────╰G²(0.02)───────────╰G²(0.01)
#
# ──╭G²(0.01)─────────────────────╭G²(0.00)─┤ ╭<𝓗>
# ──│───────────────────╭G²(0.00)─│─────────┤ ├<𝓗>
# ──│─────────╭G²(0.01)─├G²(0.00)─│─────────┤ ├<𝓗>
# ──├G²(0.01)─├G²(0.01)─│─────────├G²(0.00)─┤ ├<𝓗>
# ──│─────────│─────────├G²(0.00)─│─────────┤ ├<𝓗>
# ──├G²(0.01)─│─────────│─────────├G²(0.00)─┤ ├<𝓗>
# ──╰G²(0.01)─├G²(0.01)─│─────────╰G²(0.00)─┤ ├<𝓗>
# ────────────╰G²(0.01)─╰G²(0.00)───────────┤ ╰<𝓗>
# Largest Gradient: 0.0014023251237135215
#
# Energy: -1.852250151353073
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ──────────────────────╭G²(0.08)───────────╭G²(0.04)─╭G²(0.03)───────────╭G²(0.02)──────────
# ──╭G²(0.16)───────────│─────────╭G²(0.06)─├G²(0.04)─│─────────╭G²(0.02)─│─────────╭G²(0.01)
# ──├G²(0.16)─╭G²(0.11)─│─────────├G²(0.06)─│─────────│─────────├G²(0.02)─│─────────├G²(0.01)
# ──│─────────├G²(0.11)─├G²(0.08)─│─────────│─────────├G²(0.03)─│─────────├G²(0.02)─│────────
# ──├G²(0.16)─│─────────│─────────├G²(0.06)─├G²(0.04)─│─────────├G²(0.02)─│─────────├G²(0.01)
# ──│─────────│─────────├G²(0.08)─│─────────╰G²(0.04)─├G²(0.03)─│─────────├G²(0.02)─│────────
# ──│─────────├G²(0.11)─╰G²(0.08)─│───────────────────╰G²(0.03)─│─────────╰G²(0.02)─│────────
# ──╰G²(0.16)─╰G²(0.11)───────────╰G²(0.06)─────────────────────╰G²(0.02)───────────╰G²(0.01)
#
# ──╭G²(0.01)─────────────────────╭G²(0.00)───────────┤ ╭<𝓗>
# ──│───────────────────╭G²(0.00)─│─────────╭G²(0.00)─┤ ├<𝓗>
# ──│─────────╭G²(0.01)─├G²(0.00)─│─────────├G²(0.00)─┤ ├<𝓗>
# ──├G²(0.01)─├G²(0.01)─│─────────├G²(0.00)─│─────────┤ ├<𝓗>
# ──│─────────│─────────├G²(0.00)─│─────────├G²(0.00)─┤ ├<𝓗>
# ──├G²(0.01)─│─────────│─────────├G²(0.00)─│─────────┤ ├<𝓗>
# ──╰G²(0.01)─├G²(0.01)─│─────────╰G²(0.00)─│─────────┤ ├<𝓗>
# ────────────╰G²(0.01)─╰G²(0.00)───────────╰G²(0.00)─┤ ╰<𝓗>
# Largest Gradient: 0.0010614474550826314
#
# Energy: -1.852252065255735
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ──────────────────────╭G²(0.08)───────────╭G²(0.04)─╭G²(0.03)───────────╭G²(0.02)──────────
# ──╭G²(0.16)───────────│─────────╭G²(0.06)─├G²(0.04)─│─────────╭G²(0.02)─│─────────╭G²(0.01)
# ──├G²(0.16)─╭G²(0.11)─│─────────├G²(0.06)─│─────────│─────────├G²(0.02)─│─────────├G²(0.01)
# ──│─────────├G²(0.11)─├G²(0.08)─│─────────│─────────├G²(0.03)─│─────────├G²(0.02)─│────────
# ──├G²(0.16)─│─────────│─────────├G²(0.06)─├G²(0.04)─│─────────├G²(0.02)─│─────────├G²(0.01)
# ──│─────────│─────────├G²(0.08)─│─────────╰G²(0.04)─├G²(0.03)─│─────────├G²(0.02)─│────────
# ──│─────────├G²(0.11)─╰G²(0.08)─│───────────────────╰G²(0.03)─│─────────╰G²(0.02)─│────────
# ──╰G²(0.16)─╰G²(0.11)───────────╰G²(0.06)─────────────────────╰G²(0.02)───────────╰G²(0.01)
#
# ──╭G²(0.01)─────────────────────╭G²(0.00)───────────╭G²(0.00)─┤ ╭<𝓗>
# ──│───────────────────╭G²(0.00)─│─────────╭G²(0.00)─│─────────┤ ├<𝓗>
# ──│─────────╭G²(0.01)─├G²(0.00)─│─────────├G²(0.00)─│─────────┤ ├<𝓗>
# ──├G²(0.01)─├G²(0.01)─│─────────├G²(0.00)─│─────────├G²(0.00)─┤ ├<𝓗>
# ──│─────────│─────────├G²(0.00)─│─────────├G²(0.00)─│─────────┤ ├<𝓗>
# ──├G²(0.01)─│─────────│─────────├G²(0.00)─│─────────├G²(0.00)─┤ ├<𝓗>
# ──╰G²(0.01)─├G²(0.01)─│─────────╰G²(0.00)─│─────────╰G²(0.00)─┤ ├<𝓗>
# ────────────╰G²(0.01)─╰G²(0.00)───────────╰G²(0.00)───────────┤ ╰<𝓗>
# Largest Gradient: 0.0007640132630895025
#
# Energy: -1.8522530568274236
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ──────────────────────╭G²(0.08)───────────╭G²(0.04)─╭G²(0.03)───────────╭G²(0.02)──────────
# ──╭G²(0.16)───────────│─────────╭G²(0.06)─├G²(0.04)─│─────────╭G²(0.02)─│─────────╭G²(0.01)
# ──├G²(0.16)─╭G²(0.11)─│─────────├G²(0.06)─│─────────│─────────├G²(0.02)─│─────────├G²(0.01)
# ──│─────────├G²(0.11)─├G²(0.08)─│─────────│─────────├G²(0.03)─│─────────├G²(0.02)─│────────
# ──├G²(0.16)─│─────────│─────────├G²(0.06)─├G²(0.04)─│─────────├G²(0.02)─│─────────├G²(0.01)
# ──│─────────│─────────├G²(0.08)─│─────────╰G²(0.04)─├G²(0.03)─│─────────├G²(0.02)─│────────
# ──│─────────├G²(0.11)─╰G²(0.08)─│───────────────────╰G²(0.03)─│─────────╰G²(0.02)─│────────
# ──╰G²(0.16)─╰G²(0.11)───────────╰G²(0.06)─────────────────────╰G²(0.02)───────────╰G²(0.01)
#
# ──╭G²(0.01)─────────────────────╭G²(0.00)───────────╭G²(0.00)───────────┤ ╭<𝓗>
# ──│───────────────────╭G²(0.00)─│─────────╭G²(0.00)─│─────────╭G²(0.00)─┤ ├<𝓗>
# ──│─────────╭G²(0.01)─├G²(0.00)─│─────────├G²(0.00)─│─────────├G²(0.00)─┤ ├<𝓗>
# ──├G²(0.01)─├G²(0.01)─│─────────├G²(0.00)─│─────────├G²(0.00)─│─────────┤ ├<𝓗>
# ──│─────────│─────────├G²(0.00)─│─────────├G²(0.00)─│─────────├G²(0.00)─┤ ├<𝓗>
# ──├G²(0.01)─│─────────│─────────├G²(0.00)─│─────────├G²(0.00)─│─────────┤ ├<𝓗>
# ──╰G²(0.01)─├G²(0.01)─│─────────╰G²(0.00)─│─────────╰G²(0.00)─│─────────┤ ├<𝓗>
# ────────────╰G²(0.01)─╰G²(0.00)───────────╰G²(0.00)───────────╰G²(0.00)─┤ ╰<𝓗>
# Largest Gradient: 0.0005755272029795977
#
# Energy: -1.852253619497465
# 0: ─╭|Ψ⟩───────────╭G²(0.55)─╭G²(0.59)─────────────────────╭G²(0.43)─╭G²(0.32)───────────╭G²(0.19)
# 1: ─├|Ψ⟩───────────│─────────├G²(0.59)─╭G²(0.64)───────────├G²(0.43)─│─────────╭G²(0.29)─│────────
# 2: ─├|Ψ⟩─╭G²(0.48)─│─────────│─────────├G²(0.64)─╭G²(0.45)─│─────────│─────────├G²(0.29)─│────────
# 3: ─├|Ψ⟩─├G²(0.48)─├G²(0.55)─│─────────│─────────├G²(0.45)─│─────────├G²(0.32)─│─────────├G²(0.19)
# 4: ─├|Ψ⟩─│─────────│─────────├G²(0.59)─├G²(0.64)─│─────────├G²(0.43)─│─────────├G²(0.29)─│────────
# 5: ─├|Ψ⟩─│─────────├G²(0.55)─╰G²(0.59)─│─────────│─────────╰G²(0.43)─├G²(0.32)─│─────────├G²(0.19)
# 6: ─├|Ψ⟩─├G²(0.48)─╰G²(0.55)───────────│─────────├G²(0.45)───────────╰G²(0.32)─│─────────╰G²(0.19)
# 7: ─╰|Ψ⟩─╰G²(0.48)─────────────────────╰G²(0.64)─╰G²(0.45)─────────────────────╰G²(0.29)──────────
#
# ──────────────────────╭G²(0.08)───────────╭G²(0.04)─╭G²(0.03)───────────╭G²(0.02)──────────
# ──╭G²(0.16)───────────│─────────╭G²(0.06)─├G²(0.04)─│─────────╭G²(0.02)─│─────────╭G²(0.01)
# ──├G²(0.16)─╭G²(0.11)─│─────────├G²(0.06)─│─────────│─────────├G²(0.02)─│─────────├G²(0.01)
# ──│─────────├G²(0.11)─├G²(0.08)─│─────────│─────────├G²(0.03)─│─────────├G²(0.02)─│────────
# ──├G²(0.16)─│─────────│─────────├G²(0.06)─├G²(0.04)─│─────────├G²(0.02)─│─────────├G²(0.01)
# ──│─────────│─────────├G²(0.08)─│─────────╰G²(0.04)─├G²(0.03)─│─────────├G²(0.02)─│────────
# ──│─────────├G²(0.11)─╰G²(0.08)─│───────────────────╰G²(0.03)─│─────────╰G²(0.02)─│────────
# ──╰G²(0.16)─╰G²(0.11)───────────╰G²(0.06)─────────────────────╰G²(0.02)───────────╰G²(0.01)
#
# ──╭G²(0.01)─────────────────────╭G²(0.00)───────────╭G²(0.00)───────────╭G²(0.00)─┤ ╭<𝓗>
# ──│───────────────────╭G²(0.00)─│─────────╭G²(0.00)─│─────────╭G²(0.00)─│─────────┤ ├<𝓗>
# ──│─────────╭G²(0.01)─├G²(0.00)─│─────────├G²(0.00)─│─────────├G²(0.00)─│─────────┤ ├<𝓗>
# ──├G²(0.01)─├G²(0.01)─│─────────├G²(0.00)─│─────────├G²(0.00)─│─────────├G²(0.00)─┤ ├<𝓗>
# ──│─────────│─────────├G²(0.00)─│─────────├G²(0.00)─│─────────├G²(0.00)─│─────────┤ ├<𝓗>
# ──├G²(0.01)─│─────────│─────────├G²(0.00)─│─────────├G²(0.00)─│─────────├G²(0.00)─┤ ├<𝓗>
# ──╰G²(0.01)─├G²(0.01)─│─────────╰G²(0.00)─│─────────╰G²(0.00)─│─────────╰G²(0.00)─┤ ├<𝓗>
# ────────────╰G²(0.01)─╰G²(0.00)───────────╰G²(0.00)───────────╰G²(0.00)───────────┤ ╰<𝓗>
# Largest Gradient: 0.00041605256491539233

# %%
import pennylane as qml
from pennylane import qchem
from pennylane import numpy as np
from itertools import chain
import time
import re
ash_excitation = []

X = qml.PauliX
Y = qml.PauliY
Z = qml.PauliZ
I = qml.Identity


#Hamiltonian 
symbols = ["H","H","H","H"]
r_bohr = 5.0*1.8897259886  #5.0 Angstrom in Bohr 
coordinates = np.array([[0.0,0.0, 1*r_bohr], [0.0, 0.0, 2*r_bohr], [0.0,0.0,3*r_bohr],[0.0, 0.0, 4*r_bohr]])
# Calculation of the Hamiltonian
H, qubits = qml.qchem.molecular_hamiltonian(symbols, coordinates, basis="sto-6g", method="pyscf")

print('The original hamiltonian is', H)
electrons = 4
orbitals = 8
# Calculation of the excitation operators
singles, doubles = qml.qchem.excitations(electrons, orbitals,fermionic=False)
print('Singles are',singles)
print('Doubles are',doubles)
hf_state = qchem.hf_state(electrons, qubits)
print(f"Total number of excitations = {len(singles) + len(doubles)}")

#Calculation of HF state
dev = qml.device("default.qubit", wires=qubits)
@qml.qnode(dev)
def circuit(hf_state, electrons, qubits, H):
    # Prepare the Hartree-Fock state
    print('Updated hf_state is', hf_state)  #HF state : [1,1,1,1,0,0,0,0] - [alpha, beta, alpha, beta, alpha, beta, alpha, beta]
    qml.BasisState(hf_state, wires=range(qubits))

    return qml.expval(H)   #Calculating the expectation value of the Hamiltonian
print('HF state is', circuit(hf_state, electrons, qubits, H))

print('The original hamiltonian is', H)
#Putting all the functions here
#1.1091571486954503
# Out:
# The original hamiltonian is -1.109157148695451 * I(0) + 0.041963259056657966 * Z(0) + 6.339400653739263e-05 * (Y(0) @ Z(1) @ Z(2) @ Z(3) @ Y(4)) + 6.339400653739263e-05 * (X(0) @ Z(1) @ Z(2) @ Z(3) @ X(4)) + 0.041834667283523225 * Z(2) + 0.015433496464739824 * (Z(0) @ Z(2)) + 6.344558587164859e-05 * (Y(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6)) + 6.344558587164859e-05 * (X(2) @ Z(3) @ Z(4) @ Z(5) @ X(6)) + -0.004378038402077384 * (Z(0) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6)) + -0.004378038402077384 * (Z(0) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ X(6)) + 0.041705055933323014 * Z(4) + 0.019843364998430157 * (Z(0) @ Z(4)) + 0.041576261632177564 * Z(6) + 0.022112211956184253 * (Z(0) @ Z(6)) + 0.04196325905665789 * Z(1) + 0.06277200433836075 * (Z(0) @ Z(1)) + 0.0025025640476592508 * (Y(0) @ Z(2) @ Z(3) @ Y(4)) + 0.0025025640476592508 * (X(0) @ Z(2) @ Z(3) @ X(4)) + 0.04731295041965005 * (Y(0) @ X(1) @ X(2) @ Y(3)) + -0.04731295041965005 * (Y(0) @ Y(1) @ X(2) @ X(3)) + -0.04731295041965005 * (X(0) @ X(1) @ Y(2) @ Y(3)) + 0.04731295041965005 * (X(0) @ Y(1) @ Y(2) @ X(3)) + 0.0018651202549921043 * (Y(0) @ X(1) @ X(3) @ Z(4) @ Z(5) @ Y(6)) + 0.0018651202549921043 * (Y(0) @ Y(1) @ Y(3) @ Z(4) @ Z(5) @ Y(6)) + 0.0018651202549921043 * (X(0) @ X(1) @ X(3) @ Z(4) @ Z(5) @ X(6)) + 0.0018651202549921043 * (X(0) @ Y(1) @ Y(3) @ Z(4) @ Z(5) @ X(6)) + 6.339400653739133e-05 * (Y(1) @ Z(2) @ Z(3) @ Z(4) @ Y(5)) + 0.0025025640476592508 * (Z(0) @ Y(1) @ Z(2) @ Z(3) @ Z(4) @ Y(5)) + 6.339400653739133e-05 * (X(1) @ Z(2) @ Z(3) @ Z(4) @ X(5)) + 0.0025025640476592508 * (Z(0) @ X(1) @ Z(2) @ Z(3) @ Z(4) @ X(5)) + 0.0429132872742833 * (Y(0) @ X(1) @ X(4) @ Y(5)) + -0.0429132872742833 * (Y(0) @ Y(1) @ X(4) @ X(5)) + -0.0429132872742833 * (X(0) @ X(1) @ Y(4) @ Y(5)) + 0.0429132872742833 * (X(0) @ Y(1) @ Y(4) @ X(5)) + -0.0018651202549921043 * (Y(0) @ X(1) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + 0.0018651202549921043 * (Y(0) @ Y(1) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.0018651202549921043 * (X(0) @ X(1) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + -0.0018651202549921043 * (X(0) @ Y(1) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.040691003138226434 * (Y(0) @ X(1) @ X(6) @ Y(7)) + -0.040691003138226434 * (Y(0) @ Y(1) @ X(6) @ X(7)) + -0.040691003138226434 * (X(0) @ X(1) @ Y(6) @ Y(7)) + 0.040691003138226434 * (X(0) @ Y(1) @ Y(6) @ X(7)) + 0.004440663597137371 * (Y(0) @ Z(1) @ Z(3) @ Y(4)) + 0.004440663597137371 * (X(0) @ Z(1) @ Z(3) @ X(4)) + -0.0022051310600101157 * (Y(0) @ Z(1) @ X(2) @ X(4) @ Z(5) @ Y(6)) + -0.006614711279827432 * (Y(0) @ Z(1) @ Y(2) @ Y(4) @ Z(5) @ Y(6)) + -0.004409580219817317 * (Y(0) @ Z(1) @ Y(2) @ X(4) @ Z(5) @ X(6)) + -0.004409580219817317 * (X(0) @ Z(1) @ X(2) @ Y(4) @ Z(5) @ Y(6)) + -0.006614711279827432 * (X(0) @ Z(1) @ X(2) @ X(4) @ Z(5) @ X(6)) + -0.0022051310600101157 * (X(0) @ Z(1) @ Y(2) @ Y(4) @ Z(5) @ X(6)) + 0.041834667283523155 * Z(3) + 0.06274644688438988 * (Z(0) @ Z(3)) + 0.0018952186385844784 * (Y(0) @ Z(1) @ Z(2) @ Y(4)) + 0.0018952186385844784 * (X(0) @ Z(1) @ Z(2) @ X(4)) + 0.0025454449585528924 * (Y(0) @ Y(3) @ Z(4) @ Y(5) @ Z(1) @ Y(2)) + 0.0025454449585528924 * (Y(0) @ X(3) @ Z(4) @ X(5) @ Z(1) @ Y(2)) + 0.0025454449585528924 * (X(0) @ Y(3) @ Z(4) @ Y(5) @ Z(1) @ X(2)) + 0.0025454449585528924 * (X(0) @ X(3) @ Z(4) @ X(5) @ Z(1) @ X(2)) + 0.04071780318751119 * (Y(0) @ Z(1) @ Z(2) @ X(3) @ X(5) @ Y(6)) + 0.04071780318751119 * (Y(0) @ Z(1) @ Z(2) @ Y(3) @ Y(5) @ Y(6)) + 0.04071780318751119 * (X(0) @ Z(1) @ Z(2) @ X(3) @ X(5) @ X(6)) + 0.04071780318751119 * (X(0) @ Z(1) @ Z(2) @ Y(3) @ Y(5) @ X(6)) + 6.344558587164815e-05 * (Y(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + -0.0025129181470852796 * (Z(0) @ Y(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + 6.344558587164815e-05 * (X(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + -0.0025129181470852796 * (Z(0) @ X(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + -0.042922934247521305 * (Y(0) @ X(3) @ X(4) @ Z(5) @ Z(6) @ Y(7) @ Z(1) @ Z(2)) + 0.042922934247521305 * (Y(0) @ Y(3) @ X(4) @ Z(5) @ Z(6) @ X(7) @ Z(1) @ Z(2)) + 0.042922934 ...
# Singles are [[0, 4], [0, 6], [1, 5], [1, 7], [2, 4], [2, 6], [3, 5], [3, 7]]
# Doubles are [[0, 1, 4, 5], [0, 1, 4, 7], [0, 1, 5, 6], [0, 1, 6, 7], [0, 2, 4, 6], [0, 3, 4, 5], [0, 3, 4, 7], [0, 3, 5, 6], [0, 3, 6, 7], [1, 2, 4, 5], [1, 2, 4, 7], [1, 2, 5, 6], [1, 2, 6, 7], [1, 3, 5, 7], [2, 3, 4, 5], [2, 3, 4, 7], [2, 3, 5, 6], [2, 3, 6, 7]]
# Total number of excitations = 26
# Updated hf_state is [1 1 1 1 0 0 0 0]
# HF state is -1.2160238591303292
# The original hamiltonian is -1.109157148695451 * I(0) + 0.041963259056657966 * Z(0) + 6.339400653739263e-05 * (Y(0) @ Z(1) @ Z(2) @ Z(3) @ Y(4)) + 6.339400653739263e-05 * (X(0) @ Z(1) @ Z(2) @ Z(3) @ X(4)) + 0.041834667283523225 * Z(2) + 0.015433496464739824 * (Z(0) @ Z(2)) + 6.344558587164859e-05 * (Y(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6)) + 6.344558587164859e-05 * (X(2) @ Z(3) @ Z(4) @ Z(5) @ X(6)) + -0.004378038402077384 * (Z(0) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6)) + -0.004378038402077384 * (Z(0) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ X(6)) + 0.041705055933323014 * Z(4) + 0.019843364998430157 * (Z(0) @ Z(4)) + 0.041576261632177564 * Z(6) + 0.022112211956184253 * (Z(0) @ Z(6)) + 0.04196325905665789 * Z(1) + 0.06277200433836075 * (Z(0) @ Z(1)) + 0.0025025640476592508 * (Y(0) @ Z(2) @ Z(3) @ Y(4)) + 0.0025025640476592508 * (X(0) @ Z(2) @ Z(3) @ X(4)) + 0.04731295041965005 * (Y(0) @ X(1) @ X(2) @ Y(3)) + -0.04731295041965005 * (Y(0) @ Y(1) @ X(2) @ X(3)) + -0.04731295041965005 * (X(0) @ X(1) @ Y(2) @ Y(3)) + 0.04731295041965005 * (X(0) @ Y(1) @ Y(2) @ X(3)) + 0.0018651202549921043 * (Y(0) @ X(1) @ X(3) @ Z(4) @ Z(5) @ Y(6)) + 0.0018651202549921043 * (Y(0) @ Y(1) @ Y(3) @ Z(4) @ Z(5) @ Y(6)) + 0.0018651202549921043 * (X(0) @ X(1) @ X(3) @ Z(4) @ Z(5) @ X(6)) + 0.0018651202549921043 * (X(0) @ Y(1) @ Y(3) @ Z(4) @ Z(5) @ X(6)) + 6.339400653739133e-05 * (Y(1) @ Z(2) @ Z(3) @ Z(4) @ Y(5)) + 0.0025025640476592508 * (Z(0) @ Y(1) @ Z(2) @ Z(3) @ Z(4) @ Y(5)) + 6.339400653739133e-05 * (X(1) @ Z(2) @ Z(3) @ Z(4) @ X(5)) + 0.0025025640476592508 * (Z(0) @ X(1) @ Z(2) @ Z(3) @ Z(4) @ X(5)) + 0.0429132872742833 * (Y(0) @ X(1) @ X(4) @ Y(5)) + -0.0429132872742833 * (Y(0) @ Y(1) @ X(4) @ X(5)) + -0.0429132872742833 * (X(0) @ X(1) @ Y(4) @ Y(5)) + 0.0429132872742833 * (X(0) @ Y(1) @ Y(4) @ X(5)) + -0.0018651202549921043 * (Y(0) @ X(1) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + 0.0018651202549921043 * (Y(0) @ Y(1) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.0018651202549921043 * (X(0) @ X(1) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + -0.0018651202549921043 * (X(0) @ Y(1) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.040691003138226434 * (Y(0) @ X(1) @ X(6) @ Y(7)) + -0.040691003138226434 * (Y(0) @ Y(1) @ X(6) @ X(7)) + -0.040691003138226434 * (X(0) @ X(1) @ Y(6) @ Y(7)) + 0.040691003138226434 * (X(0) @ Y(1) @ Y(6) @ X(7)) + 0.004440663597137371 * (Y(0) @ Z(1) @ Z(3) @ Y(4)) + 0.004440663597137371 * (X(0) @ Z(1) @ Z(3) @ X(4)) + -0.0022051310600101157 * (Y(0) @ Z(1) @ X(2) @ X(4) @ Z(5) @ Y(6)) + -0.006614711279827432 * (Y(0) @ Z(1) @ Y(2) @ Y(4) @ Z(5) @ Y(6)) + -0.004409580219817317 * (Y(0) @ Z(1) @ Y(2) @ X(4) @ Z(5) @ X(6)) + -0.004409580219817317 * (X(0) @ Z(1) @ X(2) @ Y(4) @ Z(5) @ Y(6)) + -0.006614711279827432 * (X(0) @ Z(1) @ X(2) @ X(4) @ Z(5) @ X(6)) + -0.0022051310600101157 * (X(0) @ Z(1) @ Y(2) @ Y(4) @ Z(5) @ X(6)) + 0.041834667283523155 * Z(3) + 0.06274644688438988 * (Z(0) @ Z(3)) + 0.0018952186385844784 * (Y(0) @ Z(1) @ Z(2) @ Y(4)) + 0.0018952186385844784 * (X(0) @ Z(1) @ Z(2) @ X(4)) + 0.0025454449585528924 * (Y(0) @ Y(3) @ Z(4) @ Y(5) @ Z(1) @ Y(2)) + 0.0025454449585528924 * (Y(0) @ X(3) @ Z(4) @ X(5) @ Z(1) @ Y(2)) + 0.0025454449585528924 * (X(0) @ Y(3) @ Z(4) @ Y(5) @ Z(1) @ X(2)) + 0.0025454449585528924 * (X(0) @ X(3) @ Z(4) @ X(5) @ Z(1) @ X(2)) + 0.04071780318751119 * (Y(0) @ Z(1) @ Z(2) @ X(3) @ X(5) @ Y(6)) + 0.04071780318751119 * (Y(0) @ Z(1) @ Z(2) @ Y(3) @ Y(5) @ Y(6)) + 0.04071780318751119 * (X(0) @ Z(1) @ Z(2) @ X(3) @ X(5) @ X(6)) + 0.04071780318751119 * (X(0) @ Z(1) @ Z(2) @ Y(3) @ Y(5) @ X(6)) + 6.344558587164815e-05 * (Y(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + -0.0025129181470852796 * (Z(0) @ Y(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + 6.344558587164815e-05 * (X(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + -0.0025129181470852796 * (Z(0) @ X(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + -0.042922934247521305 * (Y(0) @ X(3) @ X(4) @ Z(5) @ Z(6) @ Y(7) @ Z(1) @ Z(2)) + 0.042922934247521305 * (Y(0) @ Y(3) @ X(4) @ Z(5) @ Z(6) @ X(7) @ Z(1) @ Z(2)) + 0.042922934 ...

# %% [markdown]
# ## Generation of Hamiltonian from Openfermion adn conversion to Pennylane

# %%
import pennylane as qml
import openfermion
from pennylane import numpy as np
from openfermionpyscf import run_pyscf

#------------------------
symbols = ["H", "H", "H", "H"]
x = np.array([0.0000000000,  0.0000000000, 5.0,
              0.0000000000,  0.0000000000, 10.0,
              0.0000000000,  0.0000000000, 15.0,
              0.0000000000,  0.0000000000, 20.0])
mult = 1
charge = 0
basis = 'sto-6g'
#core = [0, 1, 2, 3]
active = [0,1,2,3,4, 5]
filename = './H4'
#------------------------

geometry = [[s, tuple(x[3 * i : 3 * i + 3])] for i, s in enumerate(symbols)]
#print(geometry)

molecule = openfermion.MolecularData(geometry, basis, mult, charge, filename=filename)


run_pyscf(molecule, run_scf=1, verbose=0)

molecule_ = openfermion.MolecularData(filename=filename)

ht = molecule_.get_molecular_hamiltonian()

hf = openfermion.transforms.get_fermion_operator(ht) # fermion hamiltonian

hq = openfermion.transforms.jordan_wigner(hf) # qubit hamiltonian

#hp = qml.qchem.convert_observable(hq) # PennyLane hamiltonian
hp = qml.from_openfermion(hq)

print(hp)
# Out:
# -1.1091571486962957 * I(0) + 0.04196325900768057 * Z(0) + 6.339376216732981e-05 * (Y(0) @ Z(1) @ Z(2) @ Z(3) @ Y(4)) + 6.339376216732981e-05 * (X(0) @ Z(1) @ Z(2) @ Z(3) @ X(4)) + 0.04196325900768055 * Z(1) + 6.339376216733502e-05 * (Y(1) @ Z(2) @ Z(3) @ Z(4) @ Y(5)) + 6.339376216733502e-05 * (X(1) @ Z(2) @ Z(3) @ Z(4) @ X(5)) + 0.04183466713924809 * Z(2) + 6.344573257596872e-05 * (Y(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6)) + 6.344573257596872e-05 * (X(2) @ Z(3) @ Z(4) @ Z(5) @ X(6)) + 0.04183466713924815 * Z(3) + 6.344573257597175e-05 * (Y(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + 6.344573257597175e-05 * (X(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.04170505588563083 * Z(4) + 0.041705055885630817 * Z(5) + 0.041576261873649795 * Z(6) + 0.04157626187364988 * Z(7) + 0.06277201095075927 * (Z(0) @ Z(1)) + 0.0025026292513266038 * (Y(0) @ Z(2) @ Z(3) @ Y(4)) + 0.0025026292513266038 * (X(0) @ Z(2) @ Z(3) @ X(4)) + 0.04731294382814615 * (Y(0) @ X(1) @ X(2) @ Y(3)) + -0.04731294382814615 * (Y(0) @ Y(1) @ X(2) @ X(3)) + -0.04731294382814615 * (X(0) @ X(1) @ Y(2) @ Y(3)) + 0.04731294382814615 * (X(0) @ Y(1) @ Y(2) @ X(3)) + 0.0018650580230491313 * (Y(0) @ X(1) @ X(3) @ Z(4) @ Z(5) @ Y(6)) + 0.0018650580230491313 * (Y(0) @ Y(1) @ Y(3) @ Z(4) @ Z(5) @ Y(6)) + 0.0018650580230491313 * (X(0) @ X(1) @ X(3) @ Z(4) @ Z(5) @ X(6)) + 0.0018650580230491313 * (X(0) @ Y(1) @ Y(3) @ Z(4) @ Z(5) @ X(6)) + 0.0025026292513266038 * (Z(0) @ Y(1) @ Z(2) @ Z(3) @ Z(4) @ Y(5)) + 0.0025026292513266038 * (Z(0) @ X(1) @ Z(2) @ Z(3) @ Z(4) @ X(5)) + 0.04291328674053971 * (Y(0) @ X(1) @ X(4) @ Y(5)) + -0.04291328674053971 * (Y(0) @ Y(1) @ X(4) @ X(5)) + -0.04291328674053971 * (X(0) @ X(1) @ Y(4) @ Y(5)) + 0.04291328674053971 * (X(0) @ Y(1) @ Y(4) @ X(5)) + -0.0018650580230491313 * (Y(0) @ X(1) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + 0.0018650580230491313 * (Y(0) @ Y(1) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.0018650580230491313 * (X(0) @ X(1) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + -0.0018650580230491313 * (X(0) @ Y(1) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.040691003664484665 * (Y(0) @ X(1) @ X(6) @ Y(7)) + -0.040691003664484665 * (Y(0) @ Y(1) @ X(6) @ X(7)) + -0.040691003664484665 * (X(0) @ X(1) @ Y(6) @ Y(7)) + 0.040691003664484665 * (X(0) @ Y(1) @ Y(6) @ X(7)) + 0.015433508709502372 * (Z(0) @ Z(2)) + -0.00437804143539805 * (Z(0) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6)) + -0.00437804143539805 * (Z(0) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ X(6)) + 0.004440666608455984 * (Y(0) @ Z(1) @ Z(3) @ Y(4)) + 0.004440666608455984 * (X(0) @ Z(1) @ Z(3) @ X(4)) + -0.002205130902879264 * (Y(0) @ Z(1) @ X(2) @ X(4) @ Z(5) @ Y(6)) + -0.006614710803695614 * (Y(0) @ Z(1) @ Y(2) @ Y(4) @ Z(5) @ Y(6)) + -0.004409579900816351 * (Y(0) @ Z(1) @ Y(2) @ X(4) @ Z(5) @ X(6)) + -0.004409579900816351 * (X(0) @ Z(1) @ X(2) @ Y(4) @ Z(5) @ Y(6)) + -0.006614710803695614 * (X(0) @ Z(1) @ X(2) @ X(4) @ Z(5) @ X(6)) + -0.002205130902879264 * (X(0) @ Z(1) @ Y(2) @ Y(4) @ Z(5) @ X(6)) + 0.06274645253764852 * (Z(0) @ Z(3)) + 0.001895283092591473 * (Y(0) @ Z(1) @ Z(2) @ Y(4)) + 0.001895283092591473 * (X(0) @ Z(1) @ Z(2) @ X(4)) + 0.002545383515864511 * (Y(0) @ Z(1) @ Y(2) @ Y(3) @ Z(4) @ Y(5)) + 0.002545383515864511 * (Y(0) @ Z(1) @ Y(2) @ X(3) @ Z(4) @ X(5)) + 0.002545383515864511 * (X(0) @ Z(1) @ X(2) @ Y(3) @ Z(4) @ Y(5)) + 0.002545383515864511 * (X(0) @ Z(1) @ X(2) @ X(3) @ Z(4) @ X(5)) + 0.04071780373820732 * (Y(0) @ Z(1) @ Z(2) @ X(3) @ X(5) @ Y(6)) + 0.04071780373820732 * (Y(0) @ Z(1) @ Z(2) @ Y(3) @ Y(5) @ Y(6)) + 0.04071780373820732 * (X(0) @ Z(1) @ Z(2) @ X(3) @ X(5) @ X(6)) + 0.04071780373820732 * (X(0) @ Z(1) @ Z(2) @ Y(3) @ Y(5) @ X(6)) + -0.0025129834123489196 * (Z(0) @ Y(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + -0.0025129834123489196 * (Z(0) @ X(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + -0.04292293464108659 * (Y(0) @ Z(1) @ Z(2) @ X(3) @ X(4) @ Z(5) @ Z(6) @ Y(7)) + 0.04292293464108659 * (Y(0) @ Z(1) @ Z(2) @ Y(3) @ X(4) @ Z(5) @ Z(6) @ X(7)) + 0.04292293464108659 * (X(0) @ Z(1) @ Z(2) @ X(3) @ Y(4) @ Z(5) @ Z(6) ...

# %%
#geometry = [('H', (0, 0, 0)), ('H', (0, 0, 5.0)), ('H', (0, 0, 10.0)), ('H', (0, 0, 15.0))]

#molecule = openfermion.chem.MolecularData(
#    geometry=geometry,
#    basis='sto-6g',
#    multiplicity=1,
#    charge=0,
    #description='',
#    filename='h4',
#    data_directory=None
#)

#molecule_ = openfermion.MolecularData(filename=filename)
#ht = molecule_.get_molecular_hamiltonian()

#hf = openfermion.transforms.get_fermion_operator(ht) # fermion hamiltonian

#hq = openfermion.transforms.jordan_wigner(hf) # qubit hamiltonian

#hp = qml.qchem.convert_observable(hq) # PennyLane hamiltonian
#hp = qml.from_openfermion(hq)

#print(hp)
# Out:
# -1.1091576954319777 * I(0) + 0.04176989823100373 * Z(0) + 0.04176989823100376 * Z(1) + 0.041769895302565335 * Z(2) + 0.04176989530256536 * Z(3) + 0.04176989676571248 * Z(4) + 0.04176989676571251 * Z(5) + 0.04176989676571262 * Z(6) + 0.041769896765712564 * Z(7) + 0.10388364715680193 * (Z(0) @ Z(1)) + 0.0008541674847805311 * (Y(0) @ Y(2)) + 0.0008541674847805311 * (X(0) @ X(2)) + 8.086941645375899e-08 * (Y(0) @ Z(2) @ Z(3) @ Y(4)) + 8.086941645375899e-08 * (X(0) @ Z(2) @ Z(3) @ X(4)) + 8.30898231992348e-08 * (Y(0) @ Z(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6)) + 8.30898231992348e-08 * (X(0) @ Z(2) @ Z(3) @ Z(4) @ Z(5) @ X(6)) + 0.0008541674847805311 * (Z(0) @ Y(1) @ Z(2) @ Y(3)) + 0.0008541674847805311 * (Z(0) @ X(1) @ Z(2) @ X(3)) + 0.08986598286270031 * (Y(0) @ X(1) @ X(2) @ Y(3)) + -0.08986598286270031 * (Y(0) @ Y(1) @ X(2) @ X(3)) + -0.08986598286270031 * (X(0) @ X(1) @ Y(2) @ Y(3)) + 0.08986598286270031 * (X(0) @ Y(1) @ Y(2) @ X(3)) + 8.086941645375899e-08 * (Z(0) @ Y(1) @ Z(2) @ Z(3) @ Z(4) @ Y(5)) + 8.086941645375899e-08 * (Z(0) @ X(1) @ Z(2) @ Z(3) @ Z(4) @ X(5)) + 8.30898231992348e-08 * (Z(0) @ Y(1) @ Z(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + 8.30898231992348e-08 * (Z(0) @ X(1) @ Z(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.014001427039674746 * (Z(0) @ Z(2)) + 0.10386740990237506 * (Z(0) @ Z(3)) + -0.0008541674818875224 * (Y(0) @ Z(1) @ Y(2) @ Z(3)) + -0.0008541674818875224 * (X(0) @ Z(1) @ X(2) @ Z(3)) + 8.230407947171509e-08 * (Y(0) @ Z(1) @ Z(2) @ Y(4)) + 8.230407947171509e-08 * (X(0) @ Z(1) @ Z(2) @ X(4)) + 8.164145494208284e-08 * (Y(0) @ Z(1) @ Z(2) @ Z(4) @ Z(5) @ Y(6)) + 8.164145494208284e-08 * (X(0) @ Z(1) @ Z(2) @ Z(4) @ Z(5) @ X(6)) + 8.164253085702064e-08 * (Z(0) @ Y(3) @ Z(4) @ Y(5)) + 8.164253085702064e-08 * (Z(0) @ X(3) @ Z(4) @ X(5)) + -8.230514100770968e-08 * (Z(0) @ Y(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + -8.230514100770968e-08 * (Z(0) @ X(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.01046780122773075 * (Z(0) @ Z(4)) + -0.0035001986541734788 * (Y(0) @ Z(1) @ Y(2) @ Z(4)) + -0.0035001986541734788 * (X(0) @ Z(1) @ X(2) @ Z(4)) + 0.01046780122773075 * (Z(0) @ Z(5)) + -0.0035001986541734788 * (Y(0) @ Z(1) @ Y(2) @ Z(5)) + -0.0035001986541734788 * (X(0) @ Z(1) @ X(2) @ Z(5)) + -1.56844486793723e-07 * (Y(0) @ Z(1) @ Z(2) @ Z(3) @ Y(4) @ Z(5)) + -1.56844486793723e-07 * (X(0) @ Z(1) @ Z(2) @ Z(3) @ X(4) @ Z(5)) + 0.010534339318382258 * (Z(0) @ Z(6)) + 0.0035001986486612765 * (Y(0) @ Z(1) @ Y(2) @ Z(6)) + 0.0035001986486612765 * (X(0) @ Z(1) @ X(2) @ Z(6)) + 0.010534339318382258 * (Z(0) @ Z(7)) + 0.0035001986486612765 * (Y(0) @ Z(1) @ Y(2) @ Z(7)) + 0.0035001986486612765 * (X(0) @ Z(1) @ X(2) @ Z(7)) + -1.5834238647494485e-07 * (Y(0) @ Z(1) @ Z(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6) @ Z(7)) + -1.5834238647494485e-07 * (X(0) @ Z(1) @ Z(2) @ Z(3) @ Z(4) @ Z(5) @ X(6) @ Z(7)) + 0.10386740990237506 * (Z(1) @ Z(2)) + -0.0008541674818875224 * (Y(1) @ Y(3)) + -0.0008541674818875224 * (X(1) @ X(3)) + 8.230407947171509e-08 * (Y(1) @ Z(3) @ Z(4) @ Y(5)) + 8.230407947171509e-08 * (X(1) @ Z(3) @ Z(4) @ X(5)) + 8.164145494208284e-08 * (Y(1) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + 8.164145494208284e-08 * (X(1) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 8.164253085702064e-08 * (Z(1) @ Y(2) @ Z(3) @ Y(4)) + 8.164253085702064e-08 * (Z(1) @ X(2) @ Z(3) @ X(4)) + -8.230514100770968e-08 * (Z(1) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6)) + -8.230514100770968e-08 * (Z(1) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ X(6)) + 0.014001427039674746 * (Z(1) @ Z(3)) + 0.01046780122773075 * (Z(1) @ Z(4)) + -0.0035001986541734788 * (Y(1) @ Z(2) @ Y(3) @ Z(4)) + -0.0035001986541734788 * (X(1) @ Z(2) @ X(3) @ Z(4)) + -1.56844486793723e-07 * (Y(1) @ Z(2) @ Z(3) @ Y(5)) + -1.56844486793723e-07 * (X(1) @ Z(2) @ Z(3) @ X(5)) + 0.01046780122773075 * (Z(1) @ Z(5)) + -0.0035001986541734788 * (Y(1) @ Z(2) @ Y(3) @ Z(5)) + -0.0035001986541734788 * (X(1) @ Z(2) @ X(3) @ Z(5)) + 0.010534339318382258 * (Z(1) @ Z(6)) + 0.0035001986486612765 * (Y(1) @ Z(2) @ Y(3) @ Z(6)) + 0.0035001986486612765 * (X(1) @ Z(2) @ X(3)  ...

# %%
import pennylane as qml
from pennylane import qchem
from pennylane import numpy as np
from itertools import chain
import time
import re
ash_excitation = []

X = qml.PauliX
Y = qml.PauliY
Z = qml.PauliZ
I = qml.Identity


#Hamiltonian 
symbols = ["H","H","H","H"]
r_bohr = 5.0*1.8897259886  #5.0 Angstrom in Bohr 
coordinates = np.array([[0.0,0.0, 1*r_bohr], [0.0, 0.0, 2*r_bohr], [0.0,0.0,3*r_bohr],[0.0, 0.0, 4*r_bohr]])
# Calculation of the Hamiltonian
H, qubits = qml.qchem.molecular_hamiltonian(symbols, coordinates, basis="sto-6g", method="pyscf")


electrons = 4
orbitals = 8
# Calculation of the excitation operators
singles, doubles = qml.qchem.excitations(electrons, orbitals,fermionic=False)
print('Singles are',singles)
print('Doubles are',doubles)
hf_state = qchem.hf_state(electrons, qubits)
print(f"Total number of excitations = {len(singles) + len(doubles)}")

#Calculation of HF state
dev = qml.device("default.qubit", wires=qubits)
@qml.qnode(dev)
def circuit(hf_state, electrons, qubits, hp):
    # Prepare the Hartree-Fock state
    print('Updated hf_state is', hf_state)  #HF state : [1,1,1,1,0,0,0,0] - [alpha, beta, alpha, beta, alpha, beta, alpha, beta]
    qml.BasisState(hf_state, wires=range(qubits))

    return qml.expval(hp)   #Calculating the expectation value of the Hamiltonian
print('HF state is', circuit(hf_state, electrons, qubits, hp))

print('The original hamiltonian is', hp)
#Putting all the functions here
#1.1091571486954503
# Out:
# Singles are [[0, 4], [0, 6], [1, 5], [1, 7], [2, 4], [2, 6], [3, 5], [3, 7]]
# Doubles are [[0, 1, 4, 5], [0, 1, 4, 7], [0, 1, 5, 6], [0, 1, 6, 7], [0, 2, 4, 6], [0, 3, 4, 5], [0, 3, 4, 7], [0, 3, 5, 6], [0, 3, 6, 7], [1, 2, 4, 5], [1, 2, 4, 7], [1, 2, 5, 6], [1, 2, 6, 7], [1, 3, 5, 7], [2, 3, 4, 5], [2, 3, 4, 7], [2, 3, 5, 6], [2, 3, 6, 7]]
# Total number of excitations = 26
# Updated hf_state is [1 1 1 1 0 0 0 0]
# HF state is -1.2160238507809693
# The original hamiltonian is -1.1091571486962957 * I(0) + 0.04196325900768057 * Z(0) + 6.339376216732981e-05 * (Y(0) @ Z(1) @ Z(2) @ Z(3) @ Y(4)) + 6.339376216732981e-05 * (X(0) @ Z(1) @ Z(2) @ Z(3) @ X(4)) + 0.04196325900768055 * Z(1) + 6.339376216733502e-05 * (Y(1) @ Z(2) @ Z(3) @ Z(4) @ Y(5)) + 6.339376216733502e-05 * (X(1) @ Z(2) @ Z(3) @ Z(4) @ X(5)) + 0.04183466713924809 * Z(2) + 6.344573257596872e-05 * (Y(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6)) + 6.344573257596872e-05 * (X(2) @ Z(3) @ Z(4) @ Z(5) @ X(6)) + 0.04183466713924815 * Z(3) + 6.344573257597175e-05 * (Y(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + 6.344573257597175e-05 * (X(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.04170505588563083 * Z(4) + 0.041705055885630817 * Z(5) + 0.041576261873649795 * Z(6) + 0.04157626187364988 * Z(7) + 0.06277201095075927 * (Z(0) @ Z(1)) + 0.0025026292513266038 * (Y(0) @ Z(2) @ Z(3) @ Y(4)) + 0.0025026292513266038 * (X(0) @ Z(2) @ Z(3) @ X(4)) + 0.04731294382814615 * (Y(0) @ X(1) @ X(2) @ Y(3)) + -0.04731294382814615 * (Y(0) @ Y(1) @ X(2) @ X(3)) + -0.04731294382814615 * (X(0) @ X(1) @ Y(2) @ Y(3)) + 0.04731294382814615 * (X(0) @ Y(1) @ Y(2) @ X(3)) + 0.0018650580230491313 * (Y(0) @ X(1) @ X(3) @ Z(4) @ Z(5) @ Y(6)) + 0.0018650580230491313 * (Y(0) @ Y(1) @ Y(3) @ Z(4) @ Z(5) @ Y(6)) + 0.0018650580230491313 * (X(0) @ X(1) @ X(3) @ Z(4) @ Z(5) @ X(6)) + 0.0018650580230491313 * (X(0) @ Y(1) @ Y(3) @ Z(4) @ Z(5) @ X(6)) + 0.0025026292513266038 * (Z(0) @ Y(1) @ Z(2) @ Z(3) @ Z(4) @ Y(5)) + 0.0025026292513266038 * (Z(0) @ X(1) @ Z(2) @ Z(3) @ Z(4) @ X(5)) + 0.04291328674053971 * (Y(0) @ X(1) @ X(4) @ Y(5)) + -0.04291328674053971 * (Y(0) @ Y(1) @ X(4) @ X(5)) + -0.04291328674053971 * (X(0) @ X(1) @ Y(4) @ Y(5)) + 0.04291328674053971 * (X(0) @ Y(1) @ Y(4) @ X(5)) + -0.0018650580230491313 * (Y(0) @ X(1) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + 0.0018650580230491313 * (Y(0) @ Y(1) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.0018650580230491313 * (X(0) @ X(1) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + -0.0018650580230491313 * (X(0) @ Y(1) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.040691003664484665 * (Y(0) @ X(1) @ X(6) @ Y(7)) + -0.040691003664484665 * (Y(0) @ Y(1) @ X(6) @ X(7)) + -0.040691003664484665 * (X(0) @ X(1) @ Y(6) @ Y(7)) + 0.040691003664484665 * (X(0) @ Y(1) @ Y(6) @ X(7)) + 0.015433508709502372 * (Z(0) @ Z(2)) + -0.00437804143539805 * (Z(0) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6)) + -0.00437804143539805 * (Z(0) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ X(6)) + 0.004440666608455984 * (Y(0) @ Z(1) @ Z(3) @ Y(4)) + 0.004440666608455984 * (X(0) @ Z(1) @ Z(3) @ X(4)) + -0.002205130902879264 * (Y(0) @ Z(1) @ X(2) @ X(4) @ Z(5) @ Y(6)) + -0.006614710803695614 * (Y(0) @ Z(1) @ Y(2) @ Y(4) @ Z(5) @ Y(6)) + -0.004409579900816351 * (Y(0) @ Z(1) @ Y(2) @ X(4) @ Z(5) @ X(6)) + -0.004409579900816351 * (X(0) @ Z(1) @ X(2) @ Y(4) @ Z(5) @ Y(6)) + -0.006614710803695614 * (X(0) @ Z(1) @ X(2) @ X(4) @ Z(5) @ X(6)) + -0.002205130902879264 * (X(0) @ Z(1) @ Y(2) @ Y(4) @ Z(5) @ X(6)) + 0.06274645253764852 * (Z(0) @ Z(3)) + 0.001895283092591473 * (Y(0) @ Z(1) @ Z(2) @ Y(4)) + 0.001895283092591473 * (X(0) @ Z(1) @ Z(2) @ X(4)) + 0.002545383515864511 * (Y(0) @ Z(1) @ Y(2) @ Y(3) @ Z(4) @ Y(5)) + 0.002545383515864511 * (Y(0) @ Z(1) @ Y(2) @ X(3) @ Z(4) @ X(5)) + 0.002545383515864511 * (X(0) @ Z(1) @ X(2) @ Y(3) @ Z(4) @ Y(5)) + 0.002545383515864511 * (X(0) @ Z(1) @ X(2) @ X(3) @ Z(4) @ X(5)) + 0.04071780373820732 * (Y(0) @ Z(1) @ Z(2) @ X(3) @ X(5) @ Y(6)) + 0.04071780373820732 * (Y(0) @ Z(1) @ Z(2) @ Y(3) @ Y(5) @ Y(6)) + 0.04071780373820732 * (X(0) @ Z(1) @ Z(2) @ X(3) @ X(5) @ X(6)) + 0.04071780373820732 * (X(0) @ Z(1) @ Z(2) @ Y(3) @ Y(5) @ X(6)) + -0.0025129834123489196 * (Z(0) @ Y(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + -0.0025129834123489196 * (Z(0) @ X(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + -0.04292293464108659 * (Y(0) @ Z(1) @ Z(2) @ X(3) @ X(4) @ Z(5) @ Z(6) @ Y(7)) + 0.04292293464108659 * (Y(0) @ Z(1) @ Z(2) @ Y(3) @ X(4) @ Z(5) @ Z(6) @ X(7)) + 0.04292293464108659 * (X(0) @ Z(1) @ Z(2) ...

# %%
# Commutator calculation for HF state
dev = qml.device("default.qubit", wires=qubits)
@qml.qnode(dev,diff_method='backprop')
def commutator_0(hp,w, k):  #H is the Hamiltonian, w is the operator, k is the basis state - HF state
    qml.BasisState(k, wires=range(qubits))
    res = qml.commutator(hp, w)   #Calculating the commutator
    #res = (qml.prod(H, w)) - (qml.prod(w, H))
    return qml.expval(res)

# Commutator calculation for other states except HF state
dev = qml.device("default.qubit", wires=qubits)
@qml.qnode(dev,diff_method='backprop')
def commutator_1(hp,w, k): #H is the Hamiltonian, w is the operator, k is the basis state
    qml.StatePrep(k, wires=range(qubits))
    res = qml.commutator(hp, w) #Calculating the commutator
    return qml.expval(res)

# Energy calculation 
dev = qml.device("default.qubit", wires=qubits)
@qml.qnode(dev, diff_method='backprop')
def ash(params, ash_excitation, hf_state, qubits, hp):
    #qml.BasisState(hf_state, wires=range(qubits))
    [qml.PauliX(i) for i in np.nonzero(hf_state)[0]]  #Appln of HF state
    for i, excitation in enumerate(ash_excitation):
        if len(ash_excitation[i]) == 4:
            qml.DoubleExcitation(params[i], wires = ash_excitation[i])  #Applying the double excitation and their parameters
        elif len(ash_excitation[i]) == 2:
            print('Single Exc going in is', ash_excitation[i])
            qml.SingleExcitation(params[i], wires = ash_excitation[i]) #Applying the single excitation and their parameters
            
    return qml.expval(hp)  #Calculating the expectation value of the Hamiltonian

# Calculation of New state, same as the above function but with the state return

dev = qml.device("default.qubit", wires=qubits)
@qml.qnode(dev, diff_method='backprop')
def new_state(hf_state, ash_excitation, fparams, params):
    #qml.BasisState(hf_state, wires=range(qubits))
    [qml.PauliX(i) for i in np.nonzero(hf_state)[0]] #Applying the HF state
    for i, excitations in enumerate(ash_excitation):
        if len(ash_excitation[i]) == 4:
            print('Exc. dealing right now is', ash_excitation[i])
            print('The params that are going in', params[i])
            qml.DoubleExcitation(params[i], wires = ash_excitation[i])
        elif len(ash_excitation[i]) == 2:
            print('Single Exc. dealing right now is', ash_excitation[i])
            print('Single exc params that are going in', params[i])
            qml.SingleExcitation(params[i], wires = ash_excitation[i])
            

    return qml.state()

# %%
electrons = 4
orbitals = 8
singles, doubles = qml.qchem.excitations(electrons, orbitals, fermionic=True)
optimizer = qml.GradientDescentOptimizer(stepsize=0.5)  #Optimizer

print('The Hamiltonian is ', hp)
adit = 6
fparams = []
excitations= []
operator_pool = (singles) + (doubles)  #Operator pool - Singles and Doubles
states = [hf_state]


for j in range(adit):
    print('The adapt iteration now is', j)  #Adapt iteration
    max_value = float('-inf')
    max_operator = None
    # Start with the most recent state (last state in the list)
    k = states[-1] if states else hf_state  # if states is empty, fall back to hf_state

    for i in operator_pool:
        print('The current excitation operator is', i)   #Current excitation operator - fermionic one
        w = qml.fermi.jordan_wigner(i)  #JW transformation
        if np.array_equal(k, hf_state): # If the current state is the HF state
            print('Print, if this is activated - HF state')
            current_value = abs(2*(commutator_0(hp, w, k)))      #Commutator calculation is activated  
        else:
            current_value = abs(2*(commutator_1(hp, w, k)))      #For other states, commutator calculation is activated
        print(f'The expectation value of {i} is', current_value)

        if current_value > max_value:
            max_value = current_value
            max_operator = i

    print(f"The highest operator value is {max_value} for operator {max_operator}")  #Highest operator value

    # Convert operator to excitations and append to ash_excitation
    indices_str = re.findall(r'\d+', str(max_operator))
    excitations = [int(index) for index in indices_str]
    print('Highest gradient excitation is', excitations)
    ash_excitation.append(excitations) #Appending the excitations to the ash_excitation
    print('The current status of ash_excitation is', ash_excitation)
    print('Moving towards parameters')
    params = np.zeros(len(ash_excitation), requires_grad=True)  #Parameters initialization
    print('The length of parameters is', len(params))
    
    # Cost function definition
    cost_fn = qml.QNode(ash, dev, interface="autograd", diff_method="backprop") #Cost function definition, gradient calculated automatically and method is backprop
    print('Going to do energy calculation')
    for n in range(150):
        print(f'Each step, the iteration is {n} and the parameter is {params}')
        params, energy = optimizer.step_and_cost(cost_fn, params, ash_excitation=ash_excitation, hf_state=hf_state, qubits=qubits, hp=hp)
        if n % 5 == 0:
            print(f"step = {n}, E = {energy:.8f} Ha")
    fparams.append(params)
    print('Updated params are', params)
    print('Updated excitation are', ash_excitation)
    
    # New state generation - With the updated parameters
    ostate = new_state(hf_state, ash_excitation, fparams, params)
    print(qml.draw(new_state, level="device", max_length=100)(hf_state,ash_excitation,fparams,params))
    print('The updated state is', ostate)
    # Append the new state to the states list
    states.append(ostate)
# Out:
# The Hamiltonian is  -1.1091571486962957 * I(0) + 0.04196325900768057 * Z(0) + 6.339376216732981e-05 * (Y(0) @ Z(1) @ Z(2) @ Z(3) @ Y(4)) + 6.339376216732981e-05 * (X(0) @ Z(1) @ Z(2) @ Z(3) @ X(4)) + 0.04196325900768055 * Z(1) + 6.339376216733502e-05 * (Y(1) @ Z(2) @ Z(3) @ Z(4) @ Y(5)) + 6.339376216733502e-05 * (X(1) @ Z(2) @ Z(3) @ Z(4) @ X(5)) + 0.04183466713924809 * Z(2) + 6.344573257596872e-05 * (Y(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6)) + 6.344573257596872e-05 * (X(2) @ Z(3) @ Z(4) @ Z(5) @ X(6)) + 0.04183466713924815 * Z(3) + 6.344573257597175e-05 * (Y(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + 6.344573257597175e-05 * (X(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.04170505588563083 * Z(4) + 0.041705055885630817 * Z(5) + 0.041576261873649795 * Z(6) + 0.04157626187364988 * Z(7) + 0.06277201095075927 * (Z(0) @ Z(1)) + 0.0025026292513266038 * (Y(0) @ Z(2) @ Z(3) @ Y(4)) + 0.0025026292513266038 * (X(0) @ Z(2) @ Z(3) @ X(4)) + 0.04731294382814615 * (Y(0) @ X(1) @ X(2) @ Y(3)) + -0.04731294382814615 * (Y(0) @ Y(1) @ X(2) @ X(3)) + -0.04731294382814615 * (X(0) @ X(1) @ Y(2) @ Y(3)) + 0.04731294382814615 * (X(0) @ Y(1) @ Y(2) @ X(3)) + 0.0018650580230491313 * (Y(0) @ X(1) @ X(3) @ Z(4) @ Z(5) @ Y(6)) + 0.0018650580230491313 * (Y(0) @ Y(1) @ Y(3) @ Z(4) @ Z(5) @ Y(6)) + 0.0018650580230491313 * (X(0) @ X(1) @ X(3) @ Z(4) @ Z(5) @ X(6)) + 0.0018650580230491313 * (X(0) @ Y(1) @ Y(3) @ Z(4) @ Z(5) @ X(6)) + 0.0025026292513266038 * (Z(0) @ Y(1) @ Z(2) @ Z(3) @ Z(4) @ Y(5)) + 0.0025026292513266038 * (Z(0) @ X(1) @ Z(2) @ Z(3) @ Z(4) @ X(5)) + 0.04291328674053971 * (Y(0) @ X(1) @ X(4) @ Y(5)) + -0.04291328674053971 * (Y(0) @ Y(1) @ X(4) @ X(5)) + -0.04291328674053971 * (X(0) @ X(1) @ Y(4) @ Y(5)) + 0.04291328674053971 * (X(0) @ Y(1) @ Y(4) @ X(5)) + -0.0018650580230491313 * (Y(0) @ X(1) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + 0.0018650580230491313 * (Y(0) @ Y(1) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.0018650580230491313 * (X(0) @ X(1) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + -0.0018650580230491313 * (X(0) @ Y(1) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.040691003664484665 * (Y(0) @ X(1) @ X(6) @ Y(7)) + -0.040691003664484665 * (Y(0) @ Y(1) @ X(6) @ X(7)) + -0.040691003664484665 * (X(0) @ X(1) @ Y(6) @ Y(7)) + 0.040691003664484665 * (X(0) @ Y(1) @ Y(6) @ X(7)) + 0.015433508709502372 * (Z(0) @ Z(2)) + -0.00437804143539805 * (Z(0) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6)) + -0.00437804143539805 * (Z(0) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ X(6)) + 0.004440666608455984 * (Y(0) @ Z(1) @ Z(3) @ Y(4)) + 0.004440666608455984 * (X(0) @ Z(1) @ Z(3) @ X(4)) + -0.002205130902879264 * (Y(0) @ Z(1) @ X(2) @ X(4) @ Z(5) @ Y(6)) + -0.006614710803695614 * (Y(0) @ Z(1) @ Y(2) @ Y(4) @ Z(5) @ Y(6)) + -0.004409579900816351 * (Y(0) @ Z(1) @ Y(2) @ X(4) @ Z(5) @ X(6)) + -0.004409579900816351 * (X(0) @ Z(1) @ X(2) @ Y(4) @ Z(5) @ Y(6)) + -0.006614710803695614 * (X(0) @ Z(1) @ X(2) @ X(4) @ Z(5) @ X(6)) + -0.002205130902879264 * (X(0) @ Z(1) @ Y(2) @ Y(4) @ Z(5) @ X(6)) + 0.06274645253764852 * (Z(0) @ Z(3)) + 0.001895283092591473 * (Y(0) @ Z(1) @ Z(2) @ Y(4)) + 0.001895283092591473 * (X(0) @ Z(1) @ Z(2) @ X(4)) + 0.002545383515864511 * (Y(0) @ Z(1) @ Y(2) @ Y(3) @ Z(4) @ Y(5)) + 0.002545383515864511 * (Y(0) @ Z(1) @ Y(2) @ X(3) @ Z(4) @ X(5)) + 0.002545383515864511 * (X(0) @ Z(1) @ X(2) @ Y(3) @ Z(4) @ Y(5)) + 0.002545383515864511 * (X(0) @ Z(1) @ X(2) @ X(3) @ Z(4) @ X(5)) + 0.04071780373820732 * (Y(0) @ Z(1) @ Z(2) @ X(3) @ X(5) @ Y(6)) + 0.04071780373820732 * (Y(0) @ Z(1) @ Z(2) @ Y(3) @ Y(5) @ Y(6)) + 0.04071780373820732 * (X(0) @ Z(1) @ Z(2) @ X(3) @ X(5) @ X(6)) + 0.04071780373820732 * (X(0) @ Z(1) @ Z(2) @ Y(3) @ Y(5) @ X(6)) + -0.0025129834123489196 * (Z(0) @ Y(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + -0.0025129834123489196 * (Z(0) @ X(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + -0.04292293464108659 * (Y(0) @ Z(1) @ Z(2) @ X(3) @ X(4) @ Z(5) @ Z(6) @ Y(7)) + 0.04292293464108659 * (Y(0) @ Z(1) @ Z(2) @ Y(3) @ X(4) @ Z(5) @ Z(6) @ X(7)) + 0.04292293464108659 * (X(0) @ Z(1) @ Z(2) @ X(3)  ...
# The adapt iteration now is 0
# The current excitation operator is a⁺(0) a(4)
# Print, if this is activated - HF state
# /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/autoray/autoray.py:1127: ComplexWarning: Casting complex values to real discards the imaginary part
#   return x.astype(dtype, **kwargs)
# The expectation value of a⁺(0) a(4) is 1.4703538010082257e-05
# The current excitation operator is a⁺(0) a(6)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a(6) is 0.0
# The current excitation operator is a⁺(1) a(5)
# Print, if this is activated - HF state
# The expectation value of a⁺(1) a(5) is 1.4703538010110012e-05
# The current excitation operator is a⁺(1) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(1) a(7) is 0.0
# The current excitation operator is a⁺(2) a(4)
# Print, if this is activated - HF state
# The expectation value of a⁺(2) a(4) is 0.0
# The current excitation operator is a⁺(2) a(6)
# Print, if this is activated - HF state
# The expectation value of a⁺(2) a(6) is 1.4546630969208135e-05
# The current excitation operator is a⁺(3) a(5)
# Print, if this is activated - HF state
# The expectation value of a⁺(3) a(5) is 0.0
# The current excitation operator is a⁺(3) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(3) a(7) is 1.4546630969190788e-05
# The current excitation operator is a⁺(0) a⁺(1) a(4) a(5)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(1) a(4) a(5) is 0.34330629392431766
# The current excitation operator is a⁺(0) a⁺(1) a(4) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(1) a(4) a(7) is 0.0
# The current excitation operator is a⁺(0) a⁺(1) a(5) a(6)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(1) a(5) a(6) is 0.0
# The current excitation operator is a⁺(0) a⁺(1) a(6) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(1) a(6) a(7) is 0.3255280293158773
# The current excitation operator is a⁺(0) a⁺(2) a(4) a(6)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(2) a(4) a(6) is 0.01764104722303411
# The current excitation operator is a⁺(0) a⁺(3) a(4) a(5)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(3) a(4) a(5) is 0.0
# The current excitation operator is a⁺(0) a⁺(3) a(4) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(3) a(4) a(7) is 0.3433834771286927
# The current excitation operator is a⁺(0) a⁺(3) a(5) a(6)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(3) a(5) a(6) is 0.32574242990565855
# The current excitation operator is a⁺(0) a⁺(3) a(6) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(3) a(6) a(7) is 0.0
# The current excitation operator is a⁺(1) a⁺(2) a(4) a(5)
# Print, if this is activated - HF state
# The expectation value of a⁺(1) a⁺(2) a(4) a(5) is 0.0
# The current excitation operator is a⁺(1) a⁺(2) a(4) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(1) a⁺(2) a(4) a(7) is 0.32574242990565855
# The current excitation operator is a⁺(1) a⁺(2) a(5) a(6)
# Print, if this is activated - HF state
# The expectation value of a⁺(1) a⁺(2) a(5) a(6) is 0.3433834771286927
# The current excitation operator is a⁺(1) a⁺(2) a(6) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(1) a⁺(2) a(6) a(7) is 0.0
# The current excitation operator is a⁺(1) a⁺(3) a(5) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(1) a⁺(3) a(5) a(7) is 0.01764104722303411
# The current excitation operator is a⁺(2) a⁺(3) a(4) a(5)
# Print, if this is activated - HF state
# The expectation value of a⁺(2) a⁺(3) a(4) a(5) is 0.32603509116173357
# The current excitation operator is a⁺(2) a⁺(3) a(4) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(2) a⁺(3) a(4) a(7) is 0.0
# The current excitation operator is a⁺(2) a⁺(3) a(5) a(6)
# Print, if this is activated - HF state
# The expectation value of a⁺(2) a⁺(3) a(5) a(6) is 0.0
# The current excitation operator is a⁺(2) a⁺(3) a(6) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(2) a⁺(3) a(6) a(7) is 0.3434607567407615
# The highest operator value is 0.3434607567407615 for operator a⁺(2) a⁺(3) a(6) a(7)
# Highest gradient excitation is [2, 3, 6, 7]
# The current status of ash_excitation is [[2, 3, 6, 7]]
# Moving towards parameters
# The length of parameters is 1
# Going to do energy calculation
# Each step, the iteration is 0 and the parameter is [0.]
# step = 0, E = -1.21602385 Ha
# Each step, the iteration is 1 and the parameter is [0.08586519]
# Each step, the iteration is 2 and the parameter is [0.17025665]
# Each step, the iteration is 3 and the parameter is [0.25259368]
# Each step, the iteration is 4 and the parameter is [0.33236134]
# Each step, the iteration is 5 and the parameter is [0.40912417]
# step = 5, E = -1.28211159 Ha
# Each step, the iteration is 6 and the parameter is [0.48253418]
# Each step, the iteration is 7 and the parameter is [0.55233306]
# Each step, the iteration is 8 and the parameter is [0.61834944]
# Each step, the iteration is 9 and the parameter is [0.68049215]
# Each step, the iteration is 10 and the parameter is [0.7387408]
# step = 10, E = -1.32462356 Ha
# Each step, the iteration is 11 and the parameter is [0.79313492]
# Each step, the iteration is 12 and the parameter is [0.84376273]
# Each step, the iteration is 13 and the parameter is [0.89075021]
# Each step, the iteration is 14 and the parameter is [0.93425118]
# Each step, the iteration is 15 and the parameter is [0.97443856]
# step = 15, E = -1.34627908 Ha
# Each step, the iteration is 16 and the parameter is [1.01149704]
# Each step, the iteration is 17 and the parameter is [1.04561708]
# Each step, the iteration is 18 and the parameter is [1.07699015]
# Each step, the iteration is 19 and the parameter is [1.10580511]
# Each step, the iteration is 20 and the parameter is [1.13224549]
# step = 20, E = -1.35597286 Ha
# Each step, the iteration is 21 and the parameter is [1.15648761]
# Each step, the iteration is 22 and the parameter is [1.17869931]
# Each step, the iteration is 23 and the parameter is [1.19903917]
# Each step, the iteration is 24 and the parameter is [1.21765609]
# Each step, the iteration is 25 and the parameter is [1.23468926]
# step = 25, E = -1.36005586 Ha
# Each step, the iteration is 26 and the parameter is [1.25026823]
# Each step, the iteration is 27 and the parameter is [1.26451318]
# Each step, the iteration is 28 and the parameter is [1.2775353]
# Each step, the iteration is 29 and the parameter is [1.28943725]
# Each step, the iteration is 30 and the parameter is [1.30031361]
# step = 30, E = -1.36173098 Ha
# Each step, the iteration is 31 and the parameter is [1.31025142]
# Each step, the iteration is 32 and the parameter is [1.31933063]
# Each step, the iteration is 33 and the parameter is [1.32762463]
# Each step, the iteration is 34 and the parameter is [1.33520073]
# Each step, the iteration is 35 and the parameter is [1.34212062]
# step = 35, E = -1.36241078 Ha
# Each step, the iteration is 36 and the parameter is [1.34844079]
# Each step, the iteration is 37 and the parameter is [1.35421294]
# Each step, the iteration is 38 and the parameter is [1.3594844]
# Each step, the iteration is 39 and the parameter is [1.36429844]
# Each step, the iteration is 40 and the parameter is [1.36869463]
# step = 40, E = -1.36268543 Ha
# Each step, the iteration is 41 and the parameter is [1.37270916]
# Each step, the iteration is 42 and the parameter is [1.37637508]
# Each step, the iteration is 43 and the parameter is [1.37972263]
# Each step, the iteration is 44 and the parameter is [1.38277941]
# Each step, the iteration is 45 and the parameter is [1.38557064]
# step = 45, E = -1.36279619 Ha
# Each step, the iteration is 46 and the parameter is [1.38811938]
# Each step, the iteration is 47 and the parameter is [1.39044667]
# Each step, the iteration is 48 and the parameter is [1.39257174]
# Each step, the iteration is 49 and the parameter is [1.39451216]
# Each step, the iteration is 50 and the parameter is [1.39628395]
# step = 50, E = -1.36284083 Ha
# Each step, the iteration is 51 and the parameter is [1.39790176]
# Each step, the iteration is 52 and the parameter is [1.39937898]
# Each step, the iteration is 53 and the parameter is [1.40072782]
# Each step, the iteration is 54 and the parameter is [1.40195943]
# Each step, the iteration is 55 and the parameter is [1.403084]
# step = 55, E = -1.36285881 Ha
# Each step, the iteration is 56 and the parameter is [1.40411083]
# Each step, the iteration is 57 and the parameter is [1.40504842]
# Each step, the iteration is 58 and the parameter is [1.40590451]
# Each step, the iteration is 59 and the parameter is [1.4066862]
# Each step, the iteration is 60 and the parameter is [1.40739995]
# step = 60, E = -1.36286606 Ha
# Each step, the iteration is 61 and the parameter is [1.40805165]
# Each step, the iteration is 62 and the parameter is [1.40864672]
# Each step, the iteration is 63 and the parameter is [1.40919006]
# Each step, the iteration is 64 and the parameter is [1.40968618]
# Each step, the iteration is 65 and the parameter is [1.41013918]
# step = 65, E = -1.36286898 Ha
# Each step, the iteration is 66 and the parameter is [1.4105528]
# Each step, the iteration is 67 and the parameter is [1.41093047]
# Each step, the iteration is 68 and the parameter is [1.41127531]
# Each step, the iteration is 69 and the parameter is [1.41159018]
# Each step, the iteration is 70 and the parameter is [1.41187769]
# step = 70, E = -1.36287015 Ha
# Each step, the iteration is 71 and the parameter is [1.4121402]
# Each step, the iteration is 72 and the parameter is [1.41237989]
# Each step, the iteration is 73 and the parameter is [1.41259876]
# Each step, the iteration is 74 and the parameter is [1.41279859]
# Each step, the iteration is 75 and the parameter is [1.41298106]
# step = 75, E = -1.36287063 Ha
# Each step, the iteration is 76 and the parameter is [1.41314767]
# Each step, the iteration is 77 and the parameter is [1.4132998]
# Each step, the iteration is 78 and the parameter is [1.4134387]
# Each step, the iteration is 79 and the parameter is [1.41356553]
# Each step, the iteration is 80 and the parameter is [1.41368134]
# step = 80, E = -1.36287082 Ha
# Each step, the iteration is 81 and the parameter is [1.41378708]
# Each step, the iteration is 82 and the parameter is [1.41388363]
# Each step, the iteration is 83 and the parameter is [1.41397179]
# Each step, the iteration is 84 and the parameter is [1.41405229]
# Each step, the iteration is 85 and the parameter is [1.41412578]
# step = 85, E = -1.36287089 Ha
# Each step, the iteration is 86 and the parameter is [1.41419289]
# Each step, the iteration is 87 and the parameter is [1.41425417]
# Each step, the iteration is 88 and the parameter is [1.41431012]
# Each step, the iteration is 89 and the parameter is [1.41436121]
# Each step, the iteration is 90 and the parameter is [1.41440786]
# step = 90, E = -1.36287092 Ha
# Each step, the iteration is 91 and the parameter is [1.41445045]
# Each step, the iteration is 92 and the parameter is [1.41448934]
# Each step, the iteration is 93 and the parameter is [1.41452485]
# Each step, the iteration is 94 and the parameter is [1.41455728]
# Each step, the iteration is 95 and the parameter is [1.41458688]
# step = 95, E = -1.36287094 Ha
# Each step, the iteration is 96 and the parameter is [1.41461391]
# Each step, the iteration is 97 and the parameter is [1.4146386]
# Each step, the iteration is 98 and the parameter is [1.41466113]
# Each step, the iteration is 99 and the parameter is [1.41468171]
# Each step, the iteration is 100 and the parameter is [1.4147005]
# step = 100, E = -1.36287094 Ha
# Each step, the iteration is 101 and the parameter is [1.41471766]
# Each step, the iteration is 102 and the parameter is [1.41473332]
# Each step, the iteration is 103 and the parameter is [1.41474763]
# Each step, the iteration is 104 and the parameter is [1.41476069]
# Each step, the iteration is 105 and the parameter is [1.41477261]
# step = 105, E = -1.36287094 Ha
# Each step, the iteration is 106 and the parameter is [1.4147835]
# Each step, the iteration is 107 and the parameter is [1.41479344]
# Each step, the iteration is 108 and the parameter is [1.41480252]
# Each step, the iteration is 109 and the parameter is [1.41481081]
# Each step, the iteration is 110 and the parameter is [1.41481838]
# step = 110, E = -1.36287094 Ha
# Each step, the iteration is 111 and the parameter is [1.41482529]
# Each step, the iteration is 112 and the parameter is [1.4148316]
# Each step, the iteration is 113 and the parameter is [1.41483736]
# Each step, the iteration is 114 and the parameter is [1.41484262]
# Each step, the iteration is 115 and the parameter is [1.41484742]
# step = 115, E = -1.36287094 Ha
# Each step, the iteration is 116 and the parameter is [1.41485181]
# Each step, the iteration is 117 and the parameter is [1.41485581]
# Each step, the iteration is 118 and the parameter is [1.41485947]
# Each step, the iteration is 119 and the parameter is [1.41486281]
# Each step, the iteration is 120 and the parameter is [1.41486586]
# step = 120, E = -1.36287095 Ha
# Each step, the iteration is 121 and the parameter is [1.41486864]
# Each step, the iteration is 122 and the parameter is [1.41487118]
# Each step, the iteration is 123 and the parameter is [1.4148735]
# Each step, the iteration is 124 and the parameter is [1.41487562]
# Each step, the iteration is 125 and the parameter is [1.41487756]
# step = 125, E = -1.36287095 Ha
# Each step, the iteration is 126 and the parameter is [1.41487933]
# Each step, the iteration is 127 and the parameter is [1.41488094]
# Each step, the iteration is 128 and the parameter is [1.41488241]
# Each step, the iteration is 129 and the parameter is [1.41488376]
# Each step, the iteration is 130 and the parameter is [1.41488498]
# step = 130, E = -1.36287095 Ha
# Each step, the iteration is 131 and the parameter is [1.41488611]
# Each step, the iteration is 132 and the parameter is [1.41488713]
# Each step, the iteration is 133 and the parameter is [1.41488806]
# Each step, the iteration is 134 and the parameter is [1.41488892]
# Each step, the iteration is 135 and the parameter is [1.4148897]
# step = 135, E = -1.36287095 Ha
# Each step, the iteration is 136 and the parameter is [1.41489041]
# Each step, the iteration is 137 and the parameter is [1.41489106]
# Each step, the iteration is 138 and the parameter is [1.41489165]
# Each step, the iteration is 139 and the parameter is [1.41489219]
# Each step, the iteration is 140 and the parameter is [1.41489269]
# step = 140, E = -1.36287095 Ha
# Each step, the iteration is 141 and the parameter is [1.41489314]
# Each step, the iteration is 142 and the parameter is [1.41489355]
# Each step, the iteration is 143 and the parameter is [1.41489393]
# Each step, the iteration is 144 and the parameter is [1.41489427]
# Each step, the iteration is 145 and the parameter is [1.41489459]
# step = 145, E = -1.36287095 Ha
# Each step, the iteration is 146 and the parameter is [1.41489487]
# Each step, the iteration is 147 and the parameter is [1.41489513]
# Each step, the iteration is 148 and the parameter is [1.41489537]
# Each step, the iteration is 149 and the parameter is [1.41489559]
# Updated params are [1.41489579]
# Updated excitation are [[2, 3, 6, 7]]
# Exc. dealing right now is [2, 3, 6, 7]
# The params that are going in 1.414895790949795
# Exc. dealing right now is [2, 3, 6, 7]
# The params that are going in 1.414895790949795
# 0: ──X───────────┤ ╭State
# 1: ──X───────────┤ ├State
# 2: ──X─╭G²(1.41)─┤ ├State
# 3: ──X─├G²(1.41)─┤ ├State
# 4: ────│─────────┤ ├State
# 5: ────│─────────┤ ├State
# 6: ────├G²(1.41)─┤ ├State
# 7: ────╰G²(1.41)─┤ ╰State
# The updated state is [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j -0.64989623+0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.76002295+0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
# The adapt iteration now is 1
# The current excitation operator is a⁺(0) a(4)
# The expectation value of a⁺(0) a(4) is 0.001863261389290138
# The current excitation operator is a⁺(0) a(6)
# The expectation value of a⁺(0) a(6) is 0.0
# The current excitation operator is a⁺(1) a(5)
# The expectation value of a⁺(1) a(5) is 0.0018632613892901172
# The current excitation operator is a⁺(1) a(7)
# The expectation value of a⁺(1) a(7) is 0.0
# The current excitation operator is a⁺(2) a(4)
# The expectation value of a⁺(2) a(4) is 0.0
# The current excitation operator is a⁺(2) a(6)
# The expectation value of a⁺(2) a(6) is 0.00453719394341583
# The current excitation operator is a⁺(3) a(5)
# The expectation value of a⁺(3) a(5) is 0.0
# The current excitation operator is a⁺(3) a(7)
# The expectation value of a⁺(3) a(7) is 0.00453719394341583
# The current excitation operator is a⁺(0) a⁺(1) a(4) a(5)
# The expectation value of a⁺(0) a⁺(1) a(4) a(5) is 0.34330629392431766
# The current excitation operator is a⁺(0) a⁺(1) a(4) a(7)
# The expectation value of a⁺(0) a⁺(1) a(4) a(7) is 0.0
# The current excitation operator is a⁺(0) a⁺(1) a(5) a(6)
# The expectation value of a⁺(0) a⁺(1) a(5) a(6) is 0.0
# The current excitation operator is a⁺(0) a⁺(1) a(6) a(7)
# The expectation value of a⁺(0) a⁺(1) a(6) a(7) is 0.001079797094281007
# The current excitation operator is a⁺(0) a⁺(2) a(4) a(6)
# The expectation value of a⁺(0) a⁺(2) a(4) a(6) is 0.15941939490808127
# The current excitation operator is a⁺(0) a⁺(3) a(4) a(5)
# The expectation value of a⁺(0) a⁺(3) a(4) a(5) is 0.0
# The current excitation operator is a⁺(0) a⁺(3) a(4) a(7)
# The expectation value of a⁺(0) a⁺(3) a(4) a(7) is 0.21577468033749955
# The current excitation operator is a⁺(0) a⁺(3) a(5) a(6)
# The expectation value of a⁺(0) a⁺(3) a(5) a(6) is 0.37519407524558046
# The current excitation operator is a⁺(0) a⁺(3) a(6) a(7)
# The expectation value of a⁺(0) a⁺(3) a(6) a(7) is 0.0
# The current excitation operator is a⁺(1) a⁺(2) a(4) a(5)
# The expectation value of a⁺(1) a⁺(2) a(4) a(5) is 0.0
# The current excitation operator is a⁺(1) a⁺(2) a(4) a(7)
# The expectation value of a⁺(1) a⁺(2) a(4) a(7) is 0.37519407524558046
# The current excitation operator is a⁺(1) a⁺(2) a(5) a(6)
# The expectation value of a⁺(1) a⁺(2) a(5) a(6) is 0.21577468033749966
# The current excitation operator is a⁺(1) a⁺(2) a(6) a(7)
# The expectation value of a⁺(1) a⁺(2) a(6) a(7) is 0.0
# The current excitation operator is a⁺(1) a⁺(3) a(5) a(7)
# The expectation value of a⁺(1) a⁺(3) a(5) a(7) is 0.15941939490808124
# The current excitation operator is a⁺(2) a⁺(3) a(4) a(5)
# The expectation value of a⁺(2) a⁺(3) a(4) a(5) is 0.0012179313636592574
# The current excitation operator is a⁺(2) a⁺(3) a(4) a(7)
# The expectation value of a⁺(2) a⁺(3) a(4) a(7) is 0.0
# The current excitation operator is a⁺(2) a⁺(3) a(5) a(6)
# The expectation value of a⁺(2) a⁺(3) a(5) a(6) is 0.0
# The current excitation operator is a⁺(2) a⁺(3) a(6) a(7)
# The expectation value of a⁺(2) a⁺(3) a(6) a(7) is 7.276872326408661e-07
# The highest operator value is 0.37519407524558046 for operator a⁺(0) a⁺(3) a(5) a(6)
# Highest gradient excitation is [0, 3, 5, 6]
# The current status of ash_excitation is [[2, 3, 6, 7], [0, 3, 5, 6]]
# Moving towards parameters
# The length of parameters is 2
# Going to do energy calculation
# Each step, the iteration is 0 and the parameter is [0. 0.]
# step = 0, E = -1.21602385 Ha
# Each step, the iteration is 1 and the parameter is [0.08586519 0.08143561]
# Each step, the iteration is 2 and the parameter is [0.17374226 0.16562075]
# Each step, the iteration is 3 and the parameter is [0.26225459 0.25139252]
# Each step, the iteration is 4 and the parameter is [0.3499037  0.33747961]
# Each step, the iteration is 5 and the parameter is [0.43519462 0.42260276]
# step = 5, E = -1.36320090 Ha
# Each step, the iteration is 6 and the parameter is [0.51676636 0.50557791]
# Each step, the iteration is 7 and the parameter is [0.59350093 0.58540174]
# Each step, the iteration is 8 and the parameter is [0.66459066 0.66130457]
# Each step, the iteration is 9 and the parameter is [0.7295568  0.73276615]
# Each step, the iteration is 10 and the parameter is [0.78822567 0.79949981]
# step = 10, E = -1.46736026 Ha
# Each step, the iteration is 11 and the parameter is [0.84067687 0.86141597]
# Each step, the iteration is 12 and the parameter is [0.88717944 0.91857698]
# Each step, the iteration is 13 and the parameter is [0.92812895 0.97115252]
# Each step, the iteration is 14 and the parameter is [0.96399319 1.01938104]
# Each step, the iteration is 15 and the parameter is [0.99526972 1.0635394 ]
# step = 15, E = -1.51114644 Ha
# Each step, the iteration is 16 and the parameter is [1.0224554  1.10392055]
# Each step, the iteration is 17 and the parameter is [1.04602616 1.14081839]
# Each step, the iteration is 18 and the parameter is [1.06642492 1.17451789]
# Each step, the iteration is 19 and the parameter is [1.08405534 1.20528932]
# Each step, the iteration is 20 and the parameter is [1.09927978 1.23338523]
# step = 20, E = -1.52656993 Ha
# Each step, the iteration is 21 and the parameter is [1.11241975 1.25903924]
# Each step, the iteration is 22 and the parameter is [1.12375815 1.28246605]
# Each step, the iteration is 23 and the parameter is [1.1335422  1.30386208]
# Each step, the iteration is 24 and the parameter is [1.14198691 1.32340654]
# Each step, the iteration is 25 and the parameter is [1.14927853 1.34126265]
# step = 25, E = -1.53206764 Ha
# Each step, the iteration is 26 and the parameter is [1.15557798 1.35757896]
# Each step, the iteration is 27 and the parameter is [1.16102391 1.3724906 ]
# Each step, the iteration is 28 and the parameter is [1.16573565 1.3861205 ]
# Each step, the iteration is 29 and the parameter is [1.16981575 1.39858048]
# Each step, the iteration is 30 and the parameter is [1.17335228 1.40997235]
# step = 30, E = -1.53412913 Ha
# Each step, the iteration is 31 and the parameter is [1.17642082 1.42038878]
# Each step, the iteration is 32 and the parameter is [1.17908621 1.42991422]
# Each step, the iteration is 33 and the parameter is [1.18140408 1.4386256 ]
# Each step, the iteration is 34 and the parameter is [1.18342216 1.44659308]
# Each step, the iteration is 35 and the parameter is [1.18518141 1.45388065]
# step = 35, E = -1.53493344 Ha
# Each step, the iteration is 36 and the parameter is [1.18671698 1.46054671]
# Each step, the iteration is 37 and the parameter is [1.18805907 1.46664455]
# Each step, the iteration is 38 and the parameter is [1.18923362 1.47222283]
# Each step, the iteration is 39 and the parameter is [1.19026295 1.477326  ]
# Each step, the iteration is 40 and the parameter is [1.19116623 1.48199467]
# step = 40, E = -1.53525481 Ha
# Each step, the iteration is 41 and the parameter is [1.19196001 1.48626595]
# Each step, the iteration is 42 and the parameter is [1.19265852 1.49017374]
# Each step, the iteration is 43 and the parameter is [1.19327405 1.49374904]
# Each step, the iteration is 44 and the parameter is [1.19381721 1.4970202 ]
# Each step, the iteration is 45 and the parameter is [1.19429716 1.50001311]
# step = 45, E = -1.53538492 Ha
# Each step, the iteration is 46 and the parameter is [1.19472186 1.50275149]
# Each step, the iteration is 47 and the parameter is [1.19509815 1.50525699]
# Each step, the iteration is 48 and the parameter is [1.19543201 1.50754944]
# Each step, the iteration is 49 and the parameter is [1.19572862 1.50964696]
# Each step, the iteration is 50 and the parameter is [1.19599246 1.51156615]
# step = 50, E = -1.53543796 Ha
# Each step, the iteration is 51 and the parameter is [1.19622745 1.51332216]
# Each step, the iteration is 52 and the parameter is [1.19643701 1.51492888]
# Each step, the iteration is 53 and the parameter is [1.19662411 1.516399  ]
# Each step, the iteration is 54 and the parameter is [1.19679135 1.51774413]
# Each step, the iteration is 55 and the parameter is [1.19694102 1.51897491]
# step = 55, E = -1.53545966 Ha
# Each step, the iteration is 56 and the parameter is [1.1970751  1.52010105]
# Each step, the iteration is 57 and the parameter is [1.19719535 1.52113145]
# Each step, the iteration is 58 and the parameter is [1.1973033  1.52207426]
# Each step, the iteration is 59 and the parameter is [1.19740031 1.5229369 ]
# Each step, the iteration is 60 and the parameter is [1.19748757 1.52372621]
# step = 60, E = -1.53546856 Ha
# Each step, the iteration is 61 and the parameter is [1.19756613 1.52444841]
# Each step, the iteration is 62 and the parameter is [1.19763692 1.52510921]
# Each step, the iteration is 63 and the parameter is [1.19770076 1.52571383]
# Each step, the iteration is 64 and the parameter is [1.19775838 1.52626704]
# Each step, the iteration is 65 and the parameter is [1.19781042 1.52677322]
# step = 65, E = -1.53547221 Ha
# Each step, the iteration is 66 and the parameter is [1.19785747 1.52723636]
# Each step, the iteration is 67 and the parameter is [1.19790002 1.52766012]
# Each step, the iteration is 68 and the parameter is [1.19793853 1.52804785]
# Each step, the iteration is 69 and the parameter is [1.19797341 1.52840261]
# Each step, the iteration is 70 and the parameter is [1.19800502 1.52872721]
# step = 70, E = -1.53547371 Ha
# Each step, the iteration is 71 and the parameter is [1.19803368 1.5290242 ]
# Each step, the iteration is 72 and the parameter is [1.19805968 1.52929595]
# Each step, the iteration is 73 and the parameter is [1.19808328 1.52954458]
# Each step, the iteration is 74 and the parameter is [1.19810471 1.52977207]
# Each step, the iteration is 75 and the parameter is [1.19812418 1.52998022]
# step = 75, E = -1.53547433 Ha
# Each step, the iteration is 76 and the parameter is [1.19814188 1.53017066]
# Each step, the iteration is 77 and the parameter is [1.19815796 1.53034492]
# Each step, the iteration is 78 and the parameter is [1.1981726  1.53050435]
# Each step, the iteration is 79 and the parameter is [1.19818591 1.53065022]
# Each step, the iteration is 80 and the parameter is [1.19819803 1.53078369]
# step = 80, E = -1.53547458 Ha
# Each step, the iteration is 81 and the parameter is [1.19820907 1.53090581]
# Each step, the iteration is 82 and the parameter is [1.19821912 1.53101755]
# Each step, the iteration is 83 and the parameter is [1.19822827 1.53111978]
# Each step, the iteration is 84 and the parameter is [1.19823662 1.53121331]
# Each step, the iteration is 85 and the parameter is [1.19824422 1.5312989 ]
# step = 85, E = -1.53547468 Ha
# Each step, the iteration is 86 and the parameter is [1.19825116 1.5313772 ]
# Each step, the iteration is 87 and the parameter is [1.19825748 1.53144884]
# Each step, the iteration is 88 and the parameter is [1.19826324 1.53151439]
# Each step, the iteration is 89 and the parameter is [1.1982685  1.53157437]
# Each step, the iteration is 90 and the parameter is [1.1982733  1.53162924]
# step = 90, E = -1.53547473 Ha
# Each step, the iteration is 91 and the parameter is [1.19827768 1.53167945]
# Each step, the iteration is 92 and the parameter is [1.19828168 1.53172539]
# Each step, the iteration is 93 and the parameter is [1.19828533 1.53176742]
# Each step, the iteration is 94 and the parameter is [1.19828866 1.53180588]
# Each step, the iteration is 95 and the parameter is [1.1982917  1.53184106]
# step = 95, E = -1.53547474 Ha
# Each step, the iteration is 96 and the parameter is [1.19829448 1.53187325]
# Each step, the iteration is 97 and the parameter is [1.19829702 1.53190271]
# Each step, the iteration is 98 and the parameter is [1.19829933 1.53192966]
# Each step, the iteration is 99 and the parameter is [1.19830145 1.53195431]
# Each step, the iteration is 100 and the parameter is [1.19830338 1.53197687]
# step = 100, E = -1.53547475 Ha
# Each step, the iteration is 101 and the parameter is [1.19830515 1.53199752]
# Each step, the iteration is 102 and the parameter is [1.19830677 1.5320164 ]
# Each step, the iteration is 103 and the parameter is [1.19830824 1.53203368]
# Each step, the iteration is 104 and the parameter is [1.19830959 1.53204949]
# Each step, the iteration is 105 and the parameter is [1.19831082 1.53206395]
# step = 105, E = -1.53547475 Ha
# Each step, the iteration is 106 and the parameter is [1.19831195 1.53207719]
# Each step, the iteration is 107 and the parameter is [1.19831298 1.5320893 ]
# Each step, the iteration is 108 and the parameter is [1.19831392 1.53210038]
# Each step, the iteration is 109 and the parameter is [1.19831478 1.53211051]
# Each step, the iteration is 110 and the parameter is [1.19831557 1.53211979]
# step = 110, E = -1.53547476 Ha
# Each step, the iteration is 111 and the parameter is [1.19831629 1.53212827]
# Each step, the iteration is 112 and the parameter is [1.19831694 1.53213604]
# Each step, the iteration is 113 and the parameter is [1.19831754 1.53214314]
# Each step, the iteration is 114 and the parameter is [1.19831809 1.53214964]
# Each step, the iteration is 115 and the parameter is [1.1983186  1.53215559]
# step = 115, E = -1.53547476 Ha
# Each step, the iteration is 116 and the parameter is [1.19831906 1.53216103]
# Each step, the iteration is 117 and the parameter is [1.19831948 1.532166  ]
# Each step, the iteration is 118 and the parameter is [1.19831986 1.53217056]
# Each step, the iteration is 119 and the parameter is [1.19832021 1.53217472]
# Each step, the iteration is 120 and the parameter is [1.19832053 1.53217854]
# step = 120, E = -1.53547476 Ha
# Each step, the iteration is 121 and the parameter is [1.19832083 1.53218203]
# Each step, the iteration is 122 and the parameter is [1.1983211  1.53218522]
# Each step, the iteration is 123 and the parameter is [1.19832134 1.53218814]
# Each step, the iteration is 124 and the parameter is [1.19832157 1.53219081]
# Each step, the iteration is 125 and the parameter is [1.19832177 1.53219325]
# step = 125, E = -1.53547476 Ha
# Each step, the iteration is 126 and the parameter is [1.19832196 1.53219549]
# Each step, the iteration is 127 and the parameter is [1.19832213 1.53219754]
# Each step, the iteration is 128 and the parameter is [1.19832229 1.53219941]
# Each step, the iteration is 129 and the parameter is [1.19832244 1.53220112]
# Each step, the iteration is 130 and the parameter is [1.19832257 1.53220269]
# step = 130, E = -1.53547476 Ha
# Each step, the iteration is 131 and the parameter is [1.19832269 1.53220412]
# Each step, the iteration is 132 and the parameter is [1.1983228  1.53220543]
# Each step, the iteration is 133 and the parameter is [1.1983229  1.53220664]
# Each step, the iteration is 134 and the parameter is [1.19832299 1.53220773]
# Each step, the iteration is 135 and the parameter is [1.19832308 1.53220874]
# step = 135, E = -1.53547476 Ha
# Each step, the iteration is 136 and the parameter is [1.19832315 1.53220966]
# Each step, the iteration is 137 and the parameter is [1.19832322 1.5322105 ]
# Each step, the iteration is 138 and the parameter is [1.19832329 1.53221127]
# Each step, the iteration is 139 and the parameter is [1.19832335 1.53221197]
# Each step, the iteration is 140 and the parameter is [1.1983234  1.53221262]
# step = 140, E = -1.53547476 Ha
# Each step, the iteration is 141 and the parameter is [1.19832345 1.53221321]
# Each step, the iteration is 142 and the parameter is [1.1983235  1.53221375]
# Each step, the iteration is 143 and the parameter is [1.19832354 1.53221424]
# Each step, the iteration is 144 and the parameter is [1.19832358 1.53221469]
# Each step, the iteration is 145 and the parameter is [1.19832361 1.5322151 ]
# step = 145, E = -1.53547476 Ha
# Each step, the iteration is 146 and the parameter is [1.19832364 1.53221548]
# Each step, the iteration is 147 and the parameter is [1.19832367 1.53221583]
# Each step, the iteration is 148 and the parameter is [1.1983237  1.53221614]
# Each step, the iteration is 149 and the parameter is [1.19832372 1.53221643]
# Updated params are [1.19832374 1.5322167 ]
# Updated excitation are [[2, 3, 6, 7], [0, 3, 5, 6]]
# Exc. dealing right now is [2, 3, 6, 7]
# The params that are going in 1.1983237445387396
# Exc. dealing right now is [0, 3, 5, 6]
# The params that are going in 1.5322166980832561
# Exc. dealing right now is [2, 3, 6, 7]
# The params that are going in 1.1983237445387396
# Exc. dealing right now is [0, 3, 5, 6]
# The params that are going in 1.5322166980832561
# 0: ──X───────────╭G²(1.53)─┤ ╭State
# 1: ──X───────────│─────────┤ ├State
# 2: ──X─╭G²(1.20)─│─────────┤ ├State
# 3: ──X─├G²(1.20)─├G²(1.53)─┤ ├State
# 4: ────│─────────│─────────┤ ├State
# 5: ────│─────────├G²(1.53)─┤ ├State
# 6: ────├G²(1.20)─╰G²(1.53)─┤ ├State
# 7: ────╰G²(1.20)───────────┤ ╰State
# The updated state is [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j -0.57256291+0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j -0.56395054+0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.5950895 +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
# The adapt iteration now is 2
# The current excitation operator is a⁺(0) a(4)
# The expectation value of a⁺(0) a(4) is 0.014914387365082321
# The current excitation operator is a⁺(0) a(6)
# The expectation value of a⁺(0) a(6) is 0.0
# The current excitation operator is a⁺(1) a(5)
# The expectation value of a⁺(1) a(5) is 0.008497347038635918
# The current excitation operator is a⁺(1) a(7)
# The expectation value of a⁺(1) a(7) is 0.0
# The current excitation operator is a⁺(2) a(4)
# The expectation value of a⁺(2) a(4) is 0.0
# The current excitation operator is a⁺(2) a(6)
# The expectation value of a⁺(2) a(6) is 0.005358269138115624
# The current excitation operator is a⁺(3) a(5)
# The expectation value of a⁺(3) a(5) is 0.0
# The current excitation operator is a⁺(3) a(7)
# The expectation value of a⁺(3) a(7) is 0.004729325814233985
# The current excitation operator is a⁺(0) a⁺(1) a(4) a(5)
# The expectation value of a⁺(0) a⁺(1) a(4) a(5) is 0.4649614987309325
# The current excitation operator is a⁺(0) a⁺(1) a(4) a(7)
# The expectation value of a⁺(0) a⁺(1) a(4) a(7) is 0.0
# The current excitation operator is a⁺(0) a⁺(1) a(5) a(6)
# The expectation value of a⁺(0) a⁺(1) a(5) a(6) is 0.0
# The current excitation operator is a⁺(0) a⁺(1) a(6) a(7)
# The expectation value of a⁺(0) a⁺(1) a(6) a(7) is 0.0062839870374292155
# The current excitation operator is a⁺(0) a⁺(2) a(4) a(6)
# The expectation value of a⁺(0) a⁺(2) a(4) a(6) is 0.002096086151899929
# The current excitation operator is a⁺(0) a⁺(3) a(4) a(5)
# The expectation value of a⁺(0) a⁺(3) a(4) a(5) is 0.0
# The current excitation operator is a⁺(0) a⁺(3) a(4) a(7)
# The expectation value of a⁺(0) a⁺(3) a(4) a(7) is 0.00436896251593712
# The current excitation operator is a⁺(0) a⁺(3) a(5) a(6)
# The expectation value of a⁺(0) a⁺(3) a(5) a(6) is 9.692642135832735e-07
# The current excitation operator is a⁺(0) a⁺(3) a(6) a(7)
# The expectation value of a⁺(0) a⁺(3) a(6) a(7) is 0.0
# The current excitation operator is a⁺(1) a⁺(2) a(4) a(5)
# The expectation value of a⁺(1) a⁺(2) a(4) a(5) is 0.0
# The current excitation operator is a⁺(1) a⁺(2) a(4) a(7)
# The expectation value of a⁺(1) a⁺(2) a(4) a(7) is 0.46007459577648896
# The current excitation operator is a⁺(1) a⁺(2) a(5) a(6)
# The expectation value of a⁺(1) a⁺(2) a(5) a(6) is 0.004475720426008691
# The current excitation operator is a⁺(1) a⁺(2) a(6) a(7)
# The expectation value of a⁺(1) a⁺(2) a(6) a(7) is 0.0
# The current excitation operator is a⁺(1) a⁺(3) a(5) a(7)
# The expectation value of a⁺(1) a⁺(3) a(5) a(7) is 0.001923316910503201
# The current excitation operator is a⁺(2) a⁺(3) a(4) a(5)
# The expectation value of a⁺(2) a⁺(3) a(4) a(5) is 0.006358401533648165
# The current excitation operator is a⁺(2) a⁺(3) a(4) a(7)
# The expectation value of a⁺(2) a⁺(3) a(4) a(7) is 0.0
# The current excitation operator is a⁺(2) a⁺(3) a(5) a(6)
# The expectation value of a⁺(2) a⁺(3) a(5) a(6) is 0.0
# The current excitation operator is a⁺(2) a⁺(3) a(6) a(7)
# The expectation value of a⁺(2) a⁺(3) a(6) a(7) is 5.174951467259298e-07
# The highest operator value is 0.4649614987309325 for operator a⁺(0) a⁺(1) a(4) a(5)
# Highest gradient excitation is [0, 1, 4, 5]
# The current status of ash_excitation is [[2, 3, 6, 7], [0, 3, 5, 6], [0, 1, 4, 5]]
# Moving towards parameters
# The length of parameters is 3
# Going to do energy calculation
# Each step, the iteration is 0 and the parameter is [0. 0. 0.]
# step = 0, E = -1.21602385 Ha
# Each step, the iteration is 1 and the parameter is [0.08586519 0.08143561 0.08582657]
# Each step, the iteration is 2 and the parameter is [0.17387121 0.16943567 0.17387779]
# Each step, the iteration is 3 and the parameter is [0.26300433 0.2622046  0.26335923]
# Each step, the iteration is 4 and the parameter is [0.35196127 0.35754762 0.35325148]
# ...
# The expectation value of a⁺(1) a(7) is 0.0
# The current excitation operator is a⁺(2) a(4)
# The expectation value of a⁺(2) a(4) is 2.124120848827736e-19
# The current excitation operator is a⁺(2) a(6)
# The expectation value of a⁺(2) a(6) is 0.006349419742252416
# The current excitation operator is a⁺(3) a(5)
# The expectation value of a⁺(3) a(5) is 2.5982281616481597e-19
# The current excitation operator is a⁺(3) a(7)
# The expectation value of a⁺(3) a(7) is 0.006349412616726197
# The current excitation operator is a⁺(0) a⁺(1) a(4) a(5)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 28
#      26     current_value = abs(2*(commutator_0(hp, w, k)))      #Commutator calculation is activated
#      27 else:
# ---> 28     current_value = abs(2*(commutator_1(hp, w, k)))      #For other states, commutator calculation is activated
#      29 print(f'The expectation value of {i} is', current_value)
#      31 if current_value > max_value:
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/workflow/qnode.py:987, in QNode.__call__(self, *args, **kwargs)
#     985 if qml.capture.enabled():
#     986     return qml.capture.qnode_call(self, *args, **kwargs)
# --> 987 return self._impl_call(*args, **kwargs)
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/workflow/qnode.py:977, in QNode._impl_call(self, *args, **kwargs)
#     974     self._interface = interface
#     976 try:
# --> 977     res = self._execution_component(args, kwargs)
#     978 finally:
#     979     if old_interface == "auto":
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/workflow/qnode.py:935, in QNode._execution_component(self, args, kwargs)
#     932 interface = None if self.interface == "numpy" else self.interface
#     934 # pylint: disable=unexpected-keyword-arg
# --> 935 res = qml.execute(
#     936     (self._tape,),
#     937     device=self.device,
#     938     gradient_fn=gradient_fn,
#     939     interface=interface,
#     940     transform_program=full_transform_program,
#     941     inner_transform=inner_transform_program,
#     942     config=config,
#     943     gradient_kwargs=gradient_kwargs,
#     944     **execute_kwargs,
#     945 )
#     946 res = res[0]
#     948 # convert result to the interface in case the qfunc has no parameters
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/workflow/execution.py:523, in execute(tapes, device, gradient_fn, interface, transform_program, inner_transform, config, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, device_vjp, mcm_config)
#     521 # Exiting early if we do not need to deal with an interface boundary
#     522 if no_interface_boundary_required:
# --> 523     results = inner_execute(tapes)
#     524     return post_processing(results)
#     526 if config.use_device_jacobian_product and interface in jpc_interfaces:
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/workflow/execution.py:202, in _make_inner_execute.<locals>.inner_execute(tapes, **_)
#     199 transformed_tapes, transform_post_processing = transform_program(tapes)
#     201 if transformed_tapes:
# --> 202     results = device.execute(transformed_tapes, execution_config=execution_config)
#     203 else:
#     204     results = ()
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/devices/modifiers/simulator_tracking.py:30, in _track_execute.<locals>.execute(self, circuits, execution_config)
#      28 @wraps(untracked_execute)
#      29 def execute(self, circuits, execution_config=DefaultExecutionConfig):
# ---> 30     results = untracked_execute(self, circuits, execution_config)
#      31     if isinstance(circuits, QuantumScript):
#      32         batch = (circuits,)
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/devices/modifiers/single_tape_support.py:32, in _make_execute.<locals>.execute(self, circuits, execution_config)
#      30     is_single_circuit = True
#      31     circuits = (circuits,)
# ---> 32 results = batch_execute(self, circuits, execution_config)
#      33 return results[0] if is_single_circuit else results
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/logging/decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/devices/default_qubit.py:642, in DefaultQubit.execute(self, circuits, execution_config)
#     639 prng_keys = [self.get_prng_keys()[0] for _ in range(len(circuits))]
#     641 if max_workers is None:
# --> 642     return tuple(
#     643         _simulate_wrapper(
#     644             c,
#     645             {
#     646                 "rng": self._rng,
#     647                 "debugger": self._debugger,
#     648                 "interface": interface,
#     649                 "state_cache": self._state_cache,
#     650                 "prng_key": _key,
#     651                 "mcm_method": execution_config.mcm_config.mcm_method,
#     652                 "postselect_mode": execution_config.mcm_config.postselect_mode,
#     653             },
#     654         )
#     655         for c, _key in zip(circuits, prng_keys)
#     656     )
#     658 vanilla_circuits = convert_to_numpy_parameters(circuits)[0]
#     659 seeds = self._rng.integers(2**31 - 1, size=len(vanilla_circuits))
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/devices/default_qubit.py:643, in <genexpr>(.0)
#     639 prng_keys = [self.get_prng_keys()[0] for _ in range(len(circuits))]
#     641 if max_workers is None:
#     642     return tuple(
# --> 643         _simulate_wrapper(
#     644             c,
#     645             {
#     646                 "rng": self._rng,
#     647                 "debugger": self._debugger,
#     648                 "interface": interface,
#     649                 "state_cache": self._state_cache,
#     650                 "prng_key": _key,
#     651                 "mcm_method": execution_config.mcm_config.mcm_method,
#     652                 "postselect_mode": execution_config.mcm_config.postselect_mode,
#     653             },
#     654         )
#     655         for c, _key in zip(circuits, prng_keys)
#     656     )
#     658 vanilla_circuits = convert_to_numpy_parameters(circuits)[0]
#     659 seeds = self._rng.integers(2**31 - 1, size=len(vanilla_circuits))
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/devices/default_qubit.py:908, in _simulate_wrapper(circuit, kwargs)
#     907 def _simulate_wrapper(circuit, kwargs):
# --> 908     return simulate(circuit, **kwargs)
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/logging/decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/devices/qubit/simulate.py:384, in simulate(circuit, debugger, state_cache, **execution_kwargs)
#     382 if state_cache is not None:
#     383     state_cache[circuit.hash] = state
# --> 384 return measure_final_state(
#     385     circuit, state, is_state_batched, prng_key=meas_key, **execution_kwargs
#     386 )
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/logging/decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/devices/qubit/simulate.py:272, in measure_final_state(circuit, state, is_state_batched, **execution_kwargs)
#     269         raise TypeError("Native mid-circuit measurements are only supported with finite shots.")
#     271     if len(circuit.measurements) == 1:
# --> 272         return measure(circuit.measurements[0], state, is_state_batched=is_state_batched)
#     274     return tuple(
#     275         measure(mp, state, is_state_batched=is_state_batched) for mp in circuit.measurements
#     276     )
#     278 # finite-shot case
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/devices/qubit/measure.py:252, in measure(measurementprocess, state, is_state_batched)
#     239 def measure(
#     240     measurementprocess: MeasurementProcess, state: TensorLike, is_state_batched: bool = False
#     241 ) -> TensorLike:
#     242     """Apply a measurement process to a state.
#     243
#     244     Args:
#    (...)
#     250         Tensorlike: the result of the measurement
#     251     """
# --> 252     return get_measurement_function(measurementprocess, state)(
#     253         measurementprocess, state, is_state_batched
#     254     )
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/devices/qubit/measure.py:161, in sum_of_terms_method(measurementprocess, state, is_state_batched)
#     147 """Measure the expecation value of the state when the measured observable is a ``Hamiltonian`` or ``Sum``
#     148 and it must be backpropagation compatible.
#     149
#    (...)
#     156     TensorLike: the result of the measurement
#     157 """
#     158 if isinstance(measurementprocess.obs, Sum):
#     159     # Recursively call measure on each term, so that the best measurement method can
#     160     # be used for each term
# --> 161     return sum(
#     162         measure(ExpectationMP(term), state, is_state_batched=is_state_batched)
#     163         for term in measurementprocess.obs
#     164     )
#     165 # else hamiltonian
#     166 return sum(
#     167     c * measure(ExpectationMP(t), state, is_state_batched=is_state_batched)
#     168     for c, t in zip(*measurementprocess.obs.terms())
#     169 )
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/devices/qubit/measure.py:162, in <genexpr>(.0)
#     147 """Measure the expecation value of the state when the measured observable is a ``Hamiltonian`` or ``Sum``
#     148 and it must be backpropagation compatible.
#     149
#    (...)
#     156     TensorLike: the result of the measurement
#     157 """
#     158 if isinstance(measurementprocess.obs, Sum):
#     159     # Recursively call measure on each term, so that the best measurement method can
#     160     # be used for each term
#     161     return sum(
# --> 162         measure(ExpectationMP(term), state, is_state_batched=is_state_batched)
#     163         for term in measurementprocess.obs
#     164     )
#     165 # else hamiltonian
#     166 return sum(
#     167     c * measure(ExpectationMP(t), state, is_state_batched=is_state_batched)
#     168     for c, t in zip(*measurementprocess.obs.terms())
#     169 )
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/devices/qubit/measure.py:252, in measure(measurementprocess, state, is_state_batched)
#     239 def measure(
#     240     measurementprocess: MeasurementProcess, state: TensorLike, is_state_batched: bool = False
#     241 ) -> TensorLike:
#     242     """Apply a measurement process to a state.
#     243
#     244     Args:
#    (...)
#     250         Tensorlike: the result of the measurement
#     251     """
# --> 252     return get_measurement_function(measurementprocess, state)(
#     253         measurementprocess, state, is_state_batched
#     254     )
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/devices/qubit/measure.py:68, in state_diagonalizing_gates(measurementprocess, state, is_state_batched)
#      57 """Apply a measurement to state when the measurement process has an observable with diagonalizing gates.
#      58
#      59 Args:
#    (...)
#      65     TensorLike: the result of the measurement
#      66 """
#      67 for op in measurementprocess.diagonalizing_gates():
# ---> 68     state = apply_operation(op, state, is_state_batched=is_state_batched)
#      70 total_indices = len(state.shape) - is_state_batched
#      71 wires = Wires(range(total_indices))
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/functools.py:909, in singledispatch.<locals>.wrapper(*args, **kw)
#     905 if not args:
#     906     raise TypeError(f'{funcname} requires at least '
#     907                     '1 positional argument')
# --> 909 return dispatch(args[0].__class__)(*args, **kw)
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/devices/qubit/apply_operation.py:489, in apply_S(op, state, is_state_batched, debugger, **_)
#     486 sl_1 = _get_slice(1, axis, n_dim)
#     488 state1 = math.multiply(math.cast(state[sl_1], dtype=complex), 1j)
# --> 489 return math.stack([state[sl_0], state1], axis=axis)
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/math/multi_dispatch.py:152, in multi_dispatch.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     149 interface = interface or get_interface(*dispatch_args)
#     150 kwargs["like"] = interface
# --> 152 return fn(*args, **kwargs)
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/math/multi_dispatch.py:503, in stack(values, axis, like)
#     474 """Stack a sequence of tensors along the specified axis.
#     475
#     476 .. warning::
#    (...)
#     500        [5.00e+00, 8.00e+00, 1.01e+02]], dtype=float32)>
#     501 """
#     502 values = np.coerce(values, like=like)
# --> 503 return np.stack(values, axis=axis, like=like)
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/autoray/autoray.py:81, in do(fn, like, *args, **kwargs)
#      79 backend = _choose_backend(fn, args, kwargs, like=like)
#      80 func = get_lib_fn(backend, fn)
# ---> 81 return func(*args, **kwargs)
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/numpy/wrapper.py:122, in tensor_wrapper.<locals>._wrapped(*args, **kwargs)
#     117 res = obj(*args, **kwargs)
#     119 if isinstance(res, _np.ndarray):
#     120     # only if the output of the object is a ndarray,
#     121     # then convert to a PennyLane tensor
# --> 122     res = tensor(res, **tensor_kwargs)
#     124 return res
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/numpy/tensor.py:114, in tensor.__new__(cls, input_array, requires_grad, *args, **kwargs)
#     111 obj = asarray(input_array, *args, **kwargs)
#     113 if isinstance(obj, onp.ndarray):
# --> 114     obj = obj.view(cls)
#     115     obj.requires_grad = requires_grad
#     117 return obj
#
# File /Users/cwq/CodingwithQiskit/miniconda3/envs/cwq/lib/python3.12/site-packages/pennylane/numpy/tensor.py:119, in tensor.__array_finalize__(self, obj)
#     115         obj.requires_grad = requires_grad
#     117     return obj
# --> 119 def __array_finalize__(self, obj):
#     120     # pylint: disable=attribute-defined-outside-init
#     121     if obj is None:  # pragma: no cover
#     122         return
#
# KeyboardInterrupt:
