# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane import qchem

hf_state = [1,1,1,1,0,0,0,0]
qubits = 8

dev = qml.device('default.qubit', wires=8)

@qml.qnode(dev)
def circuit(weight):
    qml.BasisState(hf_state, wires=range(qubits))
    qml.FermionicSingleExcitation(weight, wires=[2,6])
    #qml.DoubleExcitation(weight, wires=[0,1,2,3])
    #qml.SingleExcitation(weight, wires=[2,0])
    
    return qml.state()

weight = 10.0
print(circuit(weight))
print(qml.draw(circuit, level="device", max_length=1000)(weight))

# %%
-7.77775928 - (-7.777758247643)

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane import qchem

dev = qml.device('default.qubit', wires=8)
#hf_state = [1,1,1,1,0,0,0,0]
hf_state = [0,0,0,0,1,1,1,1]

@qml.qnode(dev)
def circuit(weight):
    [qml.PauliX(i) for i in np.nonzero(hf_state)[0]]
    #qml.FermionicSingleExcitation(weight, wires=[0,2])
    qml.SingleExcitation(weight, wires=[0,4])
    #qml.FermionicDoubleExcitation(weight, wires1=[0,1], wires2=[2,3])
    #qml.DoubleExcitation(weight, wires=[0,1,2,3])
    #[qml.PauliX(i) for i in np.nonzero(hf_state)[0]]
    return qml.state()

weight = 0.9
print(circuit(weight))
print(qml.draw(circuit, level="device", max_length=1000)(weight))

# %%
#-0.43496553  0.9004471 - 4th line

# %%
import numpy as np
import pennylane as qml
from scipy.optimize import minimize

import pennylane as qml

from pennylane import qchem
from pennylane import numpy as np




X = qml.PauliX
Y = qml.PauliY
Z = qml.PauliZ
I = qml.Identity

symbols = ["H","H","H","H"]
r_bohr = 3.0*1.8897259886
coordinates = np.array([[0.0,0.0, 1*r_bohr], [0.0, 0.0, 2*r_bohr], [0.0,0.0,3*r_bohr],[0.0, 0.0, 4*r_bohr]])
H, qubits = qml.qchem.molecular_hamiltonian(symbols, coordinates, basis="sto-6g", method = "openfermion")

print('The original hamiltonian is', H)
electrons = 4
orbitals = 8
qubits = 8
singles, doubles = qml.qchem.excitations(electrons, orbitals,fermionic=True)
print('Singles are',singles)
print('Doubles are',doubles)
hf_state = qchem.hf_state(electrons, qubits)
print(f"Total number of excitations = {len(singles) + len(doubles)}")



dev = qml.device("default.qubit", wires=qubits)
@qml.qnode(dev)
def circuit(hf_state, electrons, qubits, H):
    # Prepare the Hartree-Fock state
    print('Updated hf_state is', hf_state)
    qml.BasisState(hf_state, wires=range(qubits))
    

    return qml.expval(H)
print('HF state is', circuit(hf_state, electrons, qubits, H))

# Define the Ash excitation structure (as per your example)
#ash_excitation = [[2, 3, 6, 7], [0, 3, 5, 6], [0, 1, 4, 5], [1, 2, 4, 7], [0, 4], [2,6]]
#ash_excitation = [[2, 3, 6, 7], [0, 3, 5, 6], [0, 1, 4, 5], [1, 2, 4, 7], [3, 7], [0,4]]
#ash_excitation = [[2, 3, 6, 7], [0, 3, 5, 6], [0, 1, 4, 5], [1, 2, 4, 7], [1, 5]]

ash_excitation = [[2,6],[1, 2, 4, 7],[0,1,4,5],[0, 3, 5, 6],[2, 3, 6, 7]]
params = np.zeros(len(ash_excitation), requires_grad=True)

dev = qml.device("default.qubit", wires=qubits)

# QNode to evaluate energy
@qml.qnode(dev)
def circuit(params, ash_excitation, hf_state, qubits, H):
    qml.BasisState(hf_state, wires=range(qubits))
    for i, excitations in enumerate(ash_excitation):
        if len(excitations) == 4:
            qml.FermionicDoubleExcitation(weight = params[i], wires1=excitations[2:][::-1], wires2=excitations[:2][::-1])
        else:
            print(f'Single excitations coming in is {excitations} and parameters are {params[i]}')
            qml.FermionicSingleExcitation(weight= params[i], wires = ash_excitation[i])
    return qml.expval(H)


#dev = qml.device("default.qubit", wires=qubits)

# QNode to evaluate energy
#@qml.qnode(dev)
def cost_fn(params, ash_excitation, hf_state, qubits, H):
    # Compute the energy
    energy = circuit(params, ash_excitation, hf_state, qubits, H)
    
    # Compute the gradient of the energy with respect to the parameters
    #grad = qml.grad(circuit)(params, ash_excitation, hf_state, qubits, H)
    
        # Calculate gradient norm (L2 norm)
    #grad_norm = np.linalg.norm(grad)
    
    # Calculate maximum gradient
    #grad_max = np.max(np.abs(grad))
    
    # Debugging: Print the gradient information
    print(f"Energy: {energy}")
    #print(f"Gradient: {grad}")
    #print(f"Gradient Norm: {grad_norm}")
    #print(f"Maximum Gradient: {grad_max}")
    return energy



params_initial = np.zeros(len(ash_excitation))
#bounds = ([(0, 0.97)] * len(ash_excitation))

# Function to minimize
def minimize_function(params):
    energy= cost_fn(params, ash_excitation, hf_state, qubits, H)
    return energy

# Using scipy.optimize.minimize with L-BFGS-B
result = minimize(
    fun=minimize_function,   # The cost function
    x0=params_initial,       # Initial guess
    jac=True,                 # Enable gradient computation
    method='L-BFGS-B',        # Use L-BFGS-B optimizer
    #bounds=bounds,       # Use L-BFGS-B optimizer
    options={'disp': True, 'maxiter': 100, 'gtol' : 1e-12}  # Display options and max iterations
)

# Extract the result
optimized_params = result.x
minimized_energy = result.fun
Gradient = result.jac   

print(f"Optimized parameters: {optimized_params}")
print(f"Minimized energy: {minimized_energy}")

# %% [markdown]
# ## Adaptive optimizer

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane import qchem



symbols = ["H","H","H","H"]
r_bohr = 5.0*1.8897259886
coordinates = np.array([[0.0,0.0, 1*r_bohr], [0.0, 0.0, 2*r_bohr], [0.0,0.0,3*r_bohr],[0.0, 0.0, 4*r_bohr]])
H, qubits = qml.qchem.molecular_hamiltonian(symbols, coordinates, basis="sto-6g", method="pyscf")

n_electrons = 4
singles, doubles = qml.qchem.excitations(n_electrons, qubits)
singles_excitations = [qml.SingleExcitation(0.0, x) for x in singles]
doubles_excitations = [qml.DoubleExcitation(0.0, x) for x in doubles]
operator_pool = doubles_excitations + singles_excitations
print(len(operator_pool))

hf_state = qml.qchem.hf_state(n_electrons, qubits)
dev = qml.device("default.qubit", wires=qubits)
@qml.qnode(dev)
def circuit():
    qml.BasisState(hf_state, wires=range(qubits))
    return qml.expval(H)

print(circuit())

opt = qml.AdaptiveOptimizer(param_steps = 6)
for i in range(len(operator_pool)):
    circuit, energy, gradient = opt.step_and_cost(circuit, operator_pool, drain_pool=False)
    print('Energy:', energy)
    print(qml.draw(circuit, show_matrices=False)())
    print('Largest Gradient:', gradient)
    print()
    if gradient < 1e-4:
        break

# %%
import pennylane as qml
from pennylane import qchem
from pennylane import numpy as np
from itertools import chain
import time
import re
ash_excitation = []

X = qml.PauliX
Y = qml.PauliY
Z = qml.PauliZ
I = qml.Identity


#Hamiltonian 
symbols = ["H","H","H","H"]
r_bohr = 5.0*1.8897259886  #5.0 Angstrom in Bohr 
coordinates = np.array([[0.0,0.0, 1*r_bohr], [0.0, 0.0, 2*r_bohr], [0.0,0.0,3*r_bohr],[0.0, 0.0, 4*r_bohr]])
# Calculation of the Hamiltonian
H, qubits = qml.qchem.molecular_hamiltonian(symbols, coordinates, basis="sto-6g", method="pyscf")

print('The original hamiltonian is', H)
electrons = 4
orbitals = 8
# Calculation of the excitation operators
singles, doubles = qml.qchem.excitations(electrons, orbitals,fermionic=False)
print('Singles are',singles)
print('Doubles are',doubles)
hf_state = qchem.hf_state(electrons, qubits)
print(f"Total number of excitations = {len(singles) + len(doubles)}")

#Calculation of HF state
dev = qml.device("default.qubit", wires=qubits)
@qml.qnode(dev)
def circuit(hf_state, electrons, qubits, H):
    # Prepare the Hartree-Fock state
    print('Updated hf_state is', hf_state)  #HF state : [1,1,1,1,0,0,0,0] - [alpha, beta, alpha, beta, alpha, beta, alpha, beta]
    qml.BasisState(hf_state, wires=range(qubits))

    return qml.expval(H)   #Calculating the expectation value of the Hamiltonian
print('HF state is', circuit(hf_state, electrons, qubits, H))

print('The original hamiltonian is', H)
#Putting all the functions here
#1.1091571486954503

# %% [markdown]
# ## Generation of Hamiltonian from Openfermion adn conversion to Pennylane

# %%
import pennylane as qml
import openfermion
from pennylane import numpy as np
from openfermionpyscf import run_pyscf

#------------------------
symbols = ["H", "H", "H", "H"]
x = np.array([0.0000000000,  0.0000000000, 5.0,
              0.0000000000,  0.0000000000, 10.0,
              0.0000000000,  0.0000000000, 15.0,
              0.0000000000,  0.0000000000, 20.0])
mult = 1
charge = 0
basis = 'sto-6g'
#core = [0, 1, 2, 3]
active = [0,1,2,3,4, 5]
filename = './H4'
#------------------------

geometry = [[s, tuple(x[3 * i : 3 * i + 3])] for i, s in enumerate(symbols)]
#print(geometry)

molecule = openfermion.MolecularData(geometry, basis, mult, charge, filename=filename)


run_pyscf(molecule, run_scf=1, verbose=0)

molecule_ = openfermion.MolecularData(filename=filename)

ht = molecule_.get_molecular_hamiltonian()

hf = openfermion.transforms.get_fermion_operator(ht) # fermion hamiltonian

hq = openfermion.transforms.jordan_wigner(hf) # qubit hamiltonian

#hp = qml.qchem.convert_observable(hq) # PennyLane hamiltonian
hp = qml.from_openfermion(hq)

print(hp)

# %% [markdown]
# ## H4-1A

# %%
import pennylane as qml
from pennylane import qchem
from pennylane import numpy as np
from itertools import chain
import time
import re
ash_excitation = []

X = qml.PauliX
Y = qml.PauliY
Z = qml.PauliZ
I = qml.Identity


#Hamiltonian 
symbols = ["H","H","H","H"]
#symbols = ["Li", "H"]
r_bohr = 1.0*1.8897259886  #5.0 Angstrom in Bohr 
coordinates = np.array([[0.0,0.0, 1*r_bohr], [0.0, 0.0, 2*r_bohr], [0.0,0.0,3*r_bohr],[0.0, 0.0, 4*r_bohr]])
#coordinates = np.array([[0.0,0.0, 0*r_bohr], [0.0, 0.0, 1*r_bohr]])
# Calculation of the Hamiltonian
H, qubits = qml.qchem.molecular_hamiltonian(symbols, coordinates, basis="sto-6g", method="pyscf")


electrons = 4
orbitals = 8
# Calculation of the excitation operators
singles, doubles = qml.qchem.excitations(electrons, orbitals,fermionic=False)
print('Singles are',singles)
print('Doubles are',doubles)
hf_state = qchem.hf_state(electrons, qubits)
print(f"Total number of excitations = {len(singles) + len(doubles)}")

#Calculation of HF state
dev = qml.device("lightning.qubit", wires=qubits)
@qml.qnode(dev)
def circuit(hf_state, electrons, qubits, H):
    # Prepare the Hartree-Fock state
    print('Updated hf_state is', hf_state)  #HF state : [1,1,1,1,0,0,0,0] - [alpha, beta, alpha, beta, alpha, beta, alpha, beta]
    qml.BasisState(hf_state, wires=range(qubits))

    return qml.expval(H)   #Calculating the expectation value of the Hamiltonian
print('HF state is', circuit(hf_state, electrons, qubits, H))

print('The original hamiltonian is', H)
#Putting all the functions here
#1.1091571486954503
# Out:
# Singles are [[0, 4], [0, 6], [1, 5], [1, 7], [2, 4], [2, 6], [3, 5], [3, 7]]
# Doubles are [[0, 1, 4, 5], [0, 1, 4, 7], [0, 1, 5, 6], [0, 1, 6, 7], [0, 2, 4, 6], [0, 3, 4, 5], [0, 3, 4, 7], [0, 3, 5, 6], [0, 3, 6, 7], [1, 2, 4, 5], [1, 2, 4, 7], [1, 2, 5, 6], [1, 2, 6, 7], [1, 3, 5, 7], [2, 3, 4, 5], [2, 3, 4, 7], [2, 3, 5, 6], [2, 3, 6, 7]]
# Total number of excitations = 26
# Updated hf_state is [1 1 1 1 0 0 0 0]
# HF state is -2.1124607252577317
# The original hamiltonian is -0.3528372123109008 * I([0, 1, 2, 3, 4, 5, 6, 7]) + 0.18311695676742126 * Z(0) + 0.005593161752353127 * (Y(0) @ Z(1) @ Z(2) @ Z(3) @ Y(4)) + 0.005593161752353127 * (X(0) @ Z(1) @ Z(2) @ Z(3) @ X(4)) + 0.08955343029607518 * Z(2) + 0.06964291217842293 * (Z(0) @ Z(2)) + 0.0173376567184301 * (Y(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6)) + 0.0173376567184301 * (X(2) @ Z(3) @ Z(4) @ Z(5) @ X(6)) + -0.01032965410286123 * (Z(0) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6)) + -0.01032965410286123 * (Z(0) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ X(6)) + -0.0763817659244268 * Z(4) + 0.08457004538976735 * (Z(0) @ Z(4)) + -0.3301799781494755 * Z(6) + 0.10628194743355107 * (Z(0) @ Z(6)) + 0.1831169567674212 * Z(1) + 0.12416940624433223 * (Z(0) @ Z(1)) + 0.02040883856268705 * (Y(0) @ Z(2) @ Z(3) @ Y(4)) + 0.02040883856268705 * (X(0) @ Z(2) @ Z(3) @ X(4)) + 0.03941337226027998 * (Y(0) @ X(1) @ X(2) @ Y(3)) + -0.03941337226027998 * (Y(0) @ Y(1) @ X(2) @ X(3)) + -0.03941337226027998 * (X(0) @ X(1) @ Y(2) @ Y(3)) + 0.03941337226027998 * (X(0) @ Y(1) @ Y(2) @ X(3)) + -0.010755574417883123 * (Y(0) @ X(1) @ X(3) @ Z(4) @ Z(5) @ Y(6)) + -0.010755574417883123 * (Y(0) @ Y(1) @ Y(3) @ Z(4) @ Z(5) @ Y(6)) + -0.010755574417883123 * (X(0) @ X(1) @ X(3) @ Z(4) @ Z(5) @ X(6)) + -0.010755574417883123 * (X(0) @ Y(1) @ Y(3) @ Z(4) @ Z(5) @ X(6)) + 0.0055931617523531305 * (Y(1) @ Z(2) @ Z(3) @ Z(4) @ Y(5)) + 0.02040883856268705 * (Z(0) @ Y(1) @ Z(2) @ Z(3) @ Z(4) @ Y(5)) + 0.0055931617523531305 * (X(1) @ Z(2) @ Z(3) @ Z(4) @ X(5)) + 0.02040883856268705 * (Z(0) @ X(1) @ Z(2) @ Z(3) @ Z(4) @ X(5)) + 0.02701252114996286 * (Y(0) @ X(1) @ X(4) @ Y(5)) + -0.02701252114996286 * (Y(0) @ Y(1) @ X(4) @ X(5)) + -0.02701252114996286 * (X(0) @ X(1) @ Y(4) @ Y(5)) + 0.02701252114996286 * (X(0) @ Y(1) @ Y(4) @ X(5)) + 0.010755574417883123 * (Y(0) @ X(1) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + -0.010755574417883123 * (Y(0) @ Y(1) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + -0.010755574417883123 * (X(0) @ X(1) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + 0.010755574417883123 * (X(0) @ Y(1) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.024259782433430584 * (Y(0) @ X(1) @ X(6) @ Y(7)) + -0.024259782433430584 * (Y(0) @ Y(1) @ X(6) @ X(7)) + -0.024259782433430584 * (X(0) @ X(1) @ Y(6) @ Y(7)) + 0.024259782433430584 * (X(0) @ Y(1) @ Y(6) @ X(7)) + 0.022090579140630052 * (Y(0) @ Z(1) @ Z(3) @ Y(4)) + 0.022090579140630052 * (X(0) @ Z(1) @ Z(3) @ X(4)) + -0.011405685541976051 * (Y(0) @ Z(1) @ X(2) @ X(4) @ Z(5) @ Y(6)) + -0.024423929537070236 * (Y(0) @ Z(1) @ Y(2) @ Y(4) @ Z(5) @ Y(6)) + -0.013018243995094185 * (Y(0) @ Z(1) @ Y(2) @ X(4) @ Z(5) @ X(6)) + -0.013018243995094185 * (X(0) @ Z(1) @ X(2) @ Y(4) @ Z(5) @ Y(6)) + -0.024423929537070236 * (X(0) @ Z(1) @ X(2) @ X(4) @ Z(5) @ X(6)) + -0.011405685541976051 * (X(0) @ Z(1) @ Y(2) @ Y(4) @ Z(5) @ X(6)) + 0.08955343029607514 * Z(3) + 0.10905628443870291 * (Z(0) @ Z(3)) + -0.0023816204897449495 * (Y(0) @ Z(1) @ Z(2) @ Y(4)) + -0.0023816204897449495 * (X(0) @ Z(1) @ Z(2) @ X(4)) + 0.024472199630375 * (Y(0) @ Y(3) @ Z(4) @ Y(5) @ Z(1) @ Y(2)) + 0.024472199630375 * (Y(0) @ X(3) @ Z(4) @ X(5) @ Z(1) @ Y(2)) + 0.024472199630375 * (X(0) @ Y(3) @ Z(4) @ Y(5) @ Z(1) @ X(2)) + 0.024472199630375 * (X(0) @ X(3) @ Z(4) @ X(5) @ Z(1) @ X(2)) + 0.013326290728678865 * (Y(0) @ Z(1) @ Z(2) @ X(3) @ X(5) @ Y(6)) + 0.013326290728678865 * (Y(0) @ Z(1) @ Z(2) @ Y(3) @ Y(5) @ Y(6)) + 0.013326290728678865 * (X(0) @ Z(1) @ Z(2) @ X(3) @ X(5) @ X(6)) + 0.013326290728678865 * (X(0) @ Z(1) @ Z(2) @ Y(3) @ Y(5) @ X(6)) + 0.0173376567184301 * (Y(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + -0.021085228520744355 * (Z(0) @ Y(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + 0.0173376567184301 * (X(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + -0.021085228520744355 * (Z(0) @ X(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + -0.024731976270654918 * (Y(0) @ X(3) @ X(4) @ Z(5) @ Z(6) @ Y(7) @ Z(1) @ Z(2)) + 0.024731976270654918 * (Y(0) @ Y(3) @ X(4) @ Z(5) @ Z(6) @ X(7) @ Z(1) @ Z(2)) + 0.024731976270654918 * (X(0) @ X(3 ...

# %%
# Commutator calculation for HF state
dev = qml.device("lightning.qubit", wires=qubits)
@qml.qnode(dev)
def commutator_0(H,w, k):  #H is the Hamiltonian, w is the operator, k is the basis state - HF state
    qml.BasisState(k, wires=range(qubits))
    res = qml.commutator(H, w)   #Calculating the commutator
    #res = (qml.prod(H, w)) - (qml.prod(w, H))
    return qml.expval(res)

# Commutator calculation for other states except HF state
dev = qml.device("lightning.qubit", wires=qubits)
@qml.qnode(dev)
def commutator_1(H,w, k): #H is the Hamiltonian, w is the operator, k is the basis state
    qml.StatePrep(k, wires=range(qubits))
    res = qml.commutator(H, w) #Calculating the commutator
    return qml.expval(res)

# Energy calculation 
dev = qml.device("lightning.qubit", wires=qubits)
@qml.qnode(dev)
def ash(params, ash_excitation, hf_state, qubits, H):
    #qml.BasisState(hf_state, wires=range(qubits))
    [qml.PauliX(i) for i in np.nonzero(hf_state)[0]]  #Appln of HF state
    for i, excitation in enumerate(ash_excitation):
        if len(ash_excitation[i]) == 4:
            #qml.DoubleExcitation(params[i], wires = ash_excitation[i])  #Applying the double excitation and their parameters
            qml.FermionicDoubleExcitation(weight=params[i], wires1=ash_excitation[i][2:][::-1], wires2=ash_excitation[i][:2][::-1])
        elif len(ash_excitation[i]) == 2:
            print('Single Exc going in is', ash_excitation[i])
            #qml.SingleExcitation(params[i], wires = ash_excitation[i]) #Applying the single excitation and their parameters
            qml.FermionicSingleExcitation(weight=params[i], wires=list(range(ash_excitation[i][0], ash_excitation[i][1] + 1)))

    return qml.expval(H)  #Calculating the expectation value of the Hamiltonian

# Calculation of New state, same as the above function but with the state return

dev = qml.device("lightning.qubit", wires=qubits)
@qml.qnode(dev)
def new_state(hf_state, ash_excitation, fparams, params):
    #qml.BasisState(hf_state, wires=range(qubits))
    [qml.PauliX(i) for i in np.nonzero(hf_state)[0]] #Applying the HF state
    for i, excitations in enumerate(ash_excitation):
        if len(ash_excitation[i]) == 4:
            print('Exc. dealing right now is', ash_excitation[i])
            print('The params that are going in', params[i])
            #qml.DoubleExcitation(params[i], wires = ash_excitation[i])
            qml.FermionicDoubleExcitation(weight=params[i], wires1=ash_excitation[i][2:][::-1], wires2=ash_excitation[i][:2][::-1])

        elif len(ash_excitation[i]) == 2:
            print('Single Exc. dealing right now is', ash_excitation[i])
            print('Single exc params that are going in', params[i])
            #qml.SingleExcitation(params[i], wires = ash_excitation[i])
            qml.FermionicSingleExcitation(weight=params[i], wires=list(range(ash_excitation[i][0], ash_excitation[i][1] + 1)))

            

    return qml.state()

# %%
electrons = 4
orbitals = 8
singles, doubles = qml.qchem.excitations(electrons, orbitals, fermionic=True)
optimizer = qml.GradientDescentOptimizer(stepsize=0.5)  #Optimizer

print('The Hamiltonian is ', H)
adit = 18
fparams = []
excitations= []
operator_pool = (singles) + (doubles)  #Operator pool - Singles and Doubles
states = [hf_state]


for j in range(adit):
    print('The adapt iteration now is', j)  #Adapt iteration
    max_value = float('-inf')
    max_operator = None
    # Start with the most recent state (last state in the list)
    k = states[-1] if states else hf_state  # if states is empty, fall back to hf_state

    for i in operator_pool:
        print('The current excitation operator is', i)   #Current excitation operator - fermionic one
        w = qml.fermi.jordan_wigner(i)  #JW transformation
        if np.array_equal(k, hf_state): # If the current state is the HF state
            print('Print, if this is activated - HF state')
            current_value = abs(2*(commutator_0(H, w, k)))      #Commutator calculation is activated  
        else:
            current_value = abs(2*(commutator_1(H, w, k)))      #For other states, commutator calculation is activated
        print(f'The expectation value of {i} is', current_value)

        if current_value > max_value:
            max_value = current_value
            max_operator = i

    print(f"The highest operator value is {max_value} for operator {max_operator}")  #Highest operator value

    # Convert operator to excitations and append to ash_excitation
    indices_str = re.findall(r'\d+', str(max_operator))
    excitations = [int(index) for index in indices_str]
    print('Highest gradient excitation is', excitations)
    ash_excitation.append(excitations) #Appending the excitations to the ash_excitation
    print('The current status of ash_excitation is', ash_excitation)
    print('Moving towards parameters')
    params = np.zeros(len(ash_excitation), requires_grad=True)  #Parameters initialization
    print('The length of parameters is', len(params))
    
    # Cost function definition
    cost_fn = qml.QNode(ash, dev, interface="autograd", diff_method="adjoint") #Cost function definition, gradient calculated automatically and method is backprop
    print('Going to do energy calculation')
    for n in range(300):
        print(f'Each step, the iteration is {n} and the parameter is {params}')
        params, energy = optimizer.step_and_cost(cost_fn, params, ash_excitation=ash_excitation, hf_state=hf_state, qubits=qubits, H=H)
        if n % 5 == 0:
            print(f"step = {n}, E = {energy:.8f} Ha")
    fparams.append(params)
    print('Updated params are', params)
    print('Updated excitation are', ash_excitation)
    
    # New state generation - With the updated parameters
    ostate = new_state(hf_state, ash_excitation, fparams, params)
    print(qml.draw(new_state, level="device", max_length=100)(hf_state,ash_excitation,fparams,params))
    print('The updated state is', ostate)
    # Append the new state to the states list
    states.append(ostate)
# Out:
# The Hamiltonian is  -0.3528372123109008 * I([0, 1, 2, 3, 4, 5, 6, 7]) + 0.18311695676742126 * Z(0) + 0.005593161752353127 * (Y(0) @ Z(1) @ Z(2) @ Z(3) @ Y(4)) + 0.005593161752353127 * (X(0) @ Z(1) @ Z(2) @ Z(3) @ X(4)) + 0.08955343029607518 * Z(2) + 0.06964291217842293 * (Z(0) @ Z(2)) + 0.0173376567184301 * (Y(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6)) + 0.0173376567184301 * (X(2) @ Z(3) @ Z(4) @ Z(5) @ X(6)) + -0.01032965410286123 * (Z(0) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Y(6)) + -0.01032965410286123 * (Z(0) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ X(6)) + -0.0763817659244268 * Z(4) + 0.08457004538976735 * (Z(0) @ Z(4)) + -0.3301799781494755 * Z(6) + 0.10628194743355107 * (Z(0) @ Z(6)) + 0.1831169567674212 * Z(1) + 0.12416940624433223 * (Z(0) @ Z(1)) + 0.02040883856268705 * (Y(0) @ Z(2) @ Z(3) @ Y(4)) + 0.02040883856268705 * (X(0) @ Z(2) @ Z(3) @ X(4)) + 0.03941337226027998 * (Y(0) @ X(1) @ X(2) @ Y(3)) + -0.03941337226027998 * (Y(0) @ Y(1) @ X(2) @ X(3)) + -0.03941337226027998 * (X(0) @ X(1) @ Y(2) @ Y(3)) + 0.03941337226027998 * (X(0) @ Y(1) @ Y(2) @ X(3)) + -0.010755574417883123 * (Y(0) @ X(1) @ X(3) @ Z(4) @ Z(5) @ Y(6)) + -0.010755574417883123 * (Y(0) @ Y(1) @ Y(3) @ Z(4) @ Z(5) @ Y(6)) + -0.010755574417883123 * (X(0) @ X(1) @ X(3) @ Z(4) @ Z(5) @ X(6)) + -0.010755574417883123 * (X(0) @ Y(1) @ Y(3) @ Z(4) @ Z(5) @ X(6)) + 0.0055931617523531305 * (Y(1) @ Z(2) @ Z(3) @ Z(4) @ Y(5)) + 0.02040883856268705 * (Z(0) @ Y(1) @ Z(2) @ Z(3) @ Z(4) @ Y(5)) + 0.0055931617523531305 * (X(1) @ Z(2) @ Z(3) @ Z(4) @ X(5)) + 0.02040883856268705 * (Z(0) @ X(1) @ Z(2) @ Z(3) @ Z(4) @ X(5)) + 0.02701252114996286 * (Y(0) @ X(1) @ X(4) @ Y(5)) + -0.02701252114996286 * (Y(0) @ Y(1) @ X(4) @ X(5)) + -0.02701252114996286 * (X(0) @ X(1) @ Y(4) @ Y(5)) + 0.02701252114996286 * (X(0) @ Y(1) @ Y(4) @ X(5)) + 0.010755574417883123 * (Y(0) @ X(1) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + -0.010755574417883123 * (Y(0) @ Y(1) @ X(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + -0.010755574417883123 * (X(0) @ X(1) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + 0.010755574417883123 * (X(0) @ Y(1) @ Y(2) @ Z(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + 0.024259782433430584 * (Y(0) @ X(1) @ X(6) @ Y(7)) + -0.024259782433430584 * (Y(0) @ Y(1) @ X(6) @ X(7)) + -0.024259782433430584 * (X(0) @ X(1) @ Y(6) @ Y(7)) + 0.024259782433430584 * (X(0) @ Y(1) @ Y(6) @ X(7)) + 0.022090579140630052 * (Y(0) @ Z(1) @ Z(3) @ Y(4)) + 0.022090579140630052 * (X(0) @ Z(1) @ Z(3) @ X(4)) + -0.011405685541976051 * (Y(0) @ Z(1) @ X(2) @ X(4) @ Z(5) @ Y(6)) + -0.024423929537070236 * (Y(0) @ Z(1) @ Y(2) @ Y(4) @ Z(5) @ Y(6)) + -0.013018243995094185 * (Y(0) @ Z(1) @ Y(2) @ X(4) @ Z(5) @ X(6)) + -0.013018243995094185 * (X(0) @ Z(1) @ X(2) @ Y(4) @ Z(5) @ Y(6)) + -0.024423929537070236 * (X(0) @ Z(1) @ X(2) @ X(4) @ Z(5) @ X(6)) + -0.011405685541976051 * (X(0) @ Z(1) @ Y(2) @ Y(4) @ Z(5) @ X(6)) + 0.08955343029607514 * Z(3) + 0.10905628443870291 * (Z(0) @ Z(3)) + -0.0023816204897449495 * (Y(0) @ Z(1) @ Z(2) @ Y(4)) + -0.0023816204897449495 * (X(0) @ Z(1) @ Z(2) @ X(4)) + 0.024472199630375 * (Y(0) @ Y(3) @ Z(4) @ Y(5) @ Z(1) @ Y(2)) + 0.024472199630375 * (Y(0) @ X(3) @ Z(4) @ X(5) @ Z(1) @ Y(2)) + 0.024472199630375 * (X(0) @ Y(3) @ Z(4) @ Y(5) @ Z(1) @ X(2)) + 0.024472199630375 * (X(0) @ X(3) @ Z(4) @ X(5) @ Z(1) @ X(2)) + 0.013326290728678865 * (Y(0) @ Z(1) @ Z(2) @ X(3) @ X(5) @ Y(6)) + 0.013326290728678865 * (Y(0) @ Z(1) @ Z(2) @ Y(3) @ Y(5) @ Y(6)) + 0.013326290728678865 * (X(0) @ Z(1) @ Z(2) @ X(3) @ X(5) @ X(6)) + 0.013326290728678865 * (X(0) @ Z(1) @ Z(2) @ Y(3) @ Y(5) @ X(6)) + 0.0173376567184301 * (Y(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + -0.021085228520744355 * (Z(0) @ Y(3) @ Z(4) @ Z(5) @ Z(6) @ Y(7)) + 0.0173376567184301 * (X(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + -0.021085228520744355 * (Z(0) @ X(3) @ Z(4) @ Z(5) @ Z(6) @ X(7)) + -0.024731976270654918 * (Y(0) @ X(3) @ X(4) @ Z(5) @ Z(6) @ Y(7) @ Z(1) @ Z(2)) + 0.024731976270654918 * (Y(0) @ Y(3) @ X(4) @ Z(5) @ Z(6) @ X(7) @ Z(1) @ Z(2)) + 0.024731976270654918 * (X(0) @ X(3) @ Y(4) ...
# The adapt iteration now is 0
# The current excitation operator is a⁺(0) a(4)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a(4) is 5.508703141698934e-07
# The current excitation operator is a⁺(0) a(6)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a(6) is 0.0
# The current excitation operator is a⁺(1) a(5)
# Print, if this is activated - HF state
# The expectation value of a⁺(1) a(5) is 5.508703141698934e-07
# The current excitation operator is a⁺(1) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(1) a(7) is 0.0
# The current excitation operator is a⁺(2) a(4)
# Print, if this is activated - HF state
# The expectation value of a⁺(2) a(4) is 0.0
# The current excitation operator is a⁺(2) a(6)
# Print, if this is activated - HF state
# The expectation value of a⁺(2) a(6) is 4.7570890500392427e-07
# The current excitation operator is a⁺(3) a(5)
# Print, if this is activated - HF state
# The expectation value of a⁺(3) a(5) is 0.0
# The current excitation operator is a⁺(3) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(3) a(7) is 4.7570890503167984e-07
# The current excitation operator is a⁺(0) a⁺(1) a(4) a(5)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(1) a(4) a(5) is 0.21610016919970287
# The current excitation operator is a⁺(0) a⁺(1) a(4) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(1) a(4) a(7) is 0.0
# The current excitation operator is a⁺(0) a⁺(1) a(5) a(6)
# Print, if this is activated - HF state
# /Users/s.poyyapakkam/miniconda3/envs/sri/lib/python3.12/site-packages/pennylane_lightning/core/_serialize.py:353: ComplexWarning: Casting complex values to real discards the imaginary part
#   coeffs = np.array(coeffs).astype(self.rtype)
# The expectation value of a⁺(0) a⁺(1) a(5) a(6) is 0.0
# The current excitation operator is a⁺(0) a⁺(1) a(6) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(1) a(6) a(7) is 0.19407825946744464
# The current excitation operator is a⁺(0) a⁺(2) a(4) a(6)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(2) a(4) a(6) is 0.0912454843358084
# The current excitation operator is a⁺(0) a⁺(3) a(4) a(5)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(3) a(4) a(5) is 0.0
# The current excitation operator is a⁺(0) a⁺(3) a(4) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(3) a(4) a(7) is 0.19785581016523934
# The current excitation operator is a⁺(0) a⁺(3) a(5) a(6)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(3) a(5) a(6) is 0.10661032582943089
# The current excitation operator is a⁺(0) a⁺(3) a(6) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(0) a⁺(3) a(6) a(7) is 0.0
# The current excitation operator is a⁺(1) a⁺(2) a(4) a(5)
# Print, if this is activated - HF state
# The expectation value of a⁺(1) a⁺(2) a(4) a(5) is 0.0
# The current excitation operator is a⁺(1) a⁺(2) a(4) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(1) a⁺(2) a(4) a(7) is 0.10661032582943089
# The current excitation operator is a⁺(1) a⁺(2) a(5) a(6)
# Print, if this is activated - HF state
# The expectation value of a⁺(1) a⁺(2) a(5) a(6) is 0.19785581016523934
# The current excitation operator is a⁺(1) a⁺(2) a(6) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(1) a⁺(2) a(6) a(7) is 0.0
# The current excitation operator is a⁺(1) a⁺(3) a(5) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(1) a⁺(3) a(5) a(7) is 0.0912454843358084
# The current excitation operator is a⁺(2) a⁺(3) a(4) a(5)
# Print, if this is activated - HF state
# The expectation value of a⁺(2) a⁺(3) a(4) a(5) is 0.2747270984185733
# The current excitation operator is a⁺(2) a⁺(3) a(4) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(2) a⁺(3) a(4) a(7) is 0.0
# The current excitation operator is a⁺(2) a⁺(3) a(5) a(6)
# Print, if this is activated - HF state
# The expectation value of a⁺(2) a⁺(3) a(5) a(6) is 0.0
# The current excitation operator is a⁺(2) a⁺(3) a(6) a(7)
# Print, if this is activated - HF state
# The expectation value of a⁺(2) a⁺(3) a(6) a(7) is 0.21021064723751892
# The highest operator value is 0.2747270984185733 for operator a⁺(2) a⁺(3) a(4) a(5)
# Highest gradient excitation is [2, 3, 4, 5]
# The current status of ash_excitation is [[2, 3, 4, 5]]
# Moving towards parameters
# The length of parameters is 1
# Going to do energy calculation
# Each step, the iteration is 0 and the parameter is [0.]
# step = 0, E = -2.11246073 Ha
# Each step, the iteration is 1 and the parameter is [-0.06868177]
# Each step, the iteration is 2 and the parameter is [-0.124185]
# Each step, the iteration is 3 and the parameter is [-0.16884419]
# Each step, the iteration is 4 and the parameter is [-0.20467658]
# Each step, the iteration is 5 and the parameter is [-0.23337425]
# step = 5, E = -2.13394435 Ha
# Each step, the iteration is 6 and the parameter is [-0.25633081]
# Each step, the iteration is 7 and the parameter is [-0.27468097]
# Each step, the iteration is 8 and the parameter is [-0.28934196]
# Each step, the iteration is 9 and the parameter is [-0.30105185]
# Each step, the iteration is 10 and the parameter is [-0.31040283]
# step = 10, E = -2.13628894 Ha
# Each step, the iteration is 11 and the parameter is [-0.31786916]
# Each step, the iteration is 12 and the parameter is [-0.3238302]
# Each step, the iteration is 13 and the parameter is [-0.32858919]
# Each step, the iteration is 14 and the parameter is [-0.33238841]
# Each step, the iteration is 15 and the parameter is [-0.33542135]
# step = 15, E = -2.13653632 Ha
# Each step, the iteration is 16 and the parameter is [-0.33784253]
# Each step, the iteration is 17 and the parameter is [-0.33977534]
# Each step, the iteration is 18 and the parameter is [-0.34131827]
# Each step, the iteration is 19 and the parameter is [-0.34254997]
# Each step, the iteration is 20 and the parameter is [-0.34353321]
# step = 20, E = -2.13656233 Ha
# Each step, the iteration is 21 and the parameter is [-0.34431811]
# Each step, the iteration is 22 and the parameter is [-0.34494468]
# Each step, the iteration is 23 and the parameter is [-0.34544485]
# Each step, the iteration is 24 and the parameter is [-0.34584413]
# Each step, the iteration is 25 and the parameter is [-0.34616287]
# step = 25, E = -2.13656506 Ha
# Each step, the iteration is 26 and the parameter is [-0.34641731]
# Each step, the iteration is 27 and the parameter is [-0.34662042]
# Each step, the iteration is 28 and the parameter is [-0.34678256]
# Each step, the iteration is 29 and the parameter is [-0.346912]
# Each step, the iteration is 30 and the parameter is [-0.34701532]
# step = 30, E = -2.13656535 Ha
# Each step, the iteration is 31 and the parameter is [-0.3470978]
# Each step, the iteration is 32 and the parameter is [-0.34716365]
# Each step, the iteration is 33 and the parameter is [-0.34721621]
# Each step, the iteration is 34 and the parameter is [-0.34725817]
# Each step, the iteration is 35 and the parameter is [-0.34729166]
# step = 35, E = -2.13656538 Ha
# Each step, the iteration is 36 and the parameter is [-0.3473184]
# Each step, the iteration is 37 and the parameter is [-0.34733974]
# Each step, the iteration is 38 and the parameter is [-0.34735678]
# Each step, the iteration is 39 and the parameter is [-0.34737038]
# Each step, the iteration is 40 and the parameter is [-0.34738124]
# step = 40, E = -2.13656539 Ha
# Each step, the iteration is 41 and the parameter is [-0.34738991]
# Each step, the iteration is 42 and the parameter is [-0.34739683]
# Each step, the iteration is 43 and the parameter is [-0.34740235]
# Each step, the iteration is 44 and the parameter is [-0.34740676]
# Each step, the iteration is 45 and the parameter is [-0.34741028]
# step = 45, E = -2.13656539 Ha
# Each step, the iteration is 46 and the parameter is [-0.34741309]
# Each step, the iteration is 47 and the parameter is [-0.34741533]
# Each step, the iteration is 48 and the parameter is [-0.34741712]
# Each step, the iteration is 49 and the parameter is [-0.34741855]
# Each step, the iteration is 50 and the parameter is [-0.34741969]
# step = 50, E = -2.13656539 Ha
# Each step, the iteration is 51 and the parameter is [-0.3474206]
# Each step, the iteration is 52 and the parameter is [-0.34742133]
# Each step, the iteration is 53 and the parameter is [-0.34742191]
# Each step, the iteration is 54 and the parameter is [-0.34742238]
# Each step, the iteration is 55 and the parameter is [-0.34742275]
# step = 55, E = -2.13656539 Ha
# Each step, the iteration is 56 and the parameter is [-0.34742304]
# Each step, the iteration is 57 and the parameter is [-0.34742328]
# Each step, the iteration is 58 and the parameter is [-0.34742346]
# Each step, the iteration is 59 and the parameter is [-0.34742361]
# Each step, the iteration is 60 and the parameter is [-0.34742373]
# step = 60, E = -2.13656539 Ha
# Each step, the iteration is 61 and the parameter is [-0.34742383]
# Each step, the iteration is 62 and the parameter is [-0.34742391]
# Each step, the iteration is 63 and the parameter is [-0.34742397]
# Each step, the iteration is 64 and the parameter is [-0.34742402]
# Each step, the iteration is 65 and the parameter is [-0.34742406]
# step = 65, E = -2.13656539 Ha
# Each step, the iteration is 66 and the parameter is [-0.34742409]
# Each step, the iteration is 67 and the parameter is [-0.34742411]
# Each step, the iteration is 68 and the parameter is [-0.34742413]
# Each step, the iteration is 69 and the parameter is [-0.34742415]
# Each step, the iteration is 70 and the parameter is [-0.34742416]
# step = 70, E = -2.13656539 Ha
# Each step, the iteration is 71 and the parameter is [-0.34742417]
# Each step, the iteration is 72 and the parameter is [-0.34742418]
# Each step, the iteration is 73 and the parameter is [-0.34742418]
# Each step, the iteration is 74 and the parameter is [-0.34742419]
# Each step, the iteration is 75 and the parameter is [-0.34742419]
# step = 75, E = -2.13656539 Ha
# Each step, the iteration is 76 and the parameter is [-0.3474242]
# Each step, the iteration is 77 and the parameter is [-0.3474242]
# Each step, the iteration is 78 and the parameter is [-0.3474242]
# Each step, the iteration is 79 and the parameter is [-0.3474242]
# Each step, the iteration is 80 and the parameter is [-0.3474242]
# step = 80, E = -2.13656539 Ha
# Each step, the iteration is 81 and the parameter is [-0.3474242]
# Each step, the iteration is 82 and the parameter is [-0.34742421]
# Each step, the iteration is 83 and the parameter is [-0.34742421]
# Each step, the iteration is 84 and the parameter is [-0.34742421]
# Each step, the iteration is 85 and the parameter is [-0.34742421]
# step = 85, E = -2.13656539 Ha
# Each step, the iteration is 86 and the parameter is [-0.34742421]
# Each step, the iteration is 87 and the parameter is [-0.34742421]
# Each step, the iteration is 88 and the parameter is [-0.34742421]
# Each step, the iteration is 89 and the parameter is [-0.34742421]
# Each step, the iteration is 90 and the parameter is [-0.34742421]
# step = 90, E = -2.13656539 Ha
# Each step, the iteration is 91 and the parameter is [-0.34742421]
# Each step, the iteration is 92 and the parameter is [-0.34742421]
# Each step, the iteration is 93 and the parameter is [-0.34742421]
# Each step, the iteration is 94 and the parameter is [-0.34742421]
# Each step, the iteration is 95 and the parameter is [-0.34742421]
# step = 95, E = -2.13656539 Ha
# Each step, the iteration is 96 and the parameter is [-0.34742421]
# Each step, the iteration is 97 and the parameter is [-0.34742421]
# Each step, the iteration is 98 and the parameter is [-0.34742421]
# Each step, the iteration is 99 and the parameter is [-0.34742421]
# Each step, the iteration is 100 and the parameter is [-0.34742421]
# step = 100, E = -2.13656539 Ha
# Each step, the iteration is 101 and the parameter is [-0.34742421]
# Each step, the iteration is 102 and the parameter is [-0.34742421]
# Each step, the iteration is 103 and the parameter is [-0.34742421]
# Each step, the iteration is 104 and the parameter is [-0.34742421]
# Each step, the iteration is 105 and the parameter is [-0.34742421]
# step = 105, E = -2.13656539 Ha
# Each step, the iteration is 106 and the parameter is [-0.34742421]
# Each step, the iteration is 107 and the parameter is [-0.34742421]
# Each step, the iteration is 108 and the parameter is [-0.34742421]
# Each step, the iteration is 109 and the parameter is [-0.34742421]
# Each step, the iteration is 110 and the parameter is [-0.34742421]
# step = 110, E = -2.13656539 Ha
# Each step, the iteration is 111 and the parameter is [-0.34742421]
# Each step, the iteration is 112 and the parameter is [-0.34742421]
# Each step, the iteration is 113 and the parameter is [-0.34742421]
# Each step, the iteration is 114 and the parameter is [-0.34742421]
# Each step, the iteration is 115 and the parameter is [-0.34742421]
# step = 115, E = -2.13656539 Ha
# Each step, the iteration is 116 and the parameter is [-0.34742421]
# Each step, the iteration is 117 and the parameter is [-0.34742421]
# Each step, the iteration is 118 and the parameter is [-0.34742421]
# Each step, the iteration is 119 and the parameter is [-0.34742421]
# Each step, the iteration is 120 and the parameter is [-0.34742421]
# step = 120, E = -2.13656539 Ha
# Each step, the iteration is 121 and the parameter is [-0.34742421]
# Each step, the iteration is 122 and the parameter is [-0.34742421]
# Each step, the iteration is 123 and the parameter is [-0.34742421]
# Each step, the iteration is 124 and the parameter is [-0.34742421]
# Each step, the iteration is 125 and the parameter is [-0.34742421]
# step = 125, E = -2.13656539 Ha
# Each step, the iteration is 126 and the parameter is [-0.34742421]
# Each step, the iteration is 127 and the parameter is [-0.34742421]
# Each step, the iteration is 128 and the parameter is [-0.34742421]
# Each step, the iteration is 129 and the parameter is [-0.34742421]
# Each step, the iteration is 130 and the parameter is [-0.34742421]
# step = 130, E = -2.13656539 Ha
# Each step, the iteration is 131 and the parameter is [-0.34742421]
# Each step, the iteration is 132 and the parameter is [-0.34742421]
# Each step, the iteration is 133 and the parameter is [-0.34742421]
# Each step, the iteration is 134 and the parameter is [-0.34742421]
# Each step, the iteration is 135 and the parameter is [-0.34742421]
# step = 135, E = -2.13656539 Ha
# Each step, the iteration is 136 and the parameter is [-0.34742421]
# Each step, the iteration is 137 and the parameter is [-0.34742421]
# Each step, the iteration is 138 and the parameter is [-0.34742421]
# Each step, the iteration is 139 and the parameter is [-0.34742421]
# Each step, the iteration is 140 and the parameter is [-0.34742421]
# step = 140, E = -2.13656539 Ha
# Each step, the iteration is 141 and the parameter is [-0.34742421]
# Each step, the iteration is 142 and the parameter is [-0.34742421]
# Each step, the iteration is 143 and the parameter is [-0.34742421]
# Each step, the iteration is 144 and the parameter is [-0.34742421]
# Each step, the iteration is 145 and the parameter is [-0.34742421]
# step = 145, E = -2.13656539 Ha
# Each step, the iteration is 146 and the parameter is [-0.34742421]
# Each step, the iteration is 147 and the parameter is [-0.34742421]
# Each step, the iteration is 148 and the parameter is [-0.34742421]
# Each step, the iteration is 149 and the parameter is [-0.34742421]
# Each step, the iteration is 150 and the parameter is [-0.34742421]
# step = 150, E = -2.13656539 Ha
# Each step, the iteration is 151 and the parameter is [-0.34742421]
# Each step, the iteration is 152 and the parameter is [-0.34742421]
# Each step, the iteration is 153 and the parameter is [-0.34742421]
# Each step, the iteration is 154 and the parameter is [-0.34742421]
# Each step, the iteration is 155 and the parameter is [-0.34742421]
# step = 155, E = -2.13656539 Ha
# Each step, the iteration is 156 and the parameter is [-0.34742421]
# Each step, the iteration is 157 and the parameter is [-0.34742421]
# Each step, the iteration is 158 and the parameter is [-0.34742421]
# Each step, the iteration is 159 and the parameter is [-0.34742421]
# Each step, the iteration is 160 and the parameter is [-0.34742421]
# step = 160, E = -2.13656539 Ha
# Each step, the iteration is 161 and the parameter is [-0.34742421]
# Each step, the iteration is 162 and the parameter is [-0.34742421]
# Each step, the iteration is 163 and the parameter is [-0.34742421]
# Each step, the iteration is 164 and the parameter is [-0.34742421]
# Each step, the iteration is 165 and the parameter is [-0.34742421]
# step = 165, E = -2.13656539 Ha
# Each step, the iteration is 166 and the parameter is [-0.34742421]
# Each step, the iteration is 167 and the parameter is [-0.34742421]
# Each step, the iteration is 168 and the parameter is [-0.34742421]
# Each step, the iteration is 169 and the parameter is [-0.34742421]
# Each step, the iteration is 170 and the parameter is [-0.34742421]
# step = 170, E = -2.13656539 Ha
# Each step, the iteration is 171 and the parameter is [-0.34742421]
# Each step, the iteration is 172 and the parameter is [-0.34742421]
# Each step, the iteration is 173 and the parameter is [-0.34742421]
# Each step, the iteration is 174 and the parameter is [-0.34742421]
# Each step, the iteration is 175 and the parameter is [-0.34742421]
# step = 175, E = -2.13656539 Ha
# Each step, the iteration is 176 and the parameter is [-0.34742421]
# Each step, the iteration is 177 and the parameter is [-0.34742421]
# Each step, the iteration is 178 and the parameter is [-0.34742421]
# Each step, the iteration is 179 and the parameter is [-0.34742421]
# Each step, the iteration is 180 and the parameter is [-0.34742421]
# step = 180, E = -2.13656539 Ha
# Each step, the iteration is 181 and the parameter is [-0.34742421]
# Each step, the iteration is 182 and the parameter is [-0.34742421]
# Each step, the iteration is 183 and the parameter is [-0.34742421]
# Each step, the iteration is 184 and the parameter is [-0.34742421]
# Each step, the iteration is 185 and the parameter is [-0.34742421]
# step = 185, E = -2.13656539 Ha
# Each step, the iteration is 186 and the parameter is [-0.34742421]
# Each step, the iteration is 187 and the parameter is [-0.34742421]
# Each step, the iteration is 188 and the parameter is [-0.34742421]
# Each step, the iteration is 189 and the parameter is [-0.34742421]
# Each step, the iteration is 190 and the parameter is [-0.34742421]
# step = 190, E = -2.13656539 Ha
# Each step, the iteration is 191 and the parameter is [-0.34742421]
# Each step, the iteration is 192 and the parameter is [-0.34742421]
# Each step, the iteration is 193 and the parameter is [-0.34742421]
# Each step, the iteration is 194 and the parameter is [-0.34742421]
# Each step, the iteration is 195 and the parameter is [-0.34742421]
# step = 195, E = -2.13656539 Ha
# Each step, the iteration is 196 and the parameter is [-0.34742421]
# Each step, the iteration is 197 and the parameter is [-0.34742421]
# Each step, the iteration is 198 and the parameter is [-0.34742421]
# Each step, the iteration is 199 and the parameter is [-0.34742421]
# Each step, the iteration is 200 and the parameter is [-0.34742421]
# step = 200, E = -2.13656539 Ha
# Each step, the iteration is 201 and the parameter is [-0.34742421]
# Each step, the iteration is 202 and the parameter is [-0.34742421]
# Each step, the iteration is 203 and the parameter is [-0.34742421]
# Each step, the iteration is 204 and the parameter is [-0.34742421]
# Each step, the iteration is 205 and the parameter is [-0.34742421]
# step = 205, E = -2.13656539 Ha
# Each step, the iteration is 206 and the parameter is [-0.34742421]
# Each step, the iteration is 207 and the parameter is [-0.34742421]
# Each step, the iteration is 208 and the parameter is [-0.34742421]
# Each step, the iteration is 209 and the parameter is [-0.34742421]
# Each step, the iteration is 210 and the parameter is [-0.34742421]
# step = 210, E = -2.13656539 Ha
# Each step, the iteration is 211 and the parameter is [-0.34742421]
# Each step, the iteration is 212 and the parameter is [-0.34742421]
# Each step, the iteration is 213 and the parameter is [-0.34742421]
# Each step, the iteration is 214 and the parameter is [-0.34742421]
# Each step, the iteration is 215 and the parameter is [-0.34742421]
# step = 215, E = -2.13656539 Ha
# Each step, the iteration is 216 and the parameter is [-0.34742421]
# Each step, the iteration is 217 and the parameter is [-0.34742421]
# Each step, the iteration is 218 and the parameter is [-0.34742421]
# Each step, the iteration is 219 and the parameter is [-0.34742421]
# Each step, the iteration is 220 and the parameter is [-0.34742421]
# step = 220, E = -2.13656539 Ha
# Each step, the iteration is 221 and the parameter is [-0.34742421]
# Each step, the iteration is 222 and the parameter is [-0.34742421]
# Each step, the iteration is 223 and the parameter is [-0.34742421]
# Each step, the iteration is 224 and the parameter is [-0.34742421]
# Each step, the iteration is 225 and the parameter is [-0.34742421]
# step = 225, E = -2.13656539 Ha
# Each step, the iteration is 226 and the parameter is [-0.34742421]
# Each step, the iteration is 227 and the parameter is [-0.34742421]
# Each step, the iteration is 228 and the parameter is [-0.34742421]
# Each step, the iteration is 229 and the parameter is [-0.34742421]
# Each step, the iteration is 230 and the parameter is [-0.34742421]
# step = 230, E = -2.13656539 Ha
# Each step, the iteration is 231 and the parameter is [-0.34742421]
# Each step, the iteration is 232 and the parameter is [-0.34742421]
# Each step, the iteration is 233 and the parameter is [-0.34742421]
# Each step, the iteration is 234 and the parameter is [-0.34742421]
# Each step, the iteration is 235 and the parameter is [-0.34742421]
# step = 235, E = -2.13656539 Ha
# Each step, the iteration is 236 and the parameter is [-0.34742421]
# Each step, the iteration is 237 and the parameter is [-0.34742421]
# Each step, the iteration is 238 and the parameter is [-0.34742421]
# Each step, the iteration is 239 and the parameter is [-0.34742421]
# Each step, the iteration is 240 and the parameter is [-0.34742421]
# step = 240, E = -2.13656539 Ha
# Each step, the iteration is 241 and the parameter is [-0.34742421]
# Each step, the iteration is 242 and the parameter is [-0.34742421]
# Each step, the iteration is 243 and the parameter is [-0.34742421]
# Each step, the iteration is 244 and the parameter is [-0.34742421]
# Each step, the iteration is 245 and the parameter is [-0.34742421]
# step = 245, E = -2.13656539 Ha
# Each step, the iteration is 246 and the parameter is [-0.34742421]
# Each step, the iteration is 247 and the parameter is [-0.34742421]
# Each step, the iteration is 248 and the parameter is [-0.34742421]
# Each step, the iteration is 249 and the parameter is [-0.34742421]
# Each step, the iteration is 250 and the parameter is [-0.34742421]
# step = 250, E = -2.13656539 Ha
# Each step, the iteration is 251 and the parameter is [-0.34742421]
# Each step, the iteration is 252 and the parameter is [-0.34742421]
# Each step, the iteration is 253 and the parameter is [-0.34742421]
# Each step, the iteration is 254 and the parameter is [-0.34742421]
# Each step, the iteration is 255 and the parameter is [-0.34742421]
# step = 255, E = -2.13656539 Ha
# Each step, the iteration is 256 and the parameter is [-0.34742421]
# Each step, the iteration is 257 and the parameter is [-0.34742421]
# Each step, the iteration is 258 and the parameter is [-0.34742421]
# Each step, the iteration is 259 and the parameter is [-0.34742421]
# Each step, the iteration is 260 and the parameter is [-0.34742421]
# step = 260, E = -2.13656539 Ha
# Each step, the iteration is 261 and the parameter is [-0.34742421]
# Each step, the iteration is 262 and the parameter is [-0.34742421]
# Each step, the iteration is 263 and the parameter is [-0.34742421]
# Each step, the iteration is 264 and the parameter is [-0.34742421]
# Each step, the iteration is 265 and the parameter is [-0.34742421]
# step = 265, E = -2.13656539 Ha
# Each step, the iteration is 266 and the parameter is [-0.34742421]
# Each step, the iteration is 267 and the parameter is [-0.34742421]
# Each step, the iteration is 268 and the parameter is [-0.34742421]
# Each step, the iteration is 269 and the parameter is [-0.34742421]
# Each step, the iteration is 270 and the parameter is [-0.34742421]
# step = 270, E = -2.13656539 Ha
# Each step, the iteration is 271 and the parameter is [-0.34742421]
# Each step, the iteration is 272 and the parameter is [-0.34742421]
# Each step, the iteration is 273 and the parameter is [-0.34742421]
# Each step, the iteration is 274 and the parameter is [-0.34742421]
# Each step, the iteration is 275 and the parameter is [-0.34742421]
# step = 275, E = -2.13656539 Ha
# Each step, the iteration is 276 and the parameter is [-0.34742421]
# Each step, the iteration is 277 and the parameter is [-0.34742421]
# Each step, the iteration is 278 and the parameter is [-0.34742421]
# Each step, the iteration is 279 and the parameter is [-0.34742421]
# Each step, the iteration is 280 and the parameter is [-0.34742421]
# step = 280, E = -2.13656539 Ha
# Each step, the iteration is 281 and the parameter is [-0.34742421]
# Each step, the iteration is 282 and the parameter is [-0.34742421]
# Each step, the iteration is 283 and the parameter is [-0.34742421]
# Each step, the iteration is 284 and the parameter is [-0.34742421]
# Each step, the iteration is 285 and the parameter is [-0.34742421]
# step = 285, E = -2.13656539 Ha
# Each step, the iteration is 286 and the parameter is [-0.34742421]
# Each step, the iteration is 287 and the parameter is [-0.34742421]
# Each step, the iteration is 288 and the parameter is [-0.34742421]
# Each step, the iteration is 289 and the parameter is [-0.34742421]
# Each step, the iteration is 290 and the parameter is [-0.34742421]
# step = 290, E = -2.13656539 Ha
# Each step, the iteration is 291 and the parameter is [-0.34742421]
# Each step, the iteration is 292 and the parameter is [-0.34742421]
# Each step, the iteration is 293 and the parameter is [-0.34742421]
# Each step, the iteration is 294 and the parameter is [-0.34742421]
# Each step, the iteration is 295 and the parameter is [-0.34742421]
# step = 295, E = -2.13656539 Ha
# Each step, the iteration is 296 and the parameter is [-0.34742421]
# Each step, the iteration is 297 and the parameter is [-0.34742421]
# Each step, the iteration is 298 and the parameter is [-0.34742421]
# Each step, the iteration is 299 and the parameter is [-0.34742421]
# Updated params are [-0.34742421]
# Updated excitation are [[2, 3, 4, 5]]
# Exc. dealing right now is [2, 3, 4, 5]
# The params that are going in -0.34742420901683596
# Exc. dealing right now is [2, 3, 4, 5]
# The params that are going in -0.34742420901683596
# 0: ──X──────────────────────────────────────────────────────────────────────────────────────────
# 1: ──X──────────────────────────────────────────────────────────────────────────────────────────
# 2: ──X──H────────────╭X──RZ(-0.04)─╭X──H──RX(-1.57)─────────────────────────────╭X──RZ(-0.04)─╭X
# 3: ──X──RX(-1.57)─╭X─╰●────────────╰●─╭X──RX(1.57)───RX(-1.57)───────────────╭X─╰●────────────╰●
# 4: ──H─╭X─────────╰●──────────────────╰●─╭X──────────H──────────H─────────╭X─╰●─────────────────
# 5: ──H─╰●────────────────────────────────╰●──────────H──────────RX(-1.57)─╰●────────────────────
# 6: ─────────────────────────────────────────────────────────────────────────────────────────────
# 7: ─────────────────────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────
# ──────────────────────────────────────────────────────────────────────────────────────────────────
# ───RX(1.57)──RX(-1.57)─────────────────────────────╭X──RZ(-0.04)─╭X──RX(1.57)──RX(-1.57)──────────
# ──╭X─────────RX(1.57)───RX(-1.57)───────────────╭X─╰●────────────╰●─╭X─────────RX(1.57)───H───────
# ──╰●────────╭X──────────H──────────RX(-1.57)─╭X─╰●──────────────────╰●────────╭X──────────RX(1.57)
# ────────────╰●──────────RX(1.57)───H─────────╰●───────────────────────────────╰●──────────H───────
# ──────────────────────────────────────────────────────────────────────────────────────────────────
# ──────────────────────────────────────────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────
# ───────────╭X──RZ(-0.04)─╭X──RX(1.57)──H─────────────────────╭X──RZ(0.04)─╭X──H──H──────────
# ────────╭X─╰●────────────╰●─╭X─────────H──H───────────────╭X─╰●───────────╰●─╭X──H──H───────
# ───H─╭X─╰●──────────────────╰●────────╭X──H──H─────────╭X─╰●─────────────────╰●─╭X──H───────
# ───H─╰●───────────────────────────────╰●──H──RX(-1.57)─╰●───────────────────────╰●──RX(1.57)
# ────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────
# ──────────────────────────────────────────────────────────────────────────────────────────────────
# ───────────────────╭X──RZ(0.04)─╭X──H──H─────────────────────────────╭X──RZ(0.04)─╭X──H──RX(-1.57)
# ────────────────╭X─╰●───────────╰●─╭X──H──RX(-1.57)───────────────╭X─╰●───────────╰●─╭X──RX(1.57)─
# ───RX(-1.57)─╭X─╰●─────────────────╰●─╭X──RX(1.57)───RX(-1.57)─╭X─╰●─────────────────╰●─╭X────────
# ───H─────────╰●───────────────────────╰●──H──────────RX(-1.57)─╰●───────────────────────╰●────────
# ──────────────────────────────────────────────────────────────────────────────────────────────────
# ──────────────────────────────────────────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────────────┤ ╭State
# ────────────────────────────────────────────────────────────────────┤ ├State
# ─────────────────────────────╭X──RZ(0.04)─╭X──RX(1.57)──────────────┤ ├State
# ───H──────────────────────╭X─╰●───────────╰●─╭X─────────H───────────┤ ├State
# ───RX(1.57)──RX(-1.57)─╭X─╰●─────────────────╰●────────╭X──RX(1.57)─┤ ├State
# ───RX(1.57)──RX(-1.57)─╰●──────────────────────────────╰●──RX(1.57)─┤ ├State
# ────────────────────────────────────────────────────────────────────┤ ├State
# ────────────────────────────────────────────────────────────────────┤ ╰State
# The updated state is [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#  -1.22663473e-17+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+4.85722573e-17j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00-2.45326947e-18j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#  -1.72839769e-01+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+1.11022302e-16j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#  -5.88784672e-17+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   5.55111512e-17+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+5.88784672e-17j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00-8.09578924e-17j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   9.02056208e-17+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#  -2.69859641e-17+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   9.84949955e-01+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00-5.88784672e-17j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00-1.11022302e-16j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#  -5.88784672e-17+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
# The adapt iteration now is 1
# The current excitation operator is a⁺(0) a(4)
# The expectation value of a⁺(0) a(4) is 0.03332942325896462
# The current excitation operator is a⁺(0) a(6)
# The expectation value of a⁺(0) a(6) is 4.113105229251803e-17
# The current excitation operator is a⁺(1) a(5)
# The expectation value of a⁺(1) a(5) is 0.033329423258964624
# The current excitation operator is a⁺(1) a(7)
# The expectation value of a⁺(1) a(7) is 4.319960941997905e-17
# The current excitation operator is a⁺(2) a(4)
# The expectation value of a⁺(2) a(4) is 8.779516279096925e-18
# The current excitation operator is a⁺(2) a(6)
# The expectation value of a⁺(2) a(6) is 0.03376536427534492
# The current excitation operator is a⁺(3) a(5)
# The expectation value of a⁺(3) a(5) is 5.1215210985562814e-17
# The current excitation operator is a⁺(3) a(7)
# The expectation value of a⁺(3) a(7) is 0.03376536427534495
# The current excitation operator is a⁺(0) a⁺(1) a(4) a(5)
# The expectation value of a⁺(0) a⁺(1) a(4) a(5) is 0.15596708822888677
# The current excitation operator is a⁺(0) a⁺(1) a(4) a(7)
# The expectation value of a⁺(0) a⁺(1) a(4) a(7) is 6.046080484080485e-18
# The current excitation operator is a⁺(0) a⁺(1) a(5) a(6)
# The expectation value of a⁺(0) a⁺(1) a(5) a(6) is 8.470449952387595e-18
# The current excitation operator is a⁺(0) a⁺(1) a(6) a(7)
# The expectation value of a⁺(0) a⁺(1) a(6) a(7) is 0.1940782594674435
# The current excitation operator is a⁺(0) a⁺(2) a(4) a(6)
# The expectation value of a⁺(0) a⁺(2) a(4) a(6) is 0.10666883889026185
# The current excitation operator is a⁺(0) a⁺(3) a(4) a(5)
# The expectation value of a⁺(0) a⁺(3) a(4) a(5) is 7.707877412315685e-18
# The current excitation operator is a⁺(0) a⁺(3) a(4) a(7)
# The expectation value of a⁺(0) a⁺(3) a(4) a(7) is 0.24335748143143174
# The current excitation operator is a⁺(0) a⁺(3) a(5) a(6)
# The expectation value of a⁺(0) a⁺(3) a(5) a(6) is 0.13668864254116972
# The current excitation operator is a⁺(0) a⁺(3) a(6) a(7)
# The expectation value of a⁺(0) a⁺(3) a(6) a(7) is 8.059424911563088e-18
# The current excitation operator is a⁺(1) a⁺(2) a(4) a(5)
# The expectation value of a⁺(1) a⁺(2) a(4) a(5) is 1.5550513251855214e-17
# The current excitation operator is a⁺(1) a⁺(2) a(4) a(7)
# The expectation value of a⁺(1) a⁺(2) a(4) a(7) is 0.13668864254116972
# The current excitation operator is a⁺(1) a⁺(2) a(5) a(6)
# The expectation value of a⁺(1) a⁺(2) a(5) a(6) is 0.24335748143143174
# The current excitation operator is a⁺(1) a⁺(2) a(6) a(7)
# The expectation value of a⁺(1) a⁺(2) a(6) a(7) is 5.752696957613044e-18
# The current excitation operator is a⁺(1) a⁺(3) a(5) a(7)
# The expectation value of a⁺(1) a⁺(3) a(5) a(7) is 0.1066688388902618
# The current excitation operator is a⁺(2) a⁺(3) a(4) a(5)
# The expectation value of a⁺(2) a⁺(3) a(4) a(5) is 1.1102230246251565e-16
# The current excitation operator is a⁺(2) a⁺(3) a(4) a(7)
# The expectation value of a⁺(2) a⁺(3) a(4) a(7) is 1.7528296822742852e-17
# The current excitation operator is a⁺(2) a⁺(3) a(5) a(6)
# The expectation value of a⁺(2) a⁺(3) a(5) a(6) is 1.0692030619084593e-17
# The current excitation operator is a⁺(2) a⁺(3) a(6) a(7)
# The expectation value of a⁺(2) a⁺(3) a(6) a(7) is 0.14849618639575402
# The highest operator value is 0.24335748143143174 for operator a⁺(0) a⁺(3) a(4) a(7)
# Highest gradient excitation is [0, 3, 4, 7]
# The current status of ash_excitation is [[2, 3, 4, 5], [0, 3, 4, 7]]
# Moving towards parameters
# The length of parameters is 2
# Going to do energy calculation
# Each step, the iteration is 0 and the parameter is [0. 0.]
# step = 0, E = -2.11246073 Ha
# Each step, the iteration is 1 and the parameter is [-0.06868177  0.04946395]
# Each step, the iteration is 2 and the parameter is [-0.12595759  0.08393868]
# Each step, the iteration is 3 and the parameter is [-0.17316814  0.10816442]
# Each step, the iteration is 4 and the parameter is [-0.21178049  0.12539122]
# Each step, the iteration is 5 and the parameter is [-0.24319244  0.13780935]
# step = 5, E = -2.14360775 Ha
# Each step, the iteration is 6 and the parameter is [-0.26865142  0.14688835]
# Each step, the iteration is 7 and the parameter is [-0.28923086  0.15361767]
# Each step, the iteration is 8 and the parameter is [-0.3058342   0.15866926]
# Each step, the iteration is 9 and the parameter is [-0.31921105  0.16250492]
# Each step, the iteration is 10 and the parameter is [-0.3299774   0.16544651]
# step = 10, E = -2.14688405 Ha
# Each step, the iteration is 11 and the parameter is [-0.33863613  0.16772172]
# Each step, the iteration is 12 and the parameter is [-0.34559591  0.16949415]
# Each step, the iteration is 13 and the parameter is [-0.35118774  0.17088309]
# Each step, the iteration is 14 and the parameter is [-0.35567904  0.17197679]
# Each step, the iteration is 15 and the parameter is [-0.35928554  0.17284139]
# step = 15, E = -2.14724458 Ha
# Each step, the iteration is 16 and the parameter is [-0.36218102  0.17352704]
# Each step, the iteration is 17 and the parameter is [-0.36450532  0.17407213]
# Each step, the iteration is 18 and the parameter is [-0.36637092  0.17450635]
# Each step, the iteration is 19 and the parameter is [-0.36786823  0.1748528 ]
# Each step, the iteration is 20 and the parameter is [-0.36906986  0.17512955]
# step = 20, E = -2.14728442 Ha
# Each step, the iteration is 21 and the parameter is [-0.37003416  0.17535085]
# Each step, the iteration is 22 and the parameter is [-0.37080798  0.17552795]
# ...
# ─────╰X───────────────────────────────────────────────────────────────────────────────────────────
# ───────────────────────────────────────╭●──RX(1.57)──H─╭●────────────────────────────────────╭●──H
# ──╭●────────────────────────╭●─────────╰X──────────────╰X─╭●──────────────────────────────╭●─╰X──H
# ──╰X─╭●──────────────────╭●─╰X────────────────────────────╰X─╭●─────────────────╭●────────╰X──────
# ─────╰X─╭●────────────╭●─╰X──────────────────────────────────╰X─╭●───────────╭●─╰X─────────H─╭X───
# ────────╰X──RZ(-0.00)─╰X──H──RX(-1.57)──────────────────────────╰X──RZ(0.00)─╰X──RX(1.57)──H─╰●───
#
# ────────────────────────────────────╭●──RX(1.57)──H─╭●────────────────────────────────────╭●
# ─────────────────────────╭●─────────╰X──────────────╰X─╭●──────────────────────────────╭●─╰X
# ──╭●──────────────────╭●─╰X────────────────────────────╰X─╭●─────────────────╭●────────╰X───
# ──╰X─╭●────────────╭●─╰X──────────────────────────────────╰X─╭●───────────╭●─╰X─────────────
# ─────╰X──RZ(-0.00)─╰X──H──RX(-1.57)──────────────────────────╰X──RZ(0.00)─╰X──RX(1.57)──────
# ────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────
#
# ───H──────────H─╭X──RZ(-0.01)─╭X──H──RX(-1.57)─────────────────────────────╭X──RZ(-0.01)─╭X
# ───RX(-1.57)─╭X─╰●────────────╰●─╭X──RX(1.57)───RX(-1.57)───────────────╭X─╰●────────────╰●
# ─────────────│───────────────────│──────────────────────────────────────│──────────────────
# ─────────────│───────────────────│──────────────────────────────────────│──────────────────
# ─────────────│───────────────────│──────────────────────────────────────│──────────────────
# ─────────────│───────────────────│──────────────────────────────────────│──────────────────
# ─────────────╰●──────────────────╰●─╭X──────────H──────────H─────────╭X─╰●─────────────────
# ────────────────────────────────────╰●──────────H──────────RX(-1.57)─╰●────────────────────
#
# ───RX(1.57)──RX(-1.57)─────────────────────────────╭X──RZ(-0.01)─╭X──RX(1.57)──RX(-1.57)──────────
# ──╭X─────────RX(1.57)───RX(-1.57)───────────────╭X─╰●────────────╰●─╭X─────────RX(1.57)───H───────
# ──│─────────────────────────────────────────────│───────────────────│─────────────────────────────
# ──│─────────────────────────────────────────────│───────────────────│─────────────────────────────
# ──│─────────────────────────────────────────────│───────────────────│─────────────────────────────
# ──│─────────────────────────────────────────────│───────────────────│─────────────────────────────
# ──╰●────────╭X──────────H──────────RX(-1.57)─╭X─╰●──────────────────╰●────────╭X──────────RX(1.57)
# ────────────╰●──────────RX(1.57)───H─────────╰●───────────────────────────────╰●──────────H───────
#
# ───────────╭X──RZ(-0.01)─╭X──RX(1.57)──H─────────────────────╭X──RZ(0.01)─╭X──H──H──────────
# ────────╭X─╰●────────────╰●─╭X─────────H──H───────────────╭X─╰●───────────╰●─╭X──H──H───────
# ────────│───────────────────│─────────────────────────────│──────────────────│──────────────
# ────────│───────────────────│─────────────────────────────│──────────────────│──────────────
# ────────│───────────────────│─────────────────────────────│──────────────────│──────────────
# ────────│───────────────────│─────────────────────────────│──────────────────│──────────────
# ───H─╭X─╰●──────────────────╰●────────╭X──H──H─────────╭X─╰●─────────────────╰●─╭X──H───────
# ───H─╰●───────────────────────────────╰●──H──RX(-1.57)─╰●───────────────────────╰●──RX(1.57)
#
# ───────────────────╭X──RZ(0.01)─╭X──H──H─────────────────────────────╭X──RZ(0.01)─╭X──H──RX(-1.57)
# ────────────────╭X─╰●───────────╰●─╭X──H──RX(-1.57)───────────────╭X─╰●───────────╰●─╭X──RX(1.57)─
# ────────────────│──────────────────│──────────────────────────────│──────────────────│────────────
# ────────────────│──────────────────│──────────────────────────────│──────────────────│────────────
# ────────────────│──────────────────│──────────────────────────────│──────────────────│────────────
# ────────────────│──────────────────│──────────────────────────────│──────────────────│────────────
# ───RX(-1.57)─╭X─╰●─────────────────╰●─╭X──RX(1.57)───RX(-1.57)─╭X─╰●─────────────────╰●─╭X────────
# ───H─────────╰●───────────────────────╰●──H──────────RX(-1.57)─╰●───────────────────────╰●────────
#
# ─────────────────────────────╭X──RZ(0.01)─╭X──RX(1.57)──RX(-1.57)─╭●──────────────────────────────
# ───H──────────────────────╭X─╰●───────────╰●─╭X─────────H─────────╰X────────╭●────────────────────
# ──────────────────────────│──────────────────│──────────────────────────────╰X─╭●─────────────────
# ──────────────────────────│──────────────────│─────────────────────────────────╰X─╭●────────────╭●
# ──────────────────────────│──────────────────│──────────H─────────────────────────╰X──RZ(-0.00)─╰X
# ──────────────────────────│──────────────────│──────────H─────────────────────────────────────────
# ───RX(1.57)──RX(-1.57)─╭X─╰●─────────────────╰●────────╭X──────────RX(1.57)───────────────────────
# ───RX(1.57)──RX(-1.57)─╰●──────────────────────────────╰●──────────RX(1.57)──H────────────────────
#
# ────────────────╭●──RX(1.57)──H─╭●────────────────────────────────────╭●──H────────────────────
# ─────╭●─────────╰X──────────────╰X─╭●──────────────────────────────╭●─╰X──RX(-1.57)─╭●─────────
# ──╭●─╰X────────────────────────────╰X─╭●─────────────────╭●────────╰X───────────────╰X─╭●──────
# ──╰X──────────────────────────────────╰X─╭●───────────╭●─╰X────────────────────────────╰X─╭●───
# ───H──RX(-1.57)──────────────────────────╰X──RZ(0.00)─╰X──RX(1.57)────────────────────────╰X─╭●
# ─────────────────────────────────────────────────────────────────────────────────────────────╰X
# ───────────────────────────────────────────────────────────────────────────────────────────────
# ───────────────────────────────────────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# ──────────────────────────────╭●──RX(1.57)──H─╭●────────────────────────────────────╭●──────────H───
# ───────────────────╭●─────────╰X──────────────╰X─╭●──────────────────────────────╭●─╰X──────────────
# ────────────────╭●─╰X────────────────────────────╰X─╭●─────────────────╭●────────╰X──RX(-1.57)─╭●───
# ─────────────╭●─╰X──────────────────────────────────╰X─╭●───────────╭●─╰X──────────────────────╰X─╭●
# ───RZ(-0.00)─╰X──H──RX(-1.57)──────────────────────────╰X──RZ(0.00)─╰X──RX(1.57)──────────────────╰X
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────────────────────────────────────────┤
# ────────────────────────────────────────────────────────────────────────────────────────────────┤
# ────────────────────────────────────────────────────────────────────────────────────────────────┤
# ────────────────────────────────────╭●──RX(1.57)──H─╭●────────────────────────────────────╭●──H─┤
# ─────────────────────────╭●─────────╰X──────────────╰X─╭●──────────────────────────────╭●─╰X────┤
# ──╭●──────────────────╭●─╰X────────────────────────────╰X─╭●─────────────────╭●────────╰X───────┤
# ──╰X─╭●────────────╭●─╰X──────────────────────────────────╰X─╭●───────────╭●─╰X─────────────────┤
# ─────╰X──RZ(-0.00)─╰X──H──RX(-1.57)──────────────────────────╰X──RZ(0.00)─╰X──RX(1.57)──────────┤
#
#   ╭State
#   ├State
#   ├State
#   ├State
#   ├State
#   ├State
#   ├State
#   ╰State
# The updated state is [-5.92923063e-19+0.00000000e+00j  0.00000000e+00+5.55001521e-19j
#   0.00000000e+00+5.83775107e-18j  1.07540838e-18+0.00000000e+00j
#   0.00000000e+00+8.18074136e-21j  4.38933507e-19+0.00000000e+00j
#  -1.77286776e-19+0.00000000e+00j  0.00000000e+00+8.59666625e-18j
#   0.00000000e+00-1.32534665e-17j  3.71297826e-18+0.00000000e+00j
#  -1.13079535e-19+0.00000000e+00j  0.00000000e+00+3.48357959e-18j
#  -3.68782617e-18+0.00000000e+00j  0.00000000e+00-6.06324015e-18j
#   0.00000000e+00-1.73472348e-18j  2.29543161e-02+0.00000000e+00j
#   0.00000000e+00+5.61987177e-18j -1.76182853e-18+0.00000000e+00j
#  -9.85011683e-18+0.00000000e+00j  0.00000000e+00-6.70553633e-18j
#   2.06740468e-17+0.00000000e+00j  0.00000000e+00-1.22622744e-18j
#   0.00000000e+00+1.97380426e-17j  1.23433512e-18+0.00000000e+00j
#   3.56334523e-21+0.00000000e+00j  0.00000000e+00+1.96647169e-17j
#   0.00000000e+00-7.33877788e-18j -1.72900975e-18+0.00000000e+00j
#   0.00000000e+00-3.20827101e-19j -4.15016652e-21+0.00000000e+00j
#   2.61126889e-04+0.00000000e+00j  0.00000000e+00+2.43945489e-18j
#   0.00000000e+00+7.15213445e-18j -2.70860525e-18+0.00000000e+00j
#   1.04422222e-17+0.00000000e+00j  0.00000000e+00-9.86623977e-18j
#   2.45137387e-18+0.00000000e+00j  0.00000000e+00+4.45561731e-20j
#   0.00000000e+00+2.95072398e-17j -4.51162117e-21+0.00000000e+00j
#  -1.00595056e-18+0.00000000e+00j  0.00000000e+00-4.43414342e-17j
#   0.00000000e+00+6.36255845e-18j  2.76655150e-17+0.00000000e+00j
#   0.00000000e+00+9.81202966e-18j -2.72420605e-04+0.00000000e+00j
#   3.61367430e-18+0.00000000e+00j  0.00000000e+00+1.74558494e-17j
#   8.58124532e-18+0.00000000e+00j  0.00000000e+00-4.33680869e-17j
#   0.00000000e+00-6.24500451e-17j -5.26588949e-02+0.00000000e+00j
#   0.00000000e+00-1.36019293e-17j  2.59163660e-18+0.00000000e+00j
#   3.83304462e-18+0.00000000e+00j  0.00000000e+00-1.04083409e-17j
#   0.00000000e+00-8.31815295e-17j  3.19604640e-19+0.00000000e+00j
#  -3.53867055e-18+0.00000000e+00j  0.00000000e+00+3.85185989e-34j
#  -6.47214515e-02+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+1.72710611e-17j -9.83629121e-18+0.00000000e+00j
#   0.00000000e+00-7.35980541e-18j -3.31382056e-18+0.00000000e+00j
#  -3.12483207e-22+0.00000000e+00j  0.00000000e+00+2.21961173e-17j
#   4.17688887e-17+0.00000000e+00j  0.00000000e+00-5.64398966e-18j
#   0.00000000e+00-1.97313810e-17j  3.55443736e-18+0.00000000e+00j
#   1.97257850e-17+0.00000000e+00j  0.00000000e+00-1.50933848e-17j
#   0.00000000e+00-2.45300742e-18j  2.11571356e-04+0.00000000e+00j
#   0.00000000e+00+3.91939085e-17j  1.96480834e-17+0.00000000e+00j
#  -2.08516273e-17+0.00000000e+00j  0.00000000e+00+7.69956878e-20j
#  -8.04908952e-17+0.00000000e+00j  0.00000000e+00+2.32155701e-19j
#   0.00000000e+00+3.98212903e-17j  4.36771740e-18+0.00000000e+00j
#   0.00000000e+00-2.07923038e-17j  3.52365706e-19+0.00000000e+00j
#  -2.94157491e-17+0.00000000e+00j  0.00000000e+00+6.28837260e-18j
#   0.00000000e+00+1.62624681e-18j -5.66624017e-18+0.00000000e+00j
#  -3.06386447e-02+0.00000000e+00j  0.00000000e+00+8.67361738e-18j
#   3.95343564e-17+0.00000000e+00j  0.00000000e+00-1.35328883e-17j
#   0.00000000e+00+3.29596589e-17j  7.47220678e-18+0.00000000e+00j
#  -1.07762782e-18+0.00000000e+00j  0.00000000e+00+5.58124117e-17j
#   0.00000000e+00+7.28583860e-17j  1.46603295e-18+0.00000000e+00j
#   0.00000000e+00-3.12250226e-17j -3.84045697e-18+0.00000000e+00j
#  -4.84454131e-02+0.00000000e+00j  0.00000000e+00+1.38777878e-17j
#   0.00000000e+00+0.00000000e+00j  7.90852104e-02+0.00000000e+00j
#  -7.29272987e-18+0.00000000e+00j  0.00000000e+00-2.42070653e-17j
#  -1.93340710e-17+0.00000000e+00j  0.00000000e+00-1.83651327e-20j
#   0.00000000e+00+6.93889390e-18j -3.68333156e-18+0.00000000e+00j
#   0.00000000e+00-1.56475870e-16j -7.85001769e-17+0.00000000e+00j
#  -8.32630763e-17+0.00000000e+00j  0.00000000e+00-4.90601483e-18j
#  -8.34060257e-17+0.00000000e+00j  0.00000000e+00+6.39340469e-18j
#   0.00000000e+00+4.90872534e-17j  2.61563774e-18+0.00000000e+00j
#   6.31244196e-03+0.00000000e+00j  0.00000000e+00-1.51788304e-17j
#   0.00000000e+00-3.87236080e-17j -3.98516113e-18+0.00000000e+00j
#   0.00000000e+00+9.54096144e-18j  8.43483049e-18+0.00000000e+00j
#   3.55960570e-18+0.00000000e+00j  0.00000000e+00-3.77502158e-18j
#   0.00000000e+00+6.81571574e-20j -1.74329269e-18+0.00000000e+00j
#  -6.12933889e-18+0.00000000e+00j  0.00000000e+00-7.40565820e-18j
#   2.45341535e-17+0.00000000e+00j  0.00000000e+00-1.93933344e-17j
#   0.00000000e+00-1.47180445e-17j -2.10583743e-04+0.00000000e+00j
#   2.08641156e-17+0.00000000e+00j  0.00000000e+00+2.44894166e-17j
#   0.00000000e+00-1.02786257e-17j  3.51254112e-18+0.00000000e+00j
#   0.00000000e+00-7.84691322e-17j -3.56925415e-17+0.00000000e+00j
#   6.25840499e-17+0.00000000e+00j  0.00000000e+00-4.94638119e-18j
#   6.08300148e-18+0.00000000e+00j  0.00000000e+00+3.81639165e-17j
#   0.00000000e+00-2.77413721e-17j  3.24845436e-18+0.00000000e+00j
#   0.00000000e+00-2.75805431e-17j -1.08001345e-18+0.00000000e+00j
#   7.90827832e-02+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00-4.85722573e-17j -4.84462428e-02+0.00000000e+00j
#   7.36658323e-18+0.00000000e+00j  0.00000000e+00+1.56125113e-17j
#   7.81882391e-17+0.00000000e+00j  0.00000000e+00-1.38777878e-17j
#   0.00000000e+00-1.39294228e-17j -1.22268860e-18+0.00000000e+00j
#   7.91255697e-17+0.00000000e+00j  0.00000000e+00-5.28697584e-17j
#   0.00000000e+00-2.06226033e-19j  3.02891582e-18+0.00000000e+00j
#   0.00000000e+00-3.64291930e-17j -3.06381216e-02+0.00000000e+00j
#  -1.23335140e-17+0.00000000e+00j  0.00000000e+00+6.96221497e-18j
#   0.00000000e+00+1.33831206e-17j  2.94710937e-17+0.00000000e+00j
#   3.04931861e-19+0.00000000e+00j  0.00000000e+00-2.11627166e-20j
#   5.06979382e-18+0.00000000e+00j  0.00000000e+00+5.01085432e-18j
#   0.00000000e+00+4.75764242e-19j -9.21285213e-18+0.00000000e+00j
#   0.00000000e+00-4.71080064e-16j  7.80632397e-17+0.00000000e+00j
#   1.92570157e-16+0.00000000e+00j  0.00000000e+00-2.35512429e-16j
#  -6.31823649e-03+0.00000000e+00j  0.00000000e+00+2.60208521e-18j
#   0.00000000e+00-1.44355613e-17j  9.73593585e-18+0.00000000e+00j
#   5.55254345e-19+0.00000000e+00j  0.00000000e+00-7.84915786e-17j
#   0.00000000e+00+4.33217420e-19j -9.57147230e-18+0.00000000e+00j
#   0.00000000e+00+1.48526424e-17j -4.90720695e-18+0.00000000e+00j
#  -2.42684024e-17+0.00000000e+00j  0.00000000e+00+7.36722900e-18j
#  -1.59454467e-16+0.00000000e+00j  0.00000000e+00-9.03631800e-17j
#   0.00000000e+00+7.63278329e-17j -4.15119309e-02+0.00000000e+00j
#   0.00000000e+00-8.32667268e-17j  5.56672340e-17+0.00000000e+00j
#  -1.98401700e-17+0.00000000e+00j  0.00000000e+00+1.54074396e-33j
#   0.00000000e+00-1.38777878e-17j  1.13447005e-17+0.00000000e+00j
#   1.45134989e-17+0.00000000e+00j  0.00000000e+00-5.80639817e-20j
#  -1.89507854e-01+0.00000000e+00j  0.00000000e+00+2.77555756e-17j
#   0.00000000e+00+4.85722573e-17j  3.93077818e-17+0.00000000e+00j
#   0.00000000e+00+7.77236545e-17j  8.31733584e-17+0.00000000e+00j
#   4.96058491e-03+0.00000000e+00j  0.00000000e+00+3.46944695e-17j
#  -3.76490191e-20+0.00000000e+00j  0.00000000e+00-6.16311856e-18j
#   0.00000000e+00+0.00000000e+00j  3.76720491e-18+0.00000000e+00j
#   2.44023089e-17+0.00000000e+00j  0.00000000e+00-6.77626358e-21j
#   0.00000000e+00+3.46699073e-17j  1.83779986e-18+0.00000000e+00j
#   0.00000000e+00-1.95698492e-17j  5.88721780e-17+0.00000000e+00j
#   2.87799051e-17+0.00000000e+00j  0.00000000e+00+2.37563625e-18j
#   0.00000000e+00+7.89299182e-17j -4.94329686e-03+0.00000000e+00j
#  -3.44903145e-17+0.00000000e+00j  0.00000000e+00+1.47452387e-17j
#  -4.16674507e-17+0.00000000e+00j  0.00000000e+00+1.12967384e-16j
#   0.00000000e+00+7.85165661e-17j  3.56032175e-18+0.00000000e+00j
#   2.69949420e-17+0.00000000e+00j  0.00000000e+00+9.35738832e-17j
#   0.00000000e+00+7.36065841e-18j -2.43023598e-17+0.00000000e+00j
#   0.00000000e+00+5.97912617e-19j -1.30711100e-17+0.00000000e+00j
#  -1.87702501e-18+0.00000000e+00j  0.00000000e+00+1.35114858e-17j
#   9.67298191e-01+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00-2.77415559e-17j -3.13995262e-16+0.00000000e+00j
#   0.00000000e+00+2.21827568e-16j -3.94341234e-17+0.00000000e+00j
#   5.87577830e-17+0.00000000e+00j  0.00000000e+00+3.48880086e-18j
#   0.00000000e+00+5.53050605e-17j -3.74674575e-19+0.00000000e+00j
#  -3.97253443e-21+0.00000000e+00j  0.00000000e+00+4.20357807e-18j
#  -1.12911144e-16+0.00000000e+00j  0.00000000e+00-1.73201297e-17j
#   0.00000000e+00+1.03281420e-17j -4.67562187e-19+0.00000000e+00j]
