# %% [markdown]
# ## SRJ

# %%
import numpy as np
cstate = np.array([0, 0, 1, 0, 1, 1, 0, 1])
c2state = np.array([0,1,1,1,1,0,0,0])

# %%
import pennylane as qml
from pennylane import qchem
from pennylane import numpy as np
from itertools import chain
import time
import re
from scipy.optimize import minimize
ash_excitation = []
energies = []
excitations= []
grad = []

X = qml.PauliX
Y = qml.PauliY
Z = qml.PauliZ
I = qml.Identity



bond_length = 3.0
symbols = ["H","H","H","H"]
electrons = 4
orbitals = 8
r_bohr = bond_length *1.8897259886  
coordinates = np.array([[0.0,0.0, 1*r_bohr], [0.0, 0.0, 2*r_bohr], [0.0,0.0,3*r_bohr],[0.0, 0.0, 4*r_bohr]])
H, qubits = qml.qchem.molecular_hamiltonian(symbols, coordinates, basis="sto-6g", method="pyscf")
#hf_state = qchem.hf_state(electrons, qubits)




def adaptvqe_updated(c2state,adapt_it = 4, e_th=1e-12):
    print('checking input',c2state)
    ash_excitation = []
    energies = []
    excitations= []
    #Calculation of HF state
    dev = qml.device("lightning.qubit", wires=qubits, shots=100000)
    @qml.qnode(dev)
    def circuit(c2state, electrons, qubits, H):
        print('Updated c2state is', c2state)  
        qml.BasisState(c2state, wires=range(qubits))
        return qml.expval(H)   #Calculating the expectation value of the Hamiltonian
    
    # Commutator calculation for HF state
    @qml.qnode(dev)
    def commutator_0(H,w, k):  #H is the Hamiltonian, w is the operator, k is the basis state - HF state
        qml.BasisState(k, wires=range(qubits))
        res = qml.commutator(H, w)   #Calculating the commutator
        return qml.expval(res)
    
    # Commutator calculation for other states except HF state
    @qml.qnode(dev)
    def commutator_1(H,w, k): #H is the Hamiltonian, w is the operator, k is the basis state
        qml.StatePrep(k, wires=range(qubits))
        res = qml.commutator(H, w) #Calculating the commutator
        return qml.expval(res)

    #Energy calculation 
    @qml.qnode(dev)
    def ash(params, ash_excitation, c2state, H):
        print('Updated c2state is', c2state)
        qml.BasisState(c2state, wires=range(qubits))  #Applying the c state
        for i, excitation in enumerate(ash_excitation):
            if len(ash_excitation[i]) == 4:
                qml.FermionicDoubleExcitation(weight=params[i], wires1=ash_excitation[i][2:][::-1], wires2=ash_excitation[i][:2][::-1])
            elif len(ash_excitation[i]) == 2:
                qml.FermionicSingleExcitation(weight=params[i], wires=list(range(ash_excitation[i][0], ash_excitation[i][1] + 1)))
        return qml.expval(H)  #Calculating the expectation value of the Hamiltonian
    
    # Calculation of New state, same as the above function but with the state return
    dev1 = qml.device("lightning.qubit", wires=qubits)
    @qml.qnode(dev1)
    def new_state(c2state, ash_excitation, params):
        print('Updated c2state is', c2state)
        qml.BasisState(c2state, wires=range(qubits))  #Applying the c state
        for i, excitations in enumerate(ash_excitation):
            if len(ash_excitation[i]) == 4:
                qml.FermionicDoubleExcitation(weight=params[i], wires1=ash_excitation[i][2:][::-1], wires2=ash_excitation[i][:2][::-1])
            elif len(ash_excitation[i]) == 2:
                qml.FermionicSingleExcitation(weight=params[i], wires=list(range(ash_excitation[i][0], ash_excitation[i][1] + 1)))
        return qml.state()
    
    def cost(params):
        energy = ash(params, ash_excitation, c2state, H)
        return energy

    def callback(params):
        print(f"Current parameters: {params}")
        print(f"Current cost: {cost(params)}\n")
    

    print('c2 state is', circuit(c2state, electrons, qubits, H))
    singles, doubles = qml.qchem.excitations(electrons, orbitals)
    op1 =  [qml.fermi.FermiWord({(0, x[0]): "+", (1, x[1]): "-"}) for x in singles]
    op2 =  [qml.fermi.FermiWord({(0, x[0]): "+", (1, x[1]): "+", (2, x[2]): "-", (3, x[3]): "-"})for x in doubles]
    operator_pool = (op1) + (op2)  #Operator pool - Singles and Doubles
    states = [c2state]
    

    for j in range(adapt_it):
        print('The adapt iteration now is', j)  #Adapt iteration
        max_value = float('-inf')
        max_operator = None
        k = states[-1] if states else c2state  # if states is empty, fall back to hf_state
       
        for i in operator_pool:
            w = qml.fermi.jordan_wigner(i)  #JW transformation
            if np.array_equal(k, c2state): # If the current state is the HF state
                print('Current state is c state')
                current_value = abs(2*(commutator_0(H, w, k)))      #Commutator calculation is activated  
            else:
                current_value = abs(2*(commutator_1(H, w, k)))      #For other states, commutator calculation is activated
            #print(f'The expectation value of {i} is', current_value)

            if current_value > max_value:
                max_value = current_value
                max_operator = i

        print(f"The highest operator value is {max_value} for operator {max_operator}")  #Highest operator value
        grad.append(max_value)
        # Convert operator to excitations and append to ash_excitation
        indices_str = re.findall(r'\d+', str(max_operator))
        excitations = [int(index) for index in indices_str]
        print('Highest gradient excitation is', excitations)
        ash_excitation.append(excitations) #Appending the excitations to the ash_excitation
        if j == 0:
            params = qml.numpy.zeros(len(ash_excitation), requires_grad=True)  #Parameters initialization

        else:
            params = np.append(params, 0.0) 
 


        #Energy calculation
        result = minimize(cost, params, method='powell', callback=callback, tol = e_th, options = {'disp': True, 'maxiter': 1e8, 'xtol':1e-8, 'ftol':1e-8})


        params= (result.x)
        energies.append(result.fun)
        print('Updated params are', params)
        print('Updated excitation are', ash_excitation)

        # New state generation - With the updated parameters
        ostate = new_state(c2state, ash_excitation, params)
        print(qml.draw(new_state, max_length=100)(c2state,ash_excitation,params))
        gs_state = ostate
        # Append the new state to the states list
        states.append(ostate)

    return energies, params, ash_excitation, gs_state, H, qubits

# %%
energies, params, ash_excitation, gs_state,H, qubits = adaptvqe_updated(c2state, adapt_it = 10, e_th=1e-12)
print('Energies:', energies)
print('Gradient:', grad)
# Out:
# checking input [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# c2 state is -1.264503149865449
# The adapt iteration now is 0
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# Current state is c state
# The highest operator value is 0.3107667700233577 for operator a⁺(2) a⁺(3) a(6) a(7)
# Highest gradient excitation is [2, 3, 6, 7]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current parameters: [-1.42423468]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current cost: -1.3981011134753714
#
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current parameters: [-1.43740342]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current cost: -1.3935867491696785
#
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current parameters: [-1.4243058]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current cost: -1.3973437476625705
#
# Optimization terminated successfully.
#          Current function value: -1.399558
#          Iterations: 3
#          Function evaluations: 97
# Updated params are [-1.4243058]
# Updated excitation are [[2, 3, 6, 7]]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# 0: ─╭|Ψ⟩───────────────────────────────────┤  State
# 1: ─├|Ψ⟩───────────────────────────────────┤  State
# 2: ─├|Ψ⟩─╭FermionicDoubleExcitation(-1.42)─┤  State
# 3: ─├|Ψ⟩─├FermionicDoubleExcitation(-1.42)─┤  State
# 4: ─├|Ψ⟩─│─────────────────────────────────┤  State
# 5: ─├|Ψ⟩─│─────────────────────────────────┤  State
# 6: ─├|Ψ⟩─├FermionicDoubleExcitation(-1.42)─┤  State
# 7: ─╰|Ψ⟩─╰FermionicDoubleExcitation(-1.42)─┤  State
# The adapt iteration now is 1
# The highest operator value is 0.2050477942678575 for operator a⁺(1) a⁺(2) a(5) a(6)
# Highest gradient excitation is [1, 2, 5, 6]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current parameters: [-1.44415074  1.07181163]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current cost: -1.4589034154453444
#
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current parameters: [-1.07317182  1.07172411]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current cost: -1.4711707013851225
#
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current parameters: [-1.05125145  1.18428588]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current cost: -1.472522409863411
#
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current parameters: [-1.09024132  1.18353539]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current cost: -1.4731273885769358
#
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current parameters: [-1.01164134  1.26814661]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current cost: -1.4724625689391506
#
# Optimization terminated successfully.
#          Current function value: -1.475440
#          Iterations: 5
#          Function evaluations: 371
# Updated params are [-1.01164134  1.26814661]
# Updated excitation are [[2, 3, 6, 7], [1, 2, 5, 6]]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# 0: ─╭|Ψ⟩────────────────────────────────────────────────────────────────────┤  State
# 1: ─├|Ψ⟩───────────────────────────────────╭FermionicDoubleExcitation(1.27)─┤  State
# 2: ─├|Ψ⟩─╭FermionicDoubleExcitation(-1.01)─├FermionicDoubleExcitation(1.27)─┤  State
# 3: ─├|Ψ⟩─├FermionicDoubleExcitation(-1.01)─│────────────────────────────────┤  State
# 4: ─├|Ψ⟩─│─────────────────────────────────│────────────────────────────────┤  State
# 5: ─├|Ψ⟩─│─────────────────────────────────├FermionicDoubleExcitation(1.27)─┤  State
# 6: ─├|Ψ⟩─├FermionicDoubleExcitation(-1.01)─╰FermionicDoubleExcitation(1.27)─┤  State
# 7: ─╰|Ψ⟩─╰FermionicDoubleExcitation(-1.01)──────────────────────────────────┤  State
# The adapt iteration now is 2
# The highest operator value is 0.20373971221913992 for operator a⁺(1) a⁺(3) a(5) a(7)
# Highest gradient excitation is [1, 3, 5, 7]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current parameters: [-1.01007292  1.26365227  1.46874839]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current cost: -1.5452456023154015
#
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current parameters: [-1.04002225  1.15444447  1.47377357]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current cost: -1.5429547049729964
#
# Optimization terminated successfully.
#          Current function value: -1.545409
#          Iterations: 2
#          Function evaluations: 201
# Updated params are [-1.04002225  1.15444447  1.47377357]
# Updated excitation are [[2, 3, 6, 7], [1, 2, 5, 6], [1, 3, 5, 7]]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# 0: ─╭|Ψ⟩───────────────────────────────────────────────────────────────────
# 1: ─├|Ψ⟩───────────────────────────────────╭FermionicDoubleExcitation(1.15)
# 2: ─├|Ψ⟩─╭FermionicDoubleExcitation(-1.04)─├FermionicDoubleExcitation(1.15)
# 3: ─├|Ψ⟩─├FermionicDoubleExcitation(-1.04)─│───────────────────────────────
# 4: ─├|Ψ⟩─│─────────────────────────────────│───────────────────────────────
# 5: ─├|Ψ⟩─│─────────────────────────────────├FermionicDoubleExcitation(1.15)
# 6: ─├|Ψ⟩─├FermionicDoubleExcitation(-1.04)─╰FermionicDoubleExcitation(1.15)
# 7: ─╰|Ψ⟩─╰FermionicDoubleExcitation(-1.04)─────────────────────────────────
#
# ───────────────────────────────────┤  State
# ──╭FermionicDoubleExcitation(1.47)─┤  State
# ──│────────────────────────────────┤  State
# ──├FermionicDoubleExcitation(1.47)─┤  State
# ──│────────────────────────────────┤  State
# ──├FermionicDoubleExcitation(1.47)─┤  State
# ──│────────────────────────────────┤  State
# ──╰FermionicDoubleExcitation(1.47)─┤  State
# The adapt iteration now is 3
# The highest operator value is 0.3100308384208894 for operator a⁺(0) a⁺(3) a(4) a(7)
# Highest gradient excitation is [0, 3, 4, 7]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current parameters: [-1.07096561  1.06427453  1.46813854 -1.6742039 ]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current cost: -1.697088338686364
#
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current parameters: [-1.27397569  1.04461807  1.85010454 -1.68442933]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current cost: -1.7150786381935517
#
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current parameters: [-1.28738774  1.04461807  1.93729728 -1.68016551]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current cost: -1.7145465592344116
#
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# ...
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current parameters: [-1.56541748  1.55681179 -0.07150731 -1.61528487 -1.61295149  1.48092716
#   0.16529465  0.15476382  0.14884268  0.14473878]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Current cost: -1.883154786423321
#
# Optimization terminated successfully.
#          Current function value: -1.885309
#          Iterations: 2
#          Function evaluations: 664
# Updated params are [-1.56541748  1.55681179 -0.07150731 -1.61528487 -1.61295149  1.48092716
#   0.16529465  0.15476382  0.14884268  0.14473878]
# Updated excitation are [[2, 3, 6, 7], [1, 2, 5, 6], [1, 3, 5, 7], [0, 3, 4, 7], [0, 2, 4, 6], [1, 3, 5, 7], [2, 6], [1, 5], [0, 4], [3, 7]]
# Updated c2state is [0 1 1 1 1 0 0 0]
# Updated c2state is [0 1 1 1 1 0 0 0]
# 0: ─╭|Ψ⟩───────────────────────────────────────────────────────────────────
# 1: ─├|Ψ⟩───────────────────────────────────╭FermionicDoubleExcitation(1.56)
# 2: ─├|Ψ⟩─╭FermionicDoubleExcitation(-1.57)─├FermionicDoubleExcitation(1.56)
# 3: ─├|Ψ⟩─├FermionicDoubleExcitation(-1.57)─│───────────────────────────────
# 4: ─├|Ψ⟩─│─────────────────────────────────│───────────────────────────────
# 5: ─├|Ψ⟩─│─────────────────────────────────├FermionicDoubleExcitation(1.56)
# 6: ─├|Ψ⟩─├FermionicDoubleExcitation(-1.57)─╰FermionicDoubleExcitation(1.56)
# 7: ─╰|Ψ⟩─╰FermionicDoubleExcitation(-1.57)─────────────────────────────────
#
# ────────────────────────────────────╭FermionicDoubleExcitation(-1.62)
# ──╭FermionicDoubleExcitation(-0.07)─│────────────────────────────────
# ──│─────────────────────────────────│────────────────────────────────
# ──├FermionicDoubleExcitation(-0.07)─├FermionicDoubleExcitation(-1.62)
# ──│─────────────────────────────────├FermionicDoubleExcitation(-1.62)
# ──├FermionicDoubleExcitation(-0.07)─│────────────────────────────────
# ──│─────────────────────────────────│────────────────────────────────
# ──╰FermionicDoubleExcitation(-0.07)─╰FermionicDoubleExcitation(-1.62)
#
# ──╭FermionicDoubleExcitation(-1.61)─────────────────────────────────
# ──│─────────────────────────────────╭FermionicDoubleExcitation(1.48)
# ──├FermionicDoubleExcitation(-1.61)─│───────────────────────────────
# ──│─────────────────────────────────├FermionicDoubleExcitation(1.48)
# ──├FermionicDoubleExcitation(-1.61)─│───────────────────────────────
# ──│─────────────────────────────────├FermionicDoubleExcitation(1.48)
# ──╰FermionicDoubleExcitation(-1.61)─│───────────────────────────────
# ────────────────────────────────────╰FermionicDoubleExcitation(1.48)
#
# ────────────────────────────────────────────────────────────────────╭FermionicSingleExcitation(0.15)
# ───────────────────────────────────╭FermionicSingleExcitation(0.15)─├FermionicSingleExcitation(0.15)
# ──╭FermionicSingleExcitation(0.17)─├FermionicSingleExcitation(0.15)─├FermionicSingleExcitation(0.15)
# ──├FermionicSingleExcitation(0.17)─├FermionicSingleExcitation(0.15)─├FermionicSingleExcitation(0.15)
# ──├FermionicSingleExcitation(0.17)─├FermionicSingleExcitation(0.15)─╰FermionicSingleExcitation(0.15)
# ──├FermionicSingleExcitation(0.17)─╰FermionicSingleExcitation(0.15)─────────────────────────────────
# ──╰FermionicSingleExcitation(0.17)──────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# ───────────────────────────────────┤  State
# ───────────────────────────────────┤  State
# ───────────────────────────────────┤  State
# ──╭FermionicSingleExcitation(0.14)─┤  State
# ──├FermionicSingleExcitation(0.14)─┤  State
# ──├FermionicSingleExcitation(0.14)─┤  State
# ──├FermionicSingleExcitation(0.14)─┤  State
# ──╰FermionicSingleExcitation(0.14)─┤  State
# Energies: [-1.3995576746232408, -1.4754403320728307, -1.5454086742893527, -1.713723969049848, -1.7731599405900755, -1.8594967601502421, -1.8756887857323705, -1.878681575503264, -1.8798720450052755, -1.8853085318925868]
# Gradient: [0.3107667700233577, 0.2050477942678575, 0.20373971221913992, 0.3100308384208894, 0.18435944330477258, 0.22880027506597125, 0.10305593082122638, 0.09592075470022927, 0.08940412140449948, 0.08884407153259985]

# %%
ash_excitation
# Out:
# [[2, 3, 6, 7],
#  [1, 2, 5, 6],
#  [1, 3, 5, 7],
#  [0, 3, 4, 7],
#  [0, 2, 4, 6],
#  [1, 3, 5, 7],
#  [2, 6],
#  [1, 5],
#  [0, 4],
#  [3, 7]]
